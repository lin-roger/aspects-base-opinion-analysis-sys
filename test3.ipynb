# %%
from bs4 import BeautifulSoup
from PttWebCrawler.crawler import PttWebCrawler
from dateutil import parser
from datetime import datetime, timedelta

import requests
import re
import time
import json

# %%
VERIFY = True
PTT_URL = "https://www.ptt.cc"

# %%
def _parse_articles(index, board, timeout=3):
    link_aid_board_set = set()
    resp = requests.get(
        url=PTT_URL + "/bbs/" + board + "/index" + str(index) + ".html",
        cookies={"over18": "1"},
        verify=VERIFY,
        timeout=timeout,
    )
    if resp.status_code != 200:
        print("invalid url:", resp.url)
        return []

    soup = BeautifulSoup(resp.text, "html.parser")
    divs = soup.find_all("div", "r-ent")
    for div in divs:
        try:
            # ex. link would be <a href="/bbs/PublicServan/M.1127742013.A.240.html">Re: [問題] 職等</a>
            href = div.find("a")["href"]
            link = PTT_URL + href
            article_id = re.sub("\.html", "", href.split("/")[-1])
            link_aid_board_set.add((link, article_id, board))
        except:
            pass
    return list(link_aid_board_set)


def _gen_es_article(article, idx_name, board, link):
    def comment_ipdatetime_2_datetime(ipdatetime:str, year:str)->datetime:
        ipdatetime = ipdatetime.split(" ")
        if len(ipdatetime) == 3:
            dt = parser.parse(f"{year}/{ipdatetime[1]} {ipdatetime[2]}", ignoretz=True)
            return dt.strftime("%Y-%m-%d %H:%M:%S.%f")[:-3]
        if len(ipdatetime) == 2:
            dt = parser.parse(f"{year}/{ipdatetime[0]} {ipdatetime[1]}", ignoretz=True)
            return dt.strftime("%Y-%m-%d %H:%M:%S.%f")[:-3]
        return None

    date = article["date"].strftime("%Y-%m-%d %H:%M:%S.%f")[:-3]
    crawl_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")[:-3]
    es_article = {
        "_op_type": "index",
        "_index": idx_name,
        "status_code": "UN_ASTE",
        "platform": "PTT",
        "borad": board,
        "link": link,
        "date": date,
        "crawl_time": crawl_time,
        "title": article["article_title"],
        "context": article["content"],
        "comments": [
            {
                "username": message["push_userid"],
                "content": message["push_content"],
                "date": comment_ipdatetime_2_datetime(message["push_ipdatetime"], date[:4]),
            }
            for message in article["messages"]
            if message["push_content"]
        ],
    }
    return es_article


def get_ptt_article_generator(
    idx_name: str, board="Gossiping", least_n_days: float = 7
):
    least_n_days = timedelta(days=least_n_days)
    last_page = PttWebCrawler.getLastPage(board)
    page_pointer = last_page
    now = datetime.now()
    while page_pointer > 0:
        link_aid_board_list = _parse_articles(page_pointer, board)
        for link, aid, board in link_aid_board_list:
            try:
                article_str = PttWebCrawler.parse(link, aid, board)
                article = json.loads(article_str)
                article["date"] = parser.parse(
                    article["date"], ignoretz=True
                ) - timedelta(hours=8)
            except Exception as e:
                page_pointer = 0
                break
            if (now - article["date"]) > least_n_days:
                if page_pointer == last_page:
                    continue
                else:
                    page_pointer = 0
                    break
            else:
                yield _gen_es_article(article, idx_name, board, link)
        page_pointer -= 1

# %%
list(get_ptt_article_generator("ptt", "Stock", 0.1))
# Out:
# Processing article: M.1730916378.A.2C0
# Processing article: M.1730915738.A.460
# Processing article: M.1730910698.A.7C3
# Processing article: M.1730914841.A.7A3
# Processing article: M.1730911748.A.E0E
# Processing article: M.1730913210.A.170
# Processing article: M.1730910326.A.DEF
# Processing article: M.1730872802.A.680
# Processing article: M.1730738309.A.238
# Processing article: M.1730911261.A.135
# Processing article: M.1730912786.A.751
# Processing article: M.1719872231.A.9BA
# Processing article: M.1730906726.A.069
# [{'_op_type': 'index',
#   '_index': 'ptt',
#   'status_code': 'UN_ASTE',
#   'platform': 'PTT',
#   'borad': 'Stock',
#   'link': 'https://www.ptt.cc/bbs/Stock/M.1730916378.A.2C0.html',
#   'date': '2024-11-06 18:06:15.000',
#   'crawl_time': '2024-11-07 02:55:52.301',
#   'title': 'Re: [新聞] 川普才剛當選！傳德州州長將來台 要台積',
#   'context': '我只能說川普效應大概就4年，2nm台灣才剛蓋7座場，光是蓋場效率就抵不過晶圓需求了， 等蓋到完，總統又換人了 台積電於2021年在美國亞利桑那州鳳凰城開始建設第一座晶圓廠，原計劃於2024年量產4奈 米製程，但由於人力短缺和建設成本上升等因素，量產時間延後至2025年。 以這個類比，川皇上台時動土剪綵德州場，下台時第一片晶圓不知道孵出來了沒 : 標題: Re: [新聞] 川普才剛當選傳德州州長將來台 要台積 : 時間: Thu Nov 7 00:25:24 2024 : : 如題 : : 之前就講過了 : 台積電騰籠換鳥 愈做愈強 : 台灣島籠中無鳥 愈來愈慘 : : 台積電未來20年肯定還是頂尖公司 : 只是台灣就不一定了 : 台積電裡面幹的事情就是製造業 : 製造業只有有人有錢就搞的起來 : 你真的覺得美國有真的缺錢還是缺人 : 政治力量是可以壓倒一切的 : : 再說了很多事情都是有跡可循 : 之前的新聞 : 為什麼一間世界市值前十的公司 : 要給日本高中生學費跟生活費補助 : 讓他們來台灣念大學 : 你能想像英特爾極盛時期 : 補助台灣高中生去美國讀大學嗎 : : 亮哥之前提出來還被狂噓 保護費不一定是錢 : 美國日本打的算盤局外人應該都看的清楚了 : : : 我已經清晰可以預見20年後的2045 : 2030年出生的台灣人問長輩 : Morris是誰 為什麼當初可以國葬 : 長輩答道 他呀 : 給台灣人創造了一家本不屬於這座島的公司 : 那是一個念理工科系就有一份體面薪水的時代 : 那是一個台灣人懷揣夢想前進股市的時代 : 那是一個最好的時代也是最壞的時代 : : 年輕人接著問到 : 那麼這一間偉大公司呢？ 怎麼沒聽說過了 : 長輩答道 : 已經被分拆成三間超大型公司 : 史稱三家分G : 分別在歐洲 日本 美國 : 很多島上的台勞都在這三間公司當協作了 : : 以上 : : : 引述《DrowningPool (My broken dreams)》之銘言： : : 原文標題：川普才剛當選傳德州州長將來台 要台積電設廠 : : 原文連結： https://ynews.page.link/84xVC : : 發布時間：2024116 : : 原文內容： : : 川普當選入主白宮，就在同一天，被川普拿下的德州，同時也是挺川大將馬斯克和眾多 : 企 : : 業集結的重鎮，現在傳出德州州長將來台灣找台積電，意圖拉攏台積電設廠。加上之前 : 川 : : 普的保護費一說，市場擔心是否真的要變成美積電。不過經濟部回應先進製程是 : 一 : : 個人的武林，不擔心。 : : 繼亞利桑那後，各處都有晶圓廠正在施工，傳出德州州長等一行人，計劃在美選後拜訪 : 台 : : 灣，爭取台積電設廠，還說會提供比亞利桑那州更好的水電以及優惠補助條件。 : : 半導體專家曲建仲：台積電的判斷準則，一定是看你給的條件適不適合我過去。當地 : 本 : : 來就有半導體的晶圓廠，也有相關供應鏈
#   'comments': []},
#  {'_op_type': 'index',
#   '_index': 'ptt',
#   'status_code': 'UN_ASTE',
#   'platform': 'PTT',
#   'borad': 'Stock',
#   'link': 'https://www.ptt.cc/bbs/Stock/M.1730914841.A.7A3.html',
#   'date': '2024-11-06 17:40:36.000',
#   'crawl_time': '2024-11-07 02:55:53.036',
#   'title': 'Re: [心得] 妖股的故事 第一篇',
#   'context': '個股認真文目前很稀少，進泰電子個案是屬於標準借殼案，只 是主要公司控制權是透過轉移控股公司來達成相對隱密，而整 理整個案件的時程也可以讓各位理解整個發展過程，作為個案 學習，但部分推測部分不宜公開評論，就點出讓各位觀察，也 能作為之後的經驗借鏡。 啟動階段 2018/09/05本公司董事會選任新任董事長 2018/12/14公告本公司名稱由祥業科技股份有限公司更名 為進泰電子科技股份有限公司 2018/12/24私募繳款 42000000元 2020/01/02本公司董事會通過總經理異動公告 2020/03/26私募繳款176190000元 2020/03/26私募繳款100080000元 併入階段 2020/04/16公告本公司董事會決議通過投資進泰電子科技 (越南)有限公司 2020年07月營收開出4563萬元，股價由私募時約37元漲到08月 營收開出時約7X元 2020/11/09公告本公司董事會通過 109年第三季合併財務報告 ，盈餘已轉正2020年累計營收 3億5118萬元，股價已到 17X元 2021/02/18本公司董事會決議通過發行國內第三次有擔保轉換 公司債 2021/03/18本公司董事會決議通過對進泰電子科技(越南)有 限公司現金增資案 2021/07/29本公司董事會推選邢家蓁女士擔任董事長 注意改選後代表不同法人 整合核心主體 2021/11/04本公司董事會決議通過透過 Advanced Sound Technologes Inc. 間接投資大陸地區美金 880萬元 此為轉增資東莞進泰電子有限公司，這公告建議有要研究的板 友要去細看，這裡面透露一個重要訊息，我就不公開點破。 巔峰與後續募資 2021年累計營收30.5億元，股價也在12月迎來高點 270元。 2022年累計營收14.3億元，股價年底收在80.1元。 2023/05/09本公司國內第四次無擔保轉換公司債收足債款 2023/08/04本公司112年度現金增資收足股款暨增資基準日 2023年累計營收12.3億元，股價年底收在77.3元。 心得與小記 本案在整合過程中初期使用其他關係人貿易模式，外部人不易 理解整體產銷研的成本，不易估計最終狀況；外部人在評估借 殼案時另一大風險是不易初期知道整合時程與範圍，在實際其 他個案也有取消或縮小整合標的的情形，這會讓想搭便車發生 套牢狀況；最後是當消息散播之前市場多半已有動靜，等到證 實時最甜美的階段已過，因此很考驗決定的速度與品質，需要 日常的經驗累積與風險控管能力。 責任聲明：本內容僅供參考，投資需審慎考量本身之需求與投資風險，吾恕不負任何法律 責任，亦不作任何保證。內容數據取材於公開資訊觀測站，或各公司財務資訊專區，或相 關網站資料引述；資料數據有誤請指正，並以資料出處為準，若資料內容有未盡完善之處 ，恕不負責。此外，非經本人同意，不得將本篇內容加以複製或轉載。 ',
#   'comments': []},
#  {'_op_type': 'index',
#   '_index': 'ptt',
#   'status_code': 'UN_ASTE',
#   'platform': 'PTT',
#   'borad': 'Stock',
#   'link': 'https://www.ptt.cc/bbs/Stock/M.1730911748.A.E0E.html',
#   'date': '2024-11-06 16:49:01.000',
#   'crawl_time': '2024-11-07 02:55:53.282',
#   'title': '[情報] 5284 jpp-KY 113年10月營收',
#   'context': '標題：113年10月營收 來源：臺灣證券交易所 網址： https://mopsplus.twse.com.tw/mops//web/t146sb05?companyId=5284 內文： 本年迄今累計營收 去年同期累計營收 累計營收成長率 1937229 1950288 0.67% 113年10月營收 去年同期月營收 月營收成長率 252569 190732 32.42% 113年09月營收 去年同期月營收 月營收成長率 207514 206695 0.40% 113年08月營收 去年同期月營收 月營收成長率 208511 221383 5.81% 113年07月營收 去年同期月營收 月營收成長率 205260 215057 4.56% ',
#   'comments': [{'username': 'kaneka',
#     'content': '相當亮眼',
#     'date': '2024-11-07 01:09:00.000'}]},
#  {'_op_type': 'index',
#   '_index': 'ptt',
#   'status_code': 'UN_ASTE',
#   'platform': 'PTT',
#   'borad': 'Stock',
#   'link': 'https://www.ptt.cc/bbs/Stock/M.1730913210.A.170.html',
#   'date': '2024-11-06 17:13:28.000',
#   'crawl_time': '2024-11-07 02:55:53.526',
#   'title': 'Re: [請益] 美債套著配也舒服？？？',
#   'context': '讓專業的來 債蛙應該把個人榮辱 利益放在身後 想想美債的發行 就是為了建設大美國 而美國強大 間接保護台灣 所以債蛙們 不放棄 不拋棄 不管 川普 爸爸 印多少 美債 買就對了 你們是川普黃金四年 建設美國的無名英雄 ',
#   'comments': []},
#  {'_op_type': 'index',
#   '_index': 'ptt',
#   'status_code': 'UN_ASTE',
#   'platform': 'PTT',
#   'borad': 'Stock',
#   'link': 'https://www.ptt.cc/bbs/Stock/M.1730911261.A.135.html',
#   'date': '2024-11-06 16:40:53.000',
#   'crawl_time': '2024-11-07 02:55:56.882',
#   'title': '[情報] 元大台灣50反1 ETF(00632R)將進行反分割',
#   'context': '標題： 公告本公司經理之元大ETF傘型證券投資信託基金之台灣 50單日反向1倍證券投資信託 基金(以下簡稱本基金，證券代 碼00632R)向臺灣證券交易所股份有限公司申請辦理反 分割。 元大台灣50反1 ETF(00632R)將進行反分割作業，113年12月11日為新受益憑證上市買賣日 來源：臺灣證券交易所 網址： https://www.twse.com.tw/zh/ETFortune/announcementList 內文： 臺灣證券交易所（下稱證交所）表示，由元大證券投資信託股份有限公司(下稱元大投信) 經理之元大ETF傘型證券投資信託基金之台灣50單日反向1倍證券投資信託基金受益憑 證 （簡稱：元大台灣50反1，代號：00632R），於113年10月17日受益人大會通過該基金進行 反分割，元大投信並於113年11月5日向證交所申請辦理反分割作業。證交所表示，該基金 受益憑證單位數反分割比率為0.14285714(反分割後受益權單位數:反分割前受益權單位數 =1:7)， 即投資人原如持有7個受益權單位者，於反分割後將換發為持有1個受益權單位 。 因應反分割作業，該受益憑證將於113年11月28日進行信用交易最後回補，自 113年12月4日起至113年12月10日停止在市場買賣 ，自113年12月6日起至113年12月10日停 止受益人名簿記載變更，並將 以113年12月11日作為新受益憑證換發基準日、新受益憑證 上市開始買賣日及舊受益憑證終止上市日 。 1.事實發生日:113/11/05 2.發生緣由:依據中華民國(下同)113年10月
#   'comments': [{'username': 'cin0921',
#     'content': '避免淨值等於2',
#     'date': '2024-11-07 00:42:00.000'},
#    {'username': 'distantblc',
#     'content': '反1可以繼續套著賠惹QAQ',
#     'date': '2024-11-07 00:49:00.000'},
#    {'username': 'DogEggz',
#     'content': '反一都反分割了，多軍大獲全勝',
#     'date': '2024-11-07 00:53:00.000'},
#    {'username': 'yousking',
#     'content': '套著賠都舒服',
#     'date': '2024-11-07 00:58:00.000'},
#    {'username': 'fhrhung',
#     'content': '收一收就好了，假鬼假怪',
#     'date': '2024-11-07 01:07:00.000'},
#    {'username': 'allen1988',
#     'content': '美國反向也有反分割阿，還原回去2010年股價是7位數',
#     'date': '2024-11-07 01:08:00.000'},
#    {'username': 'mamorui',
#     'content': '酷耶 反分割',
#     'date': '2024-11-07 01:09:00.000'},
#    {'username': 'allen1988',
#     'content': 'SQQQ 還原2010是44萬5，現在6.7',
#     'date': '2024-11-07 01:11:00.000'},
#    {'username': 'Jerry469',
#     'content': '笑死 爛東西',
#     'date': '2024-11-07 01:47:00.000'},
#    {'username': 'aowen', 'content': '韮爆', 'date': '2024-11-07 02:02:00.000'},
#    {'username': 'tsai18',
#     'content': '看空買這隻垃圾幹麼 直接期指容易多了',
#     'date': '2024-11-07 02:17:00.000'},
#    {'username': 'knives',
#     'content': '真的不愧是最大券商推出來的ETF',
#     'date': '2024-11-07 02:38:00.000'},
#    {'username': 'EvilJustice',
#     'content': '這東西是不是不會下市？只要一直反分割就好？',
#     'date': '2024-11-07 02:38:00.000'}]},
#  {'_op_type': 'index',
#   '_index': 'ptt',
#   'status_code': 'UN_ASTE',
#   'platform': 'PTT',
#   'borad': 'Stock',
#   'link': 'https://www.ptt.cc/bbs/Stock/M.1730912786.A.751.html',
#   'date': '2024-11-06 17:06:24.000',
#   'crawl_time': '2024-11-07 02:55:57.164',
#   'title': 'Re: [請益] 美債套著配也舒服？？？',
#   'context': '先說一下，我現在幾乎七成都是美債。 但我覺得到目前非常舒服，這一年利息大概領了十幾萬了（漲上去我都沒賣） 首先因為我工作就是領薪水的，加上吃喝生活全部靠自己，可以說就是沒有勇氣輸錢。 我以前買股票大概就是小買，賺個幾萬就跑。 因為我怕賠錢。 這一年我全部all in 買台積電現在賣掉應該能賺200萬300萬。 但重點是我就是沒種，我怕被套。 然後美債這種不管怎樣都能穩定給到快5%利息的，甚至放久了還可以賺到降息價差的產品。 簡直無敵適合我這種怕賠錢的打工仔。 而且我這兩年還買了房子，完全沒有輸的勇氣 大概是這樣，所以明天再跌我會繼續買。 畢竟這種產品最適合我這種怕賠錢的人 ',
#   'comments': []}]

# %%
{
    "_op_type": "index",
    "_index": idx_name,
    "status_code": "UN_ASTE",
    "platform": "PTT",
    "borad": board,
    "link": i["link"],
    "date": i["date"].replace("T", " ").replace("Z", ""),
    "crawl_time": i["crawl_time"].replace("T", " ").replace("Z", ""),
    "title": i["title"],
    "context": i["context"],
    "comments": [
        {
            "username": j[0],
            "content": j[1],
            "date": j[2].replace("T", " ").replace("Z", ""),
        }
        for j in i["comments"]
        if j[1]
    ],
}
