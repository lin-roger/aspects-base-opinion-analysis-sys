# %%
from elasticsearch import Elasticsearch, helpers
from glom import glom, Coalesce
from itertools import chain, combinations
from pprint import pprint as print

import datetime
import pandas as pd
import yaml

# %%
with open("config.yaml", "r", encoding="utf-8") as stream:
    config = yaml.safe_load(stream)

es = Elasticsearch(
    "http://127.0.0.1:9200",
    verify_certs=False,
    basic_auth=("elastic", "123456"),
)

index = config["index"]

# %%
es.info()
# Out:
# ObjectApiResponse({'name': 'c4a7017a324d', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'CW97Ie5ZSPKXZafOAxIPeQ', 'version': {'number': '8.15.3', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': 'f97532e680b555c3a05e73a74c28afb666923018', 'build_date': '2024-10-09T22:08:00.328917561Z', 'build_snapshot': False, 'lucene_version': '9.11.1', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
def query_from_es(
    query_words: list[str],
    query_range: tuple[datetime.date, datetime.date],
    selection: list[str],
    selection_broad: list[str],
    tern_seatch: bool,
):
    body = {
        "_source": [
            # "platform",
            # "borad",
            "title_aste.*",
            "context_aste.*",
            "date",
            "comments.content_aste.*",
        ],
        "query": {
            "bool": {
                "filter": [
                    {
                        "bool": {
                            "should": [],
                        }
                    },
                    {"terms": {"platform": selection}},
                    {"terms": {"borad": selection_broad}},
                    {
                        "range": {
                            "date": {
                                "gte": query_range[0].isoformat(),
                                "lte": query_range[1].isoformat(),
                                "time_zone": "+08:00",
                                "format": "yyyy-MM-dd",
                            },
                        }
                    },
                ]
            }
        },
    }
    if tern_seatch:
        query_words = query_words.split()
        body["query"]["bool"]["filter"][0]["bool"]["should"] = [
            {
                "terms_set": {
                    "title_token.keyword": {
                        "terms": query_words,
                        "minimum_should_match_script": {"source": "params.num_terms"},
                    }
                }
            },
            {
                "terms_set": {
                    "context_token.keyword": {
                        "terms": query_words,
                        "minimum_should_match_script": {"source": "params.num_terms"},
                    }
                }
            },
        ]
    else:
        body["query"]["bool"]["filter"][0]["bool"]["should"] = [
            {
                "multi_match": {
                    "query": " ".join(query_words),
                    "fields": ["title", "context"],
                    "minimum_should_match": "3<75%",
                }
            }
        ]

    # print(body)

    res = list(helpers.scan(es, query=body, index=index, size=5000))
    return res

    # assert len(res) != 0
    # coalesce_of_path = Coalesce(
    #     "*._source.context_aste",
    #     "*._source.title_aste",
    #     "*._source.comments.*.content_aste",
    # )
    # aop_df = pd.DataFrame.from_dict(
    #     list(chain.from_iterable(glom(res, coalesce_of_path)))
    # )
    # aop_df["t"] = aop_df["p"].map(
    #     lambda x: "POS" if x >= 6 else "NAT" if x > 4 else "NEG"
    # )
    # return aop_df

# %%
today = datetime.date.today()
last_month = today - datetime.timedelta(days=30)

# %%
boards = []
platform = []
for k, v in config["platforms"].items():
    platform.append(k)
    boards += v["boards"]

# %%
tmp = query_from_es("台灣", (last_month, today), platform, boards, True)

# %%
coalesce_of_path = Coalesce(
    "_source.context_aste",
    "_source.title_aste",
    "_source.comments.*.content_aste",
)

# %%
len(tmp)
# Out:
# 11035

# %%
list_dict = []
for idx, i in enumerate(tmp):
    try:
        g_tmp = glom(i, coalesce_of_path)
        if isinstance(g_tmp[0], list):
            g_tmp = chain.from_iterable(g_tmp)
        for j in g_tmp:
            list_dict.append(
                {
                    "id": i["_id"],
                    "date": i["_source"]["date"],
                    "a": j["a"],
                    "o": j["o"],
                    "p": j["p"],
                }
            )
    except Exception as e:
        pass
        # print(e)
        # print(i)
        # print(g_tmp)

# %%
len(list_dict)
# Out:
# 334969

# %%
aop_df = pd.DataFrame.from_dict(list_dict)
aop_df["date"] = aop_df["date"].astype("datetime64[ns]")

# %%
aop_df["t"] = aop_df["p"].map(
    lambda x: "POS" if x >= 6 else "NAT" if x > 4 else "NEG"
)
# aop_df["t"] = aop_df["p"].map(lambda x: 1 if x >= 6 else 0 if x > 4 else -1)

# %%
aop_df

# %%
list(aop_df["a"].value_counts().to_dict().items())
# Out:
# [('我', 8469),
#  ('人', 6813),
#  ('你', 5661),
#  ('台灣', 5211),
#  ('他', 4554),
#  ('川普', 2766),
#  ('政府', 1955),
#  ('美國', 1913),
#  ('我們', 1882),
#  ('自己', 1795),
#  ('大家', 1746),
#  ('這', 1526),
#  ('他們', 1445),
#  ('中國', 1415),
#  ('她', 1254),
#  ('民進黨', 1082),
#  ('柯文哲', 985),
#  ('誰', 982),
#  ('台灣人', 982),
#  ('者', 919),
#  ('來源', 918),
#  ('標題', 915),
#  ('公司', 806),
#  ('記者', 786),
#  ('國家', 778),
#  ('民眾', 749),
#  ('黃國昌', 745),
#  ('賴清德', 736),
#  ('總統', 720),
#  ('內文', 663),
#  ('中共', 662),
#  ('民眾黨', 655),
#  ('內容', 646),
#  ('媒體', 593),
#  ('颱風', 566),
#  ('時間', 558),
#  ('時候', 556),
#  ('人民', 550),
#  ('台積電', 547),
#  ('們', 542),
#  ('大法官', 523),
#  ('連結', 523),
#  ('日本', 516),
#  ('立委', 491),
#  ('問題', 490),
#  ('你們', 489),
#  ('國民黨', 473),
#  ('新聞', 455),
#  ('網友', 435),
#  ('人士', 435),
#  ('法院', 422),
#  ('備註', 416),
#  ('劉德華', 398),
#  ('官員', 388),
#  ('結果', 383),
#  ('錢', 382),
#  ('烏克蘭', 378),
#  ('法官', 368),
#  ('郭智輝', 356),
#  ('人員', 353),
#  ('關係', 353),
#  ('經濟', 348),
#  ('其中', 346),
#  ('國', 346),
#  ('青鳥', 345),
#  ('立法院', 344),
#  ('北檢', 338),
#  ('政策', 335),
#  ('東西', 333),
#  ('世界', 330),
#  ('事', 328),
#  ('成本', 326),
#  ('法庭', 314),
#  ('人家', 310),
#  ('價格', 307),
#  ('橘子', 305),
#  ('網址', 301),
#  ('賀錦麗', 297),
#  ('事情', 296),
#  ('水桶', 295),
#  ('心得', 290),
#  ('人口', 287),
#  ('俄羅斯', 280),
#  ('個', 278),
#  ('檢方', 277),
#  ('黨', 276),
#  ('它', 276),
#  ('那', 274),
#  ('市場', 272),
#  ('活動', 270),
#  ('朋友', 267),
#  ('人數', 264),
#  ('藍白', 261),
#  ('部分', 260),
#  ('中國人', 260),
#  ('社會', 255),
#  ('戰爭', 255),
#  ('話', 254),
#  ('美國人', 254),
#  ('中華民國', 250),
#  ('企業', 246),
#  ('司法', 245),
#  ('報導', 245),
#  ('委員會', 244),
#  ('單位', 240),
#  ('理由', 237),
#  ('檢察官', 234),
#  ('文章', 232),
#  ('想法', 231),
#  ('地方', 230),
#  ('大選', 226),
#  ('大學', 226),
#  ('產業', 224),
#  ('政黨', 223),
#  ('什麼', 222),
#  ('年', 221),
#  ('部隊', 216),
#  ('兩岸', 215),
#  ('別人', 215),
#  ('民調', 212),
#  ('卓榮泰', 212),
#  ('小草', 209),
#  ('電價', 208),
#  ('外界', 207),
#  ('學生', 204),
#  ('影響', 204),
#  ('各位', 202),
#  ('資', 202),
#  ('影片', 202),
#  ('法律', 202),
#  ('警方', 200),
#  ('國會', 199),
#  ('期間', 199),
#  ('案', 199),
#  ('蔡英文', 199),
#  ('憲法', 197),
#  ('其', 197),
#  ('判決', 196),
#  ('大陸', 196),
#  ('消息', 195),
#  ('雙方', 194),
#  ('地檢署', 194),
#  ('房價', 194),
#  ('馬斯克', 194),
#  ('台電', 193),
#  ('俄軍', 193),
#  ('票', 192),
#  ('券', 192),
#  ('演唱會', 191),
#  ('年輕人', 189),
#  ('預算', 188),
#  ('家', 187),
#  ('圖', 187),
#  ('經濟部', 185),
#  ('事件', 185),
#  ('地區', 182),
#  ('能力', 180),
#  ('王定宇', 179),
#  ('技術', 179),
#  ('對方', 178),
#  ('業者', 177),
#  ('情況', 176),
#  ('康芮', 176),
#  ('議員', 176),
#  ('原因', 175),
#  ('偵查', 175),
#  ('縣市', 174),
#  ('薪水', 173),
#  ('陳啟昱', 173),
#  ('利益', 172),
#  ('選舉', 171),
#  ('機率', 171),
#  ('高雄', 171),
#  ('方面', 170),
#  ('時代', 170),
#  ('廠商', 169),
#  ('態度', 169),
#  ('能源', 168),
#  ('板主', 167),
#  ('制度', 166),
#  ('機關', 166),
#  ('法案', 165),
#  ('報告', 164),
#  ('警察', 164),
#  ('數據', 163),
#  ('行政院', 163),
#  ('國際', 163),
#  ('日本人', 162),
#  ('阿北', 162),
#  ('淘寶', 161),
#  ('個人', 161),
#  ('民主', 159),
#  ('這樣', 159),
#  ('行為', 156),
#  ('集團', 156),
#  ('普丁', 156),
#  ('比例', 156),
#  ('醫師', 155),
#  ('金額', 155),
#  ('台', 154),
#  ('中心', 154),
#  ('資料', 153),
#  ('吳思瑤', 153),
#  ('系統', 152),
#  ('方式', 152),
#  ('選民', 150),
#  ('鄉民', 148),
#  ('小孩', 148),
#  ('天', 148),
#  ('生活', 148),
#  ('ubcs', 148),
#  ('專家', 147),
#  ('程度', 147),
#  ('工作', 145),
#  ('政治', 143),
#  ('表現', 142),
#  ('邏輯', 141),
#  ('電', 139),
#  ('醫生', 139),
#  ('美軍', 139),
#  ('柯', 138),
#  ('委員', 138),
#  ('團隊', 137),
#  ('遊行', 137),
#  ('裡面', 137),
#  ('月', 136),
#  ('新聞網', 136),
#  ('沈伯洋', 135),
#  ('孩子', 134),
#  ('價值', 134),
#  ('署名', 134),
#  ('綠電', 134),
#  ('妳', 133),
#  ('外交部', 132),
#  ('一切', 132),
#  ('壓力', 132),
#  ('館長', 131),
#  ('共產黨', 131),
#  ('物價', 131),
#  ('環境', 130),
#  ('產品', 130),
#  ('股價', 130),
#  ('效果', 130),
#  ('移民', 130),
#  ('需求', 130),
#  ('言論', 129),
#  ('拜登', 129),
#  ('器官', 128),
#  ('男子', 128),
#  ('國軍', 127),
#  ('軍隊', 127),
#  ('習近平', 127),
#  ('立場', 127),
#  ('規模', 127),
#  ('當局', 127),
#  ('速度', 127),
#  ('對岸', 126),
#  ('平台', 126),
#  ('計畫', 125),
#  ('民主黨', 124),
#  ('資源', 124),
#  ('粉絲', 124),
#  ('老師', 124),
#  ('電影', 124),
#  ('地', 123),
#  ('評論', 123),
#  ('老闆', 122),
#  ('資訊', 121),
#  ('香港', 121),
#  ('條件', 120),
#  ('法', 120),
#  ('題', 120),
#  ('台女', 119),
#  ('晶片', 119),
#  ('律師', 119),
#  ('王鴻薇', 119),
#  ('狀況', 119),
#  ('飛彈', 118),
#  ('執政黨', 117),
#  ('先生', 116),
#  ('黨團', 116),
#  ('在野黨', 116),
#  ('案件', 115),
#  ('林佳龍', 115),
#  ('韓國', 115),
#  ('目標', 115),
#  ('沈慶京', 115),
#  ('數量', 114),
#  ('白', 114),
#  ('國籍', 112),
#  ('組織', 112),
#  ('成員', 112),
#  ('移工', 111),
#  ('團體', 111),
#  ('科技', 111),
#  ('學校', 111),
#  ('內政部', 110),
#  ('黃珊珊', 110),
#  ('蔣萬安', 110),
#  ('中央', 110),
#  ('女生', 110),
#  ('這邊', 109),
#  ('歌手', 108),
#  ('郭正亮', 108),
#  ('黃牛', 108),
#  ('陳其邁', 108),
#  ('台北', 107),
#  ('氣象署', 107),
#  ('土地', 107),
#  ('顧立雄', 106),
#  ('綠粉', 106),
#  ('交通', 106),
#  ('解放軍', 105),
#  ('手', 105),
#  ('天氣', 105),
#  ('機會', 105),
#  ('綠畜', 105),
#  ('議題', 105),
#  ('條文', 104),
#  ('員工', 104),
#  ('設計', 104),
#  ('力量', 103),
#  ('收入', 103),
#  ('國防部', 103),
#  ('矢板明夫', 103),
#  ('過程', 103),
#  ('爸爸', 102),
#  ('本身', 102),
#  ('勞工', 102),
#  ('主席', 102),
#  ('馬英九', 102),
#  ('發展', 101),
#  ('假日', 101),
#  ('勢力', 101),
#  ('我國', 101),
#  ('部門', 100),
#  ('營收', 100),
#  ('北院', 100),
#  ('被告', 100),
#  ('老人', 100),
#  ('菲律賓', 100),
#  ('女性', 99),
#  ('文', 99),
#  ('事實', 99),
#  ('資金', 99),
#  ('政權', 98),
#  ('司機', 98),
#  ('綠共', 98),
#  ('學者', 97),
#  ('川', 97),
#  ('車', 97),
#  ('建設', 97),
#  ('差距', 97),
#  ('標準', 96),
#  ('調查', 96),
#  ('綠能', 96),
#  ('品質', 96),
#  ('鳥', 96),
#  ('日', 96),
#  ('陸委會', 95),
#  ('風雨', 95),
#  ('兒子', 95),
#  ('上面', 95),
#  ('臉', 95),
#  ('版本', 95),
#  ('四叉貓', 94),
#  ('爭議', 94),
#  ('市長', 94),
#  ('劉鏡清', 93),
#  ('移民署', 93),
#  ('人物', 93),
#  ('藝人', 93),
#  ('朱立倫', 92),
#  ('財政部', 92),
#  ('風', 92),
#  ('歷史', 92),
#  ('範圍', 92),
#  ('薪資', 91),
#  ('說法', 91),
#  ('您', 91),
#  ('罪', 91),
#  ('代表', 91),
#  ('風險', 91),
#  ('同學', 91),
#  ('客戶', 91),
#  ('文化', 91),
#  ('印度', 90),
#  ('綠營', 90),
#  ('證據', 90),
#  ('共和黨', 90),
#  ('邊', 90),
#  ('教授', 89),
#  ('肥宅', 89),
#  ('規定', 89),
#  ('蛋價', 89),
#  ('家人', 88),
#  ('核電', 88),
#  ('方', 87),
#  ('歌', 87),
#  ('男', 86),
#  ('阿', 86),
#  ('烏軍', 86),
#  ('本人', 86),
#  ('居民', 86),
#  ('綠', 86),
#  ('狗', 86),
#  ('族群', 85),
#  ('權力', 84),
#  ('韓國瑜', 84),
#  ('台北市', 84),
#  ('國民黨團', 83),
#  ('修法', 83),
#  ('條例', 83),
#  ('共軍', 83),
#  ('阿肥', 83),
#  ('指數', 82),
#  ('財劃法', 82),
#  ('網軍', 82),
#  ('原文', 82),
#  ('課程', 82),
#  ('協會', 81),
#  ('官方', 81),
#  ('李貞秀', 81),
#  ('議會', 80),
#  ('身體', 80),
#  ('颱風假', 80),
#  ('政客', 80),
#  ('無人機', 80),
#  ('外國人', 80),
#  ('賴', 80),
#  ('女兒', 80),
#  ('感覺', 80),
#  ('這些', 80),
#  ('聯盟', 79),
#  ('政', 79),
#  ('州', 79),
#  ('教育', 79),
#  ('現場', 79),
#  ('字', 79),
#  ('房子', 79),
#  ('其他', 79),
#  ('門檻', 79),
#  ('經費', 79),
#  ('費用', 78),
#  ('支出', 78),
#  ('以色列', 78),
#  ('高層', 78),
#  ('中', 77),
#  ('節目', 77),
#  ('檢調', 77),
#  ('比', 77),
#  ('重點', 77),
#  ('位置', 76),
#  ('武器', 76),
#  ('行動', 76),
#  ('風機', 76),
#  ('父母', 76),
#  ('美', 76),
#  ('聲音', 76),
#  ('面積', 76),
#  ('候選人', 75),
#  ('台股', 75),
#  ('法務部', 75),
#  ('投票', 75),
#  ('地震', 75),
#  ('高中', 74),
#  ('條', 74),
#  ('手機', 74),
#  ('質地', 74),
#  ('台中', 74),
#  ('導演', 74),
#  ('路', 74),
#  ('決議', 74),
#  ('周杰倫', 74),
#  ('銀行', 73),
#  ('心', 73),
#  ('國稅局', 73),
#  ('波波', 73),
#  ('故事', 73),
#  ('媽媽', 72),
#  ('草', 72),
#  ('方案', 72),
#  ('目的', 72),
#  ('地院', 72),
#  ('火力', 71),
#  ('外資', 71),
#  ('機構', 71),
#  ('哪裡', 71),
#  ('家園', 71),
#  ('觀眾', 71),
#  ('家長', 71),
#  ('主管', 71),
#  ('餐廳', 71),
#  ('許芷瑜', 71),
#  ('股市', 70),
#  ('林楚茵', 70),
#  ('結構', 70),
#  ('會議', 69),
#  ('安全', 69),
#  ('辦公室', 69),
#  ('呂政璋', 69),
#  ('後面', 69),
#  ('中央社', 69),
#  ('王浩宇', 69),
#  ('時期', 69),
#  ('貼文', 68),
#  ('醫院', 68),
#  ('自由', 68),
#  ('汽車', 68),
#  ('公民', 68),
#  ('顏色', 68),
#  ('人類', 68),
#  ('程序', 67),
#  ('學歷', 67),
#  ('地位', 67),
#  ('首長', 67),
#  ('巨蛋', 67),
#  ('有', 67),
#  ('照片', 67),
#  ('業務', 67),
#  ('工程師', 67),
#  ('牙醫', 67),
#  ('期限', 67),
#  ('郭雅慧', 67),
#  ('品牌', 67),
#  ('空間', 67),
#  ('施俊吉', 67),
#  ('股票', 66),
#  ('共和國', 66),
#  ('颱風天', 66),
#  ('說', 66),
#  ('王婉諭', 66),
#  ('推文', 66),
#  ('男生', 66),
#  ('傅崐萁', 66),
#  ('區域', 66),
#  ('年齡', 66),
#  ('檢察署', 66),
#  ('少子化', 66),
#  ('陳時中', 65),
#  ('市府', 65),
#  ('菜', 65),
#  ('民進黨團', 65),
#  ('北京', 65),
#  ('家庭', 65),
#  ('心情', 65),
#  ('小弟', 64),
#  ('垃圾', 64),
#  ('民意', 64),
#  ('啤酒', 64),
#  ('頻道', 64),
#  ('人才', 64),
#  ('徐巧芯', 63),
#  ('治安', 63),
#  ('那邊', 63),
#  ('很多', 63),
#  ('距離', 63),
#  ('週刊', 62),
#  ('外媒', 62),
#  ('水準', 62),
#  ('發電', 62),
#  ('媽', 62),
#  ('高院', 62),
#  ('各界', 62),
#  ('翁曉玲', 62),
#  ('人力', 62),
#  ('發文數', 62),
#  ('味道', 61),
#  ('經驗', 61),
#  ('廠', 61),
#  ('店家', 61),
#  ('人生', 61),
#  ('核電廠', 61),
#  ('皮膚', 61),
#  ('所得', 61),
#  ('內部', 60),
#  ('海關', 60),
#  ('北韓', 60),
#  ('大部分', 60),
#  ('板', 60),
#  ('黑道', 60),
#  ('女', 60),
#  ('吳崢', 60),
#  ('主義', 60),
#  ('有錢人', 60),
#  ('黃智賢', 60),
#  ('核能', 60),
#  ('台男', 59),
#  ('看板', 59),
#  ('雲豹', 59),
#  ('消費者', 59),
#  ('年紀', 59),
#  ('全民', 59),
#  ('女人', 59),
#  ('公務員', 59),
#  ('模式', 59),
#  ('旅客', 59),
#  ('學院', 59),
#  ('朱鳳蓮', 59),
#  ('風力', 59),
#  ('黃仁勳', 58),
#  ('數字', 58),
#  ('機車', 58),
#  ('疫情', 58),
#  ('素質', 58),
#  ('同志', 58),
#  ('商品', 58),
#  ('事業', 58),
#  ('新加坡', 58),
#  ('基金會', 58),
#  ('黨部', 58),
#  ('王', 58),
#  ('軍人', 58),
#  ('片', 58),
#  ('機制', 58),
#  ('體制', 57),
#  ('外電', 57),
#  ('范斯', 57),
#  ('死刑', 57),
#  ('蘋果', 57),
#  ('案子', 57),
#  ('書', 57),
#  ('戰線', 57),
#  ('工廠', 57),
#  ('歐美', 57),
#  ('手段', 57),
#  ('實力', 57),
#  ('肌膚', 57),
#  ('人們', 57),
#  ('男人', 57),
#  ('這裡', 56),
#  ('腦袋', 56),
#  ('處', 56),
#  ('央行', 56),
#  ('公投', 56),
#  ('半導體', 56),
#  ('立院', 56),
#  ('投資', 56),
#  ('動作', 56),
#  ('國人', 56),
#  ('局勢', 56),
#  ('國台辦', 55),
#  ('交易', 55),
#  ('情緒', 55),
#  ('提案', 55),
#  ('凌濤', 55),
#  ('詐騙', 55),
#  ('陳揮文', 55),
#  ('菩薩', 55),
#  ('士兵', 55),
#  ('電費', 55),
#  ('反應', 55),
#  ('風電', 55),
#  ('任內', 55),
#  ('老頭', 54),
#  ('歐洲', 54),
#  ('運氣', 54),
#  ('自刪', 54),
#  ('陳佩琪', 54),
#  ('服務', 54),
#  ('彭振聲', 54),
#  ('網紅', 53),
#  ('它們', 53),
#  ('設施', 53),
#  ('電廠', 53),
#  ('cx', 53),
#  ('陣營', 53),
#  ('智商', 53),
#  ('家屬', 53),
#  ('輝達', 53),
#  ('台海', 52),
#  ('外交', 52),
#  ('捷運', 52),
#  ('同事', 52),
#  ('X', 52),
#  ('方法', 52),
#  ('任期', 52),
#  ('路透社', 52),
#  ('阿共', 52),
#  ('塔綠班', 52),
#  ('網路', 52),
#  ('農業部', 52),
#  ('點', 52),
#  ('全球', 52),
#  ('有的', 52),
#  ('AI', 51),
#  ('論文', 51),
#  ('研究', 51),
#  ('設備', 51),
#  ('發言人', 51),
#  ('國發會', 51),
#  ('電力', 51),
#  ('國內', 51),
#  ('畫面', 51),
#  ('補助', 51),
#  ('金管會', 51),
#  ('龐培歐', 51),
#  ('技嘉', 51),
#  ('語言', 51),
#  ('檢廉', 51),
#  ('水', 51),
#  ('簡舒培', 51),
#  ('法國', 51),
#  ('配偶', 50),
#  ('城市', 50),
#  ('論述', 50),
#  ('網站', 50),
#  ('左派', 50),
#  ('波頓', 50),
#  ('麥當勞', 50),
#  ('黑熊', 50),
#  ('路徑', 50),
#  ('立陶宛', 50),
#  ('英國', 50),
#  ('方向', 50),
#  ('吳宗憲', 49),
#  ('精神', 49),
#  ('因素', 49),
#  ('歐盟', 49),
#  ('腦子', 49),
#  ('陳', 49),
#  ('良率', 49),
#  ('名單', 49),
#  ('陳玉珍', 49),
#  ('董事長', 49),
#  ('工資', 49),
#  ('電視台', 49),
#  ('顏', 49),
#  ('智庫', 49),
#  ('角色', 49),
#  ('人人', 48),
#  ('總統府', 48),
#  ('陳之漢', 48),
#  ('保護費', 48),
#  ('應曉薇', 48),
#  ('勞動部', 48),
#  ('地點', 48),
#  ('總預算', 48),
#  ('產值', 48),
#  ('製造業', 47),
#  ('老婆', 47),
#  ('背後', 47),
#  ('會', 47),
#  ('投資人', 47),
#  ('關稅', 47),
#  ('電商', 47),
#  ('元', 47),
#  ('美方', 47),
#  ('利率', 47),
#  ('台北地院', 47),
#  ('道路', 47),
#  ('李多慧', 46),
#  ('林國成', 46),
#  ('措施', 46),
#  ('負擔', 46),
#  ('軍方', 46),
#  ('發言', 46),
#  ('政黑', 46),
#  ('漲幅', 46),
#  ('訊息', 46),
#  ('早餐店', 46),
#  ('噪音', 46),
#  ('幕僚', 46),
#  ('外勞', 46),
#  ('競爭', 46),
#  ('發電量', 46),
#  ('射程', 46),
#  ('綠委', 46),
#  ('交通部', 46),
#  ('小姐', 46),
#  ('老百姓', 46),
#  ('山區', 46),
#  ('護照', 46),
#  ('評價', 45),
#  ('衛福部', 45),
#  ('藍營', 45),
#  ('難度', 45),
#  ('歌迷', 45),
#  ('台派', 45),
#  ('月薪', 45),
#  ('成績', 45),
#  ('選手', 45),
#  ('車子', 45),
#  ('王義川', 45),
#  ('GDP', 45),
#  ('損失', 45),
#  ('災情', 45),
#  ('總額', 45),
#  ('雨', 45),
#  ('效率', 45),
#  ('南檢', 45),
#  ('吳忠達', 45),
#  ('對手', 45),
#  ('票房', 45),
#  ('北捷', 45),
#  ('吳怡萱', 45),
#  ('電視', 45),
#  ('島', 44),
#  ('聯合報', 44),
#  ('台獨', 44),
#  ('情形', 44),
#  ('部', 44),
#  ('槍', 44),
#  ('法條', 44),
#  ('共', 44),
#  ('路樹', 44),
#  ('意義', 44),
#  ('小組', 44),
#  ('好處', 44),
#  ('臺灣', 44),
#  ('體系', 44),
#  ('背景', 44),
#  ('代', 44),
#  ('何佩珊', 44),
#  ('林右昌', 44),
#  ('機組', 43),
#  ('聲明', 43),
#  ('項目', 43),
#  ('ETF', 43),
#  ('責任', 43),
#  ('張啟楷', 43),
#  ('出口', 43),
#  ('草案', 43),
#  ('香港人', 43),
#  ('號碼', 43),
#  ('藍', 43),
#  ('舉', 43),
#  ('球迷', 43),
#  ('黃崇仁', 43),
#  ('財富', 43),
#  ('差異', 43),
#  ('記者會', 43),
#  ('所有人', 43),
#  ('賴士葆', 42),
#  ('父親', 42),
#  ('合約', 42),
#  ('理念', 42),
#  ('國外', 42),
#  ('暴風圈', 42),
#  ('生命', 42),
#  ('共識', 42),
#  ('光電', 42),
#  ('台南', 42),
#  ('關鍵', 42),
#  ('要求', 42),
#  ('意見', 42),
#  ('職權', 42),
#  ('作家', 42),
#  ('賀', 42),
#  ('軍演', 42),
#  ('侯友宜', 42),
#  ('功能', 42),
#  ('樹', 42),
#  ('D', 42),
#  ('產能', 42),
#  ('對象', 42),
#  ('腳', 42),
#  ('鬼', 42),
#  ('風向', 41),
#  ('插槽', 41),
#  ('吳靜怡', 41),
#  ('嘴', 41),
#  ('製程', 41),
#  ('蕭美琴', 41),
#  ('供應鏈', 41),
#  ('運動', 41),
#  ('網', 41),
#  ('包裝', 41),
#  ('林智群', 41),
#  ('租金', 41),
#  ('消費', 41),
#  ('檢警', 41),
#  ('越南', 41),
#  ('行政院長', 41),
#  ('佛教', 41),
#  ('院長', 41),
#  ('弊案', 41),
#  ('華為', 41),
#  ('法規', 41),
#  ('她們', 41),
#  ('名嘴', 41),
#  ('陸配', 41),
#  ('可能性', 41),
#  ('陳昭姿', 40),
#  ('印象', 40),
#  ('認知', 40),
#  ('配息', 40),
#  ('門票', 40),
#  ('共犯', 40),
#  ('性別', 40),
#  ('件', 40),
#  ('遊戲', 40),
#  ('證人', 40),
#  ('愛莉莎莎', 40),
#  ('大眾', 40),
#  ('李彥秀', 40),
#  ('佛', 40),
#  ('意外', 40),
#  ('朝野', 40),
#  ('小說', 40),
#  ('產量', 40),
#  ('努力', 40),
#  ('市民', 40),
#  ('帳號', 40),
#  ('環流', 40),
#  ('生育率', 40),
#  ('部長', 40),
#  ('筆者', 40),
#  ('工程', 40),
#  ('眼睛', 40),
#  ('思想', 39),
#  ('男性', 39),
#  ('蘭札', 39),
#  ('雞蛋', 39),
#  ('定義', 39),
#  ('效應', 39),
#  ('供應', 39),
#  ('德國', 39),
#  ('船', 39),
#  ('路透', 39),
#  ('季風', 39),
#  ('看法', 39),
#  ('變化', 39),
#  ('黑人', 39),
#  ('協議', 39),
#  ('電腦', 39),
#  ('女子', 39),
#  ('優勢', 39),
#  ('商人', 39),
#  ('機', 39),
#  ('蕭旭岑', 38),
#  ('患者', 38),
#  ('嘴巴', 38),
#  ('沈政男', 38),
#  ('澤倫斯基', 38),
#  ('美股', 38),
#  ('容量', 38),
#  ('身分', 38),
#  ('季', 38),
#  ('曾文生', 38),
#  ('留言', 38),
#  ('黨員', 38),
#  ('通膨', 38),
#  ('獲利', 38),
#  ('量', 38),
#  ('差別', 38),
#  ('項', 38),
#  ('小時', 38),
#  ('邱泰源', 38),
#  ('華人', 38),
#  ('游淑慧', 38),
#  ('美債', 38),
#  ('小妹', 38),
#  ('澳洲', 38),
#  ('盧秀燕', 38),
#  ('夫妻', 38),
#  ('台積', 38),
#  ('英特爾', 38),
#  ('長輩', 38),
#  ('觀念', 37),
#  ('發票', 37),
#  ('公車', 37),
#  ('權利', 37),
#  ('雨量', 37),
#  ('外商', 37),
#  ('答案', 37),
#  ('命', 37),
#  ('分析師', 37),
#  ('名字', 37),
#  ('觀光', 37),
#  ('謝金河', 37),
#  ('我方', 37),
#  ('強度', 37),
#  ('川粉', 37),
#  ('俄國', 37),
#  ('策略', 37),
#  ('特稿', 37),
#  ('張', 37),
#  ('奧納德', 37),
#  ('款', 37),
#  ('高中生', 37),
#  ('選擇', 36),
#  ('流程', 36),
#  ('羅致政', 36),
#  ('日期', 36),
#  ('陳男', 36),
#  ('陣子', 36),
#  ('少年', 36),
#  ('粉紅', 36),
#  ('馬郁雯', 36),
#  ('資產', 36),
#  ('中方', 36),
#  ('音樂', 36),
#  ('京華城案', 36),
#  ('貿易', 36),
#  ('裁定書', 36),
#  ('手法', 36),
#  ('蛋', 36),
#  ('權', 36),
#  ('熊', 36),
#  ...]

# %%
aop_df.set_index("date").loc["2024/10/25"].reset_index()
# Out:
#                          date                    id    a   o       p    t
# 0     2024-10-25 11:52:49.141  jw1bDJMBx63wKxznie5G   波波   知  4.5054  NAT
# 1     2024-10-25 11:52:49.141  jw1bDJMBx63wKxznie5G   規則  打通  3.9600  NEG
# 2     2024-10-25 11:52:49.141  jw1bDJMBx63wKxznie5G   女兒  需要  5.4476  NAT
# 3     2024-10-25 11:52:49.141  jw1bDJMBx63wKxznie5G   資格  不符  3.8000  NEG
# 4     2024-10-25 11:52:49.141  jw1bDJMBx63wKxznie5G   對象  包含  5.1192  NAT
# ...                       ...                   ...  ...  ..     ...  ...
# 15992 2024-10-25 08:33:44.000  T06oEJMBuFMZnsg338W5  影響力   大  4.7196  NAT
# 15993 2024-10-25 08:33:44.000  T06oEJMBuFMZnsg338W5   地位   高  4.9450  NAT
# 15994 2024-10-25 14:05:56.829  fw3_DpMBx63wKxznn_6D    她  住在  5.0400  NAT
# 15995 2024-10-25 14:05:56.829  fw3_DpMBx63wKxznn_6D    人  住在  5.0400  NAT
# 15996 2024-10-25 14:05:56.829  fw3_DpMBx63wKxznn_6D   爬文   寫  5.7688  NAT
#
# [15997 rows x 6 columns]

# %%
aop_df.groupby("a")

# %%
[
            {"source": "情感", "target": k, "value": v["p"].sum()}
            for k, v in aop_df.groupby("a")
        ]
# Out:
# [{'source': '情感', 'target': '', 'value': np.float64(202.7584)},
#  {'source': '情感',
#   'target': '\n\nwww.facebook.com',
#   'value': np.float64(4.965000000000001)},
#  {'source': '情感', 'target': '\n#', 'value': np.float64(11.84)},
#  {'source': '情感', 'target': '\n10%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '\n10/25', 'value': np.float64(5.1412)},
#  {'source': '情感', 'target': '\n15%\n', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '\n26%', 'value': np.float64(4.3)},
#  {'source': '情感', 'target': '\n29%', 'value': np.float64(6.0)},
#  {'source': '情感', 'target': '\n38%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '\n39%\n', 'value': np.float64(5.8)},
#  {'source': '情感', 'target': '\n4%', 'value': np.float64(4.4)},
#  {'source': '情感', 'target': '\n40%', 'value': np.float64(3.2)},
#  {'source': '情感', 'target': '\n40%\n', 'value': np.float64(3.4)},
#  {'source': '情感', 'target': '\n48%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '\n62%\n', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '\n80%', 'value': np.float64(3.3599999999999994)},
#  {'source': '情感', 'target': '\n9%', 'value': np.float64(3.9427999999999996)},
#  {'source': '情感', 'target': '\nB207', 'value': np.float64(3.16)},
#  {'source': '情感', 'target': '\nB58', 'value': np.float64(6.227000000000001)},
#  {'source': '情感', 'target': '\nM.2', 'value': np.float64(6.1592)},
#  {'source': '情感', 'target': '\nOra2', 'value': np.float64(5.7504)},
#  {'source': '情感', 'target': '\nToyota', 'value': np.float64(5.4984)},
#  {'source': '情感', 'target': '\nYoung', 'value': np.float64(4.474)},
#  {'source': '情感',
#   'target': '\nevent-guerlain.com.tw',
#   'value': np.float64(13.546199999999999)},
#  {'source': '情感',
#   'target': '\nevent-guerlain.com.tw\n',
#   'value': np.float64(7.3)},
#  {'source': '情感', 'target': '\nfinance', 'value': np.float64(3.1108)},
#  {'source': '情感',
#   'target': '\nforum.gamer.com.tw\n',
#   'value': np.float64(4.455)},
#  {'source': '情感',
#   'target': '\nfunlife',
#   'value': np.float64(3.3200000000000003)},
#  {'source': '情感',
#   'target': '\ngame.ettoday.net',
#   'value': np.float64(5.220000000000001)},
#  {'source': '情感', 'target': '\nmomo.dm', 'value': np.float64(6.8)},
#  {'source': '情感', 'target': '\nmomo.dm\n▂▂▂▂▂▂2', 'value': np.float64(12.8)},
#  {'source': '情感',
#   'target': '\nnews.tvbs.com.tw',
#   'value': np.float64(11.0948)},
#  {'source': '情感', 'target': '\nreurl.cc', 'value': np.float64(5.2866)},
#  {'source': '情感', 'target': '\ntw.msi.com', 'value': np.float64(4.0778)},
#  {'source': '情感', 'target': '\ntw.news.yahoo.com', 'value': np.float64(6.189)},
#  {'source': '情感', 'target': '\ntw.nextapple.com\n', 'value': np.float64(3.0)},
#  {'source': '情感', 'target': '\nudn.com', 'value': np.float64(4.1894)},
#  {'source': '情感', 'target': '\nudn.com\n', 'value': np.float64(7.6)},
#  {'source': '情感',
#   'target': '\nwalkbell-awards.com',
#   'value': np.float64(4.5600000000000005)},
#  {'source': '情感', 'target': '\nwww.benq.com', 'value': np.float64(4.7858)},
#  {'source': '情感',
#   'target': '\nwww.chinatimes.com',
#   'value': np.float64(4.3988)},
#  {'source': '情感',
#   'target': '\nwww.cht.com.tw\n',
#   'value': np.float64(4.631399999999999)},
#  {'source': '情感',
#   'target': '\nwww.clarins.com.tw\n1',
#   'value': np.float64(4.753400000000001)},
#  {'source': '情感',
#   'target': '\nwww.cna.com.tw',
#   'value': np.float64(12.242799999999999)},
#  {'source': '情感',
#   'target': '\nwww.cna.com.tw\n',
#   'value': np.float64(13.6058)},
#  {'source': '情感', 'target': '\nwww.facebook.com', 'value': np.float64(5.8)},
#  {'source': '情感', 'target': '\nwww.facebook.com\n', 'value': np.float64(6.0)},
#  {'source': '情感',
#   'target': '\nwww.global-shiseido.com.tw\n9️⃣',
#   'value': np.float64(5.0200000000000005)},
#  {'source': '情感',
#   'target': '\nwww.knews.com.tw\n',
#   'value': np.float64(5.446)},
#  {'source': '情感',
#   'target': '\nwww.lancome.com.tw\n',
#   'value': np.float64(6.2)},
#  {'source': '情感', 'target': '\nwww.pourquoi.tw', 'value': np.float64(4.1226)},
#  {'source': '情感', 'target': '\nwww.prsa.org.tw\n', 'value': np.float64(5.495)},
#  {'source': '情感',
#   'target': '\nwww.shuuemura.com.tw\n1',
#   'value': np.float64(6.720000000000001)},
#  {'source': '情感', 'target': '\nwww.threads.net', 'value': np.float64(10.0)},
#  {'source': '情感',
#   'target': '\nwww.youtube.com\n|\nQ',
#   'value': np.float64(3.5150000000000006)},
#  {'source': '情感', 'target': '\nynews.page.link', 'value': np.float64(4.5)},
#  {'source': '情感', 'target': '\n凱恩', 'value': np.float64(5.029999999999999)},
#  {'source': '情感', 'target': '\n圖', 'value': np.float64(4.046200000000001)},
#  {'source': '情感', 'target': '\n布林克維修特', 'value': np.float64(6.6)},
#  {'source': '情感', 'target': '\n炎', 'value': np.float64(5.0404)},
#  {'source': '情感', 'target': '\n眼', 'value': np.float64(4.728199999999999)},
#  {'source': '情感', 'target': '\n粉質', 'value': np.float64(5.68)},
#  {'source': '情感', 'target': '\n綠圾', 'value': np.float64(2.6968)},
#  {'source': '情感', 'target': '\n腦粉', 'value': np.float64(4.904599999999999)},
#  {'source': '情感', 'target': '\n達拉班', 'value': np.float64(5.6034)},
#  {'source': '情感', 'target': '\n韓系', 'value': np.float64(4.55)},
#  {'source': '情感', 'target': '\n馬茂', 'value': np.float64(6.9032)},
#  {'source': '情感', 'target': '\n駱奕涵', 'value': np.float64(5.76)},
#  {'source': '情感', 'target': '#', 'value': np.float64(34.4344)},
#  {'source': '情感', 'target': '#07', 'value': np.float64(3.8299999999999996)},
#  {'source': '情感', 'target': '#E02', 'value': np.float64(4.54)},
#  {'source': '情感', 'target': '#W002', 'value': np.float64(4.7604)},
#  {'source': '情感', 'target': '$120', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '**\n', 'value': np.float64(4.904599999999999)},
#  {'source': '情感', 'target': '+9', 'value': np.float64(7.0)},
#  {'source': '情感', 'target': '.aspx', 'value': np.float64(14.4406)},
#  {'source': '情感', 'target': '.jpeg', 'value': np.float64(5.618399999999999)},
#  {'source': '情感', 'target': '.jpg', 'value': np.float64(3.7600000000000002)},
#  {'source': '情感', 'target': '.net', 'value': np.float64(6.6)},
#  {'source': '情感', 'target': '0', 'value': np.float64(20.8604)},
#  {'source': '情感', 'target': '0.0', 'value': np.float64(11.0704)},
#  {'source': '情感', 'target': '0.06%', 'value': np.float64(4.3464)},
#  {'source': '情感', 'target': '0.0Sent', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': '0.1%', 'value': np.float64(4.7604)},
#  {'source': '情感', 'target': '0.37', 'value': np.float64(3.9599999999999995)},
#  {'source': '情感', 'target': '0.439', 'value': np.float64(4.573400000000001)},
#  {'source': '情感', 'target': '0.48%', 'value': np.float64(7.2012)},
#  {'source': '情感', 'target': '0.5', 'value': np.float64(3.4800000000000004)},
#  {'source': '情感', 'target': '0.5%', 'value': np.float64(10.8)},
#  {'source': '情感', 'target': '0.7', 'value': np.float64(4.5214)},
#  {'source': '情感', 'target': '0.7%', 'value': np.float64(4.853199999999999)},
#  {'source': '情感', 'target': '00', 'value': np.float64(3.4200000000000004)},
#  {'source': '情感', 'target': '003', 'value': np.float64(4.1894)},
#  {'source': '情感', 'target': '0043', 'value': np.float64(8.713)},
#  {'source': '情感', 'target': '0050', 'value': np.float64(35.897000000000006)},
#  {'source': '情感', 'target': '0056', 'value': np.float64(11.6)},
#  {'source': '情感', 'target': '006208', 'value': np.float64(29.1068)},
#  {'source': '情感', 'target': '007', 'value': np.float64(4.3988)},
#  {'source': '情感', 'target': '00713', 'value': np.float64(21.078000000000003)},
#  {'source': '情感', 'target': '00757', 'value': np.float64(4.58)},
#  {'source': '情感', 'target': '00887', 'value': np.float64(12.2866)},
#  {'source': '情感', 'target': '00895', 'value': np.float64(9.1574)},
#  {'source': '情感', 'target': '00932', 'value': np.float64(6.980000000000001)},
#  {'source': '情感', 'target': '00940', 'value': np.float64(54.63039999999999)},
#  {'source': '情感', 'target': '00953B', 'value': np.float64(19.735000000000003)},
#  {'source': '情感', 'target': '00963', 'value': np.float64(6.6678)},
#  {'source': '情感', 'target': '00964', 'value': np.float64(4.7858)},
#  {'source': '情感', 'target': '01', 'value': np.float64(9.862399999999997)},
#  {'source': '情感', 'target': '01.com', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': '02', 'value': np.float64(9.9538)},
#  {'source': '情感', 'target': '02日', 'value': np.float64(4.728199999999999)},
#  {'source': '情感', 'target': '03', 'value': np.float64(3.4)},
#  {'source': '情感', 'target': '032024/10/26', 'value': np.float64(4.6414)},
#  {'source': '情感', 'target': '055', 'value': np.float64(3.3199999999999994)},
#  {'source': '情感', 'target': '056', 'value': np.float64(5.2)},
#  {'source': '情感', 'target': '08', 'value': np.float64(6.1739999999999995)},
#  {'source': '情感', 'target': '0GA2PROM21', 'value': np.float64(3.6)},
#  {'source': '情感', 'target': '0元', 'value': np.float64(4.7036)},
#  {'source': '情感', 'target': '0元購', 'value': np.float64(9.7224)},
#  {'source': '情感', 'target': '0級生', 'value': np.float64(4.3738)},
#  {'source': '情感', 'target': '1', 'value': np.float64(109.33839999999998)},
#  {'source': '情感', 'target': '1%', 'value': np.float64(33.5156)},
#  {'source': '情感', 'target': '1.', 'value': np.float64(5.0653999999999995)},
#  {'source': '情感', 'target': '1.1%', 'value': np.float64(10.8)},
#  {'source': '情感',
#   'target': '1.163.72.15910/2219:42',
#   'value': np.float64(5.771199999999999)},
#  {'source': '情感', 'target': '1.165.16.175', 'value': np.float64(8.7456)},
#  {'source': '情感',
#   'target': '1.169.116.5710/2101:16',
#   'value': np.float64(4.364)},
#  {'source': '情感',
#   'target': '1.171.50.20511/0818:51',
#   'value': np.float64(4.3732)},
#  {'source': '情感', 'target': '1.3', 'value': np.float64(4.592599999999999)},
#  {'source': '情感', 'target': '1.3%', 'value': np.float64(12.2)},
#  {'source': '情感', 'target': '1.34.90.14511/0919:57', 'value': np.float64(5.0)},
#  {'source': '情感',
#   'target': '1.34.90.14511/0919:57:REALJOINGO:',
#   'value': np.float64(5.0)},
#  {'source': '情感', 'target': '1.43%', 'value': np.float64(7.2012)},
#  {'source': '情感', 'target': '1.8%', 'value': np.float64(5.0712)},
#  {'source': '情感', 'target': '1.9%', 'value': np.float64(5.4)},
#  {'source': '情感', 'target': '1.CNN', 'value': np.float64(4.6624)},
#  {'source': '情感', 'target': '1/13', 'value': np.float64(51.1014)},
#  {'source': '情感', 'target': '1/25', 'value': np.float64(4.779999999999999)},
#  {'source': '情感', 'target': '1/3', 'value': np.float64(2.2)},
#  {'source': '情感', 'target': '1/6', 'value': np.float64(1.2)},
#  {'source': '情感', 'target': '10', 'value': np.float64(32.668)},
#  {'source': '情感', 'target': '10%', 'value': np.float64(33.574200000000005)},
#  {'source': '情感', 'target': '10.0', 'value': np.float64(6.189)},
#  {'source': '情感', 'target': '10.4%', 'value': np.float64(13.091999999999999)},
#  {'source': '情感', 'target': '10/01', 'value': np.float64(4.3862)},
#  {'source': '情感', 'target': '10/1', 'value': np.float64(7.646600000000001)},
#  {'source': '情感', 'target': '10/10', 'value': np.float64(5.6034)},
#  {'source': '情感', 'target': '10/15', 'value': np.float64(9.18)},
#  {'source': '情感', 'target': '10/17', 'value': np.float64(5.6034)},
#  {'source': '情感', 'target': '10/18', 'value': np.float64(4.455)},
#  {'source': '情感', 'target': '10/19', 'value': np.float64(5.2116)},
#  {'source': '情感', 'target': '10/20', 'value': np.float64(3.16)},
#  {'source': '情感', 'target': '10/2101:23', 'value': np.float64(5.6034)},
#  {'source': '情感', 'target': '10/2118:00', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': '10/22', 'value': np.float64(10.76)},
#  {'source': '情感', 'target': '10/23', 'value': np.float64(4.260599999999999)},
#  {'source': '情感', 'target': '10/28', 'value': np.float64(5.0076)},
#  {'source': '情感', 'target': '10/29', 'value': np.float64(3.78)},
#  {'source': '情感', 'target': '10/7', 'value': np.float64(5.9)},
#  {'source': '情感', 'target': '10/9', 'value': np.float64(5.0)},
#  {'source': '情感', 'target': '100', 'value': np.float64(8.0504)},
#  {'source': '情感', 'target': '100%', 'value': np.float64(23.477400000000003)},
#  {'source': '情感', 'target': '1000', 'value': np.float64(4.4799999999999995)},
#  {'source': '情感', 'target': '1000萬', 'value': np.float64(4.985)},
#  {'source': '情感',
#   'target': '100200萬',
#   'value': np.float64(3.1919999999999997)},
#  {'source': '情感', 'target': '100年', 'value': np.float64(4.8284)},
#  {'source': '情感', 'target': '100萬', 'value': np.float64(10.143199999999998)},
#  {'source': '情感', 'target': '100趴', 'value': np.float64(4.030799999999999)},
#  {'source': '情感', 'target': '101', 'value': np.float64(26.8422)},
#  {'source': '情感', 'target': '1010', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': '102024/11/06', 'value': np.float64(4.6)},
#  {'source': '情感', 'target': '1028', 'value': np.float64(3.2421999999999995)},
#  {'source': '情感', 'target': '106', 'value': np.float64(11.040000000000001)},
#  {'source': '情感', 'target': '108年度', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': '109億', 'value': np.float64(5.135)},
#  {'source': '情感', 'target': '109旅', 'value': np.float64(5.040799999999999)},
#  {'source': '情感', 'target': '10:19', 'value': np.float64(4.857)},
#  {'source': '情感', 'target': '10億', 'value': np.float64(3.8125999999999998)},
#  {'source': '情感', 'target': '10年', 'value': np.float64(8.810000000000002)},
#  {'source': '情感', 'target': '10時', 'value': np.float64(12.120000000000001)},
#  {'source': '情感', 'target': '10月', 'value': np.float64(15.302000000000001)},
#  {'source': '情感', 'target': '10萬', 'value': np.float64(7.3538)},
#  {'source': '情感', 'target': '11', 'value': np.float64(33.7478)},
#  {'source': '情感', 'target': '11%', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': '11.5', 'value': np.float64(6.189)},
#  {'source': '情感', 'target': '11.5%', 'value': np.float64(7.140000000000001)},
#  {'source': '情感', 'target': '11/13', 'value': np.float64(4.888599999999999)},
#  {'source': '情感', 'target': '11/3', 'value': np.float64(11.6578)},
#  {'source': '情感', 'target': '11/4', 'value': np.float64(8.5738)},
#  {'source': '情感', 'target': '11/5', 'value': np.float64(5.0152)},
#  {'source': '情感', 'target': '11/6', 'value': np.float64(17.3152)},
#  {'source': '情感', 'target': '11/7', 'value': np.float64(3.56)},
#  {'source': '情感', 'target': '1105', 'value': np.float64(2.8)},
#  {'source': '情感', 'target': '110年', 'value': np.float64(6.4536)},
#  {'source': '情感', 'target': '110萬', 'value': np.float64(4.088800000000001)},
#  {'source': '情感', 'target': '111', 'value': np.float64(14.44)},
#  {'source': '情感',
#   'target': '111.81.171.15711/0823:36',
#   'value': np.float64(5.2376000000000005)},
#  {'source': '情感', 'target': '1111', 'value': np.float64(14.702200000000001)},
#  {'source': '情感', 'target': '111年度', 'value': np.float64(4.4556000000000004)},
#  {'source': '情感', 'target': '1120', 'value': np.float64(18.584999999999997)},
#  {'source': '情感', 'target': '112學年度', 'value': np.float64(4.5666)},
#  {'source': '情感', 'target': '112年度', 'value': np.float64(8.4136)},
#  {'source': '情感', 'target': '1131025', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '1131108', 'value': np.float64(3.4)},
#  {'source': '情感', 'target': '113年', 'value': np.float64(5.1334)},
#  {'source': '情感', 'target': '113年度', 'value': np.float64(12.8688)},
#  {'source': '情感', 'target': '114.137.243.188', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '114.32.68.153', 'value': np.float64(3.8)},
#  {'source': '情感',
#   'target': '114.40.140.9610/2206:13',
#   'value': np.float64(5.0076)},
#  {'source': '情感', 'target': '114年度', 'value': np.float64(6.0)},
#  {'source': '情感', 'target': '1152萬', 'value': np.float64(8.728)},
#  {'source': '情感', 'target': '116', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '116.241.252.70', 'value': np.float64(6.0144)},
#  {'source': '情感', 'target': '119', 'value': np.float64(4.5089999999999995)},
#  {'source': '情感', 'target': '11:08', 'value': np.float64(5.4444)},
#  {'source': '情感', 'target': '11時', 'value': np.float64(4.579400000000001)},
#  {'source': '情感', 'target': '11月', 'value': np.float64(6.1048)},
#  {'source': '情感', 'target': '11萬', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '11點', 'value': np.float64(5.433)},
#  {'source': '情感', 'target': '12', 'value': np.float64(10.18)},
#  {'source': '情感', 'target': '12%', 'value': np.float64(20.8)},
#  {'source': '情感', 'target': '12.3', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '12.3%', 'value': np.float64(21.6)},
#  {'source': '情感', 'target': '12.6', 'value': np.float64(8.776599999999998)},
#  {'source': '情感', 'target': '12.8%', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '12/25', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': '12/29', 'value': np.float64(6.731199999999999)},
#  {'source': '情感', 'target': '12/31', 'value': np.float64(5.917800000000001)},
#  {'source': '情感', 'target': '120', 'value': np.float64(5.08)},
#  {'source': '情感', 'target': '120%', 'value': np.float64(5.8)},
#  {'source': '情感', 'target': '123456', 'value': np.float64(3.5)},
#  {'source': '情感', 'target': '1265億', 'value': np.float64(4.9528)},
#  {'source': '情感', 'target': '1265多億', 'value': np.float64(4.6334)},
#  {'source': '情感', 'target': '12V', 'value': np.float64(18.5364)},
#  {'source': '情感', 'target': '12學年度', 'value': np.float64(13.6998)},
#  {'source': '情感', 'target': '12成', 'value': np.float64(1.2)},
#  {'source': '情感', 'target': '12日', 'value': np.float64(3.8892)},
#  {'source': '情感', 'target': '12時', 'value': np.float64(15.229199999999999)},
#  {'source': '情感', 'target': '12月', 'value': np.float64(7.0)},
#  {'source': '情感', 'target': '12點', 'value': np.float64(6.66)},
#  {'source': '情感', 'target': '13', 'value': np.float64(17.922800000000002)},
#  {'source': '情感', 'target': '13%', 'value': np.float64(25.1894)},
#  {'source': '情感', 'target': '13.1%', 'value': np.float64(6.0)},
#  {'source': '情感', 'target': '13.6%', 'value': np.float64(13.8)},
#  {'source': '情感', 'target': '13.7%', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '13.8', 'value': np.float64(6.189)},
#  {'source': '情感', 'target': '13.9%', 'value': np.float64(22.6128)},
#  {'source': '情感',
#   'target': '131662880',
#   'value': np.float64(6.5200000000000005)},
#  {'source': '情感', 'target': '132', 'value': np.float64(3.8101999999999996)},
#  {'source': '情感', 'target': '1364938.1月', 'value': np.float64(5.1112)},
#  {'source': '情感', 'target': '1364939.1月', 'value': np.float64(5.1112)},
#  {'source': '情感', 'target': '139線', 'value': np.float64(5.040799999999999)},
#  {'source': '情感', 'target': '13時', 'value': np.float64(5.994400000000001)},
#  {'source': '情感', 'target': '14', 'value': np.float64(4.2812)},
#  {'source': '情感', 'target': '14%', 'value': np.float64(34.8348)},
#  {'source': '情感', 'target': '14.0%', 'value': np.float64(4.6624)},
#  {'source': '情感', 'target': '14.16%', 'value': np.float64(12.568200000000001)},
#  {'source': '情感', 'target': '14.4%', 'value': np.float64(3.6)},
#  {'source': '情感', 'target': '14.49%', 'value': np.float64(9.930000000000001)},
#  {'source': '情感', 'target': '14.5%', 'value': np.float64(4.3504)},
#  {'source': '情感', 'target': '14.8%', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '140', 'value': np.float64(4.54)},
#  {'source': '情感',
#   'target': '1421441102',
#   'value': np.float64(3.3299999999999996)},
#  {'source': '情感', 'target': '1442', 'value': np.float64(5.7126)},
#  {'source': '情感', 'target': '1450', 'value': np.float64(6.6046000000000005)},
#  {'source': '情感', 'target': '1450817558', 'value': np.float64(26.7194)},
#  {'source': '情感', 'target': '1490', 'value': np.float64(4.7858)},
#  {'source': '情感', 'target': '14日', 'value': np.float64(5.678599999999999)},
#  {'source': '情感', 'target': '14萬', 'value': np.float64(11.241599999999998)},
#  {'source': '情感', 'target': '15', 'value': np.float64(14.991800000000001)},
#  {'source': '情感', 'target': '15%', 'value': np.float64(38.8378)},
#  {'source': '情感', 'target': '150', 'value': np.float64(3.6)},
#  {'source': '情感', 'target': '150.38', 'value': np.float64(5.0)},
#  {'source': '情感', 'target': '1500', 'value': np.float64(30.0276)},
#  {'source': '情感', 'target': '1500億', 'value': np.float64(5.3834)},
#  {'source': '情感', 'target': '1500萬', 'value': np.float64(26.135800000000003)},
#  {'source': '情感', 'target': '152', 'value': np.float64(9.879999999999999)},
#  {'source': '情感', 'target': '157', 'value': np.float64(19.671599999999998)},
#  {'source': '情感', 'target': '158', 'value': np.float64(4.7774)},
#  {'source': '情感', 'target': '15B廠', 'value': np.float64(14.264)},
#  {'source': '情感', 'target': '15區', 'value': np.float64(4.1912)},
#  {'source': '情感', 'target': '15日', 'value': np.float64(13.281600000000001)},
#  {'source': '情感', 'target': '16', 'value': np.float64(9.8196)},
#  {'source': '情感', 'target': '16%', 'value': np.float64(14.4)},
#  {'source': '情感', 'target': '16.1', 'value': np.float64(4.6624)},
#  {'source': '情感', 'target': '16.1%', 'value': np.float64(25.662399999999998)},
#  {'source': '情感', 'target': '16.55%', 'value': np.float64(12.568200000000001)},
#  {'source': '情感', 'target': '16.9%', 'value': np.float64(8.7076)},
#  {'source': '情感', 'target': '17', 'value': np.float64(16.4672)},
#  {'source': '情感', 'target': '17%', 'value': np.float64(11.600000000000001)},
#  {'source': '情感', 'target': '170', 'value': np.float64(4.54)},
#  {'source': '情感', 'target': '1700', 'value': np.float64(4.68)},
#  {'source': '情感', 'target': '1710', 'value': np.float64(5.1196)},
#  {'source': '情感', 'target': '1710萬', 'value': np.float64(10.2392)},
#  {'source': '情感', 'target': '17:51', 'value': np.float64(4.857)},
#  {'source': '情感', 'target': '17LIVE', 'value': np.float64(4.8088)},
#  {'source': '情感', 'target': '18', 'value': np.float64(10.2974)},
#  {'source': '情感', 'target': '18%', 'value': np.float64(4.6)},
#  {'source': '情感', 'target': '18.17%', 'value': np.float64(12.568200000000001)},
#  {'source': '情感', 'target': '1800億', 'value': np.float64(4.6334)},
#  {'source': '情感', 'target': '182', 'value': np.float64(9.120000000000001)},
#  {'source': '情感', 'target': '18:30', 'value': np.float64(2.88)},
#  {'source': '情感', 'target': '19', 'value': np.float64(8.1046)},
#  {'source': '情感', 'target': '19%', 'value': np.float64(22.8)},
#  {'source': '情感', 'target': '19.3%', 'value': np.float64(13.9872)},
#  {'source': '情感', 'target': '19/Dior', 'value': np.float64(7.6)},
#  {'source': '情感', 'target': '1930年代', 'value': np.float64(4.4)},
#  {'source': '情感', 'target': '1945', 'value': np.float64(4.030799999999999)},
#  {'source': '情感', 'target': '1949', 'value': np.float64(3.8432000000000004)},
#  {'source': '情感', 'target': '1985年', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': '1989年', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': '1991年', 'value': np.float64(4.5022)},
#  {'source': '情感', 'target': '1999', 'value': np.float64(14.880000000000003)},
#  {'source': '情感', 'target': '19億', 'value': np.float64(4.985)},
#  {'source': '情感', 'target': '19月', 'value': np.float64(4.9528)},
#  {'source': '情感', 'target': '1:5', 'value': np.float64(4.728199999999999)},
#  {'source': '情感', 'target': '1KW', 'value': np.float64(3.8432000000000004)},
#  {'source': '情感', 'target': '1Q25', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '1V1', 'value': np.float64(7.2)},
#  {'source': '情感',
#   'target': '1YPsKa1e',
#   'value': np.float64(5.500000000000001)},
#  {'source': '情感', 'target': '1cZs6i_l', 'value': np.float64(3.08)},
#  {'source': '情感', 'target': '1vi', 'value': np.float64(2.8)},
#  {'source': '情感', 'target': '1千多萬', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': '1成3', 'value': np.float64(14.4)},
#  {'source': '情感', 'target': '1成4', 'value': np.float64(14.895000000000003)},
#  {'source': '情感', 'target': '1成9', 'value': np.float64(4.364)},
#  {'source': '情感', 'target': '1日', 'value': np.float64(8.943999999999999)},
#  {'source': '情感', 'target': '1時', 'value': np.float64(6.731199999999999)},
#  {'source': '情感', 'target': '1月', 'value': np.float64(3.6292)},
#  {'source': '情感', 'target': '1樓', 'value': np.float64(4.382)},
#  {'source': '情感', 'target': '1段', 'value': np.float64(8.5732)},
#  {'source': '情感', 'target': '1點', 'value': np.float64(4.3)},
#  {'source': '情感', 'target': '1點半', 'value': np.float64(5.38)},
#  {'source': '情感', 'target': '2', 'value': np.float64(15.04)},
#  {'source': '情感', 'target': '2%', 'value': np.float64(23.794400000000003)},
#  {'source': '情感', 'target': '2-2', 'value': np.float64(5.76)},
#  {'source': '情感', 'target': '2.', 'value': np.float64(12.6294)},
#  {'source': '情感', 'target': '2.0', 'value': np.float64(53.3532)},
#  {'source': '情感', 'target': '2.16', 'value': np.float64(3.44)},
#  {'source': '情感', 'target': '2.35%', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': '2.3兆', 'value': np.float64(4.0822)},
#  {'source': '情感', 'target': '2.45', 'value': np.float64(5.2116)},
#  {'source': '情感', 'target': '2.45%', 'value': np.float64(12.568200000000001)},
#  {'source': '情感', 'target': '2.49%', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': '2.5', 'value': np.float64(4.620399999999999)},
#  {'source': '情感', 'target': '2.5%', 'value': np.float64(4.6624)},
#  {'source': '情感', 'target': '2.6億', 'value': np.float64(5.189)},
#  {'source': '情感', 'target': '2.6兆', 'value': np.float64(10.7668)},
#  {'source': '情感', 'target': '2.7', 'value': np.float64(13.3626)},
#  {'source': '情感', 'target': '2/8', 'value': np.float64(5.59)},
#  {'source': '情感', 'target': '20%', 'value': np.float64(34.44)},
#  {'source': '情感', 'target': '20.1%', 'value': np.float64(3.4)},
#  {'source': '情感', 'target': '20.12%', 'value': np.float64(5.2292)},
#  {'source': '情感', 'target': '20.3%', 'value': np.float64(4.6000000000000005)},
#  {'source': '情感', 'target': '20.5%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '20.61%', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': '200', 'value': np.float64(20.68)},
#  {'source': '情感', 'target': '200%', 'value': np.float64(5.8)},
#  {'source': '情感', 'target': '2000', 'value': np.float64(12.7334)},
#  {'source': '情感', 'target': '2000D', 'value': np.float64(3.6399999999999997)},
#  {'source': '情感', 'target': '2000億', 'value': np.float64(4.08)},
#  {'source': '情感', 'target': '2000多億', 'value': np.float64(4.6334)},
#  {'source': '情感', 'target': '2000萬', 'value': np.float64(4.875400000000001)},
#  {'source': '情感', 'target': '200億', 'value': np.float64(3.3)},
#  {'source': '情感', 'target': '200萬', 'value': np.float64(3.5400000000000005)},
#  {'source': '情感', 'target': '2019', 'value': np.float64(3.1)},
#  {'source': '情感', 'target': '2020', 'value': np.float64(5.0653999999999995)},
#  {'source': '情感', 'target': '2020年', 'value': np.float64(8.6292)},
#  {'source': '情感', 'target': '2023/10/25', 'value': np.float64(1.2)},
#  {'source': '情感', 'target': '2023年', 'value': np.float64(4.1666)},
#  {'source': '情感', 'target': '2024', 'value': np.float64(38.1482)},
#  {'source': '情感', 'target': '20241024', 'value': np.float64(4.1402)},
#  {'source': '情感', 'target': '2024B', 'value': np.float64(20.3946)},
#  {'source': '情感', 'target': '2024H22025', 'value': np.float64(5.7276)},
#  {'source': '情感', 'target': '2025', 'value': np.float64(9.5)},
#  {'source': '情感', 'target': '2026', 'value': np.float64(5.006600000000001)},
#  {'source': '情感', 'target': '2027', 'value': np.float64(14.36)},
#  {'source': '情感', 'target': '2028', 'value': np.float64(36.5546)},
#  {'source': '情感', 'target': '2030', 'value': np.float64(5.856800000000002)},
#  {'source': '情感', 'target': '2035', 'value': np.float64(8.639800000000001)},
#  {'source': '情感', 'target': '2040', 'value': np.float64(6.4006)},
#  {'source': '情感', 'target': '20452030年', 'value': np.float64(3.8134)},
#  {'source': '情感', 'target': '2049', 'value': np.float64(10.059999999999999)},
#  {'source': '情感', 'target': '2050', 'value': np.float64(5.720000000000001)},
#  {'source': '情感', 'target': '20Y', 'value': np.float64(4.3452)},
#  {'source': '情感', 'target': '20年', 'value': np.float64(7.879200000000001)},
#  {'source': '情感', 'target': '20日', 'value': np.float64(5.4)},
#  {'source': '情感', 'target': '21', 'value': np.float64(3.6599999999999993)},
#  {'source': '情感', 'target': '21%', 'value': np.float64(20.9102)},
#  {'source': '情感', 'target': '21.3%', 'value': np.float64(6.6)},
#  {'source': '情感', 'target': '21.6%', 'value': np.float64(21.0)},
#  {'source': '情感', 'target': '210號', 'value': np.float64(8.5732)},
#  {'source': '情感', 'target': '211', 'value': np.float64(4.8904)},
#  {'source': '情感', 'target': '214', 'value': np.float64(8.2)},
#  {'source': '情感', 'target': '21N\n', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '21日', 'value': np.float64(8.776599999999998)},
#  {'source': '情感', 'target': '21樓', 'value': np.float64(3.6)},
#  {'source': '情感', 'target': '22', 'value': np.float64(14.134)},
#  {'source': '情感', 'target': '22%', 'value': np.float64(9.909199999999998)},
#  {'source': '情感', 'target': '220', 'value': np.float64(3.54)},
#  {'source': '情感', 'target': '22200', 'value': np.float64(4.6356)},
#  {'source': '情感',
#   'target': '223.137.92.17810/2214:40',
#   'value': np.float64(6.0)},
#  {'source': '情感',
#   'target': '223.139.197.17411/08',
#   'value': np.float64(4.6274)},
#  {'source': '情感', 'target': '226', 'value': np.float64(4.9336)},
#  {'source': '情感', 'target': '2266', 'value': np.float64(4.253400000000001)},
#  {'source': '情感', 'target': '228', 'value': np.float64(2.2)},
#  {'source': '情感', 'target': '22K', 'value': np.float64(6.0)},
#  {'source': '情感', 'target': '22世紀', 'value': np.float64(3.2)},
#  {'source': '情感', 'target': '23', 'value': np.float64(9.9494)},
#  {'source': '情感', 'target': '23%', 'value': np.float64(27.886)},
#  {'source': '情感', 'target': '23.2', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '23.2%', 'value': np.float64(17.9266)},
#  {'source': '情感', 'target': '230', 'value': np.float64(3.1)},
#  {'source': '情感', 'target': '2330', 'value': np.float64(7.115600000000001)},
#  {'source': '情感', 'target': '23334', 'value': np.float64(4.5851999999999995)},
#  {'source': '情感', 'target': '2367', 'value': np.float64(3.3299999999999996)},
#  {'source': '情感', 'target': '23U', 'value': np.float64(6.8)},
#  {'source': '情感', 'target': '24', 'value': np.float64(4.14)},
#  {'source': '情感', 'target': '24%', 'value': np.float64(17.5154)},
#  {'source': '情感', 'target': '24.2%', 'value': np.float64(4.340000000000001)},
#  {'source': '情感', 'target': '24.6%', 'value': np.float64(10.3538)},
#  {'source': '情感', 'target': '24.72%', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': '24/7', 'value': np.float64(9.36)},
#  {'source': '情感', 'target': '240巷', 'value': np.float64(4.030799999999999)},
#  {'source': '情感', 'target': '245352455', 'value': np.float64(4.804)},
#  {'source': '情感', 'target': '24H', 'value': np.float64(6.6)},
#  {'source': '情感', 'target': '24台', 'value': np.float64(5.029999999999999)},
#  {'source': '情感', 'target': '25', 'value': np.float64(7.3932)},
#  {'source': '情感', 'target': '25%', 'value': np.float64(8.788)},
#  {'source': '情感', 'target': '25.1%', 'value': np.float64(4.364)},
#  {'source': '情感', 'target': '25.2%', 'value': np.float64(8.7076)},
#  {'source': '情感', 'target': '2500萬', 'value': np.float64(5.4)},
#  {'source': '情感',
#   'target': '25482700882',
#   'value': np.float64(3.3299999999999996)},
#  {'source': '情感', 'target': '25日', 'value': np.float64(15.8258)},
#  {'source': '情感', 'target': '25號', 'value': np.float64(11.1244)},
#  {'source': '情感', 'target': '26', 'value': np.float64(34.1886)},
#  {'source': '情感', 'target': '26%', 'value': np.float64(34.687200000000004)},
#  {'source': '情感', 'target': '26.6', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '2644', 'value': np.float64(5.7)},
#  {'source': '情感', 'target': '2693', 'value': np.float64(4.756)},
#  {'source': '情感', 'target': '26K', 'value': np.float64(4.429599999999999)},
#  {'source': '情感', 'target': '26仔', 'value': np.float64(4.728199999999999)},
#  {'source': '情感', 'target': '26巷', 'value': np.float64(8.5732)},
#  {'source': '情感', 'target': '27', 'value': np.float64(8.897000000000002)},
#  {'source': '情感', 'target': '27%', 'value': np.float64(9.1112)},
#  {'source': '情感',
#   'target': '27.242.94.2811/0820:20:',
#   'value': np.float64(2.9)},
#  {'source': '情感', 'target': '27.3', 'value': np.float64(4.4)},
#  {'source': '情感', 'target': '27.3%', 'value': np.float64(13.200000000000001)},
#  {'source': '情感', 'target': '27.4%', 'value': np.float64(4.7604)},
#  {'source': '情感', 'target': '27.6', 'value': np.float64(6.279999999999999)},
#  {'source': '情感', 'target': '27.8%', 'value': np.float64(15.9248)},
#  {'source': '情感', 'target': '2758', 'value': np.float64(17.3056)},
#  {'source': '情感', 'target': '28', 'value': np.float64(9.6)},
#  {'source': '情感', 'target': '28.3%', 'value': np.float64(21.9142)},
#  {'source': '情感', 'target': '28.5%', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '285', 'value': np.float64(14.0126)},
#  {'source': '情感', 'target': '28k', 'value': np.float64(4.945)},
#  {'source': '情感', 'target': '29', 'value': np.float64(4.9)},
#  {'source': '情感', 'target': '29%', 'value': np.float64(4.7604)},
#  {'source': '情感', 'target': '29.4%', 'value': np.float64(13.6)},
#  {'source': '情感',
#   'target': '293503545',
#   'value': np.float64(4.5600000000000005)},
#  {'source': '情感', 'target': '2:1', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '2D', 'value': np.float64(13.404400000000003)},
#  {'source': '情感', 'target': '2H', 'value': np.float64(7.040000000000001)},
#  {'source': '情感', 'target': '2PIN', 'value': np.float64(5.5996)},
#  {'source': '情感', 'target': '2T', 'value': np.float64(5.284599999999999)},
#  {'source': '情感', 'target': '2成', 'value': np.float64(4.9528)},
#  {'source': '情感', 'target': '2成2', 'value': np.float64(4.364)},
#  {'source': '情感', 'target': '2成3', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': '2成5', 'value': np.float64(14.4)},
#  {'source': '情感', 'target': '2日', 'value': np.float64(5.5502)},
#  {'source': '情感', 'target': '2時', 'value': np.float64(7.2584)},
#  {'source': '情感', 'target': '2萬', 'value': np.float64(4.4799999999999995)},
#  {'source': '情感', 'target': '3', 'value': np.float64(26.3942)},
#  {'source': '情感', 'target': '3%', 'value': np.float64(3.3199999999999994)},
#  {'source': '情感', 'target': '3.0', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '3.3%', 'value': np.float64(16.200000000000003)},
#  {'source': '情感', 'target': '3.3V', 'value': np.float64(15.119200000000001)},
#  {'source': '情感', 'target': '3.3億', 'value': np.float64(6.2354)},
#  {'source': '情感', 'target': '3.5%', 'value': np.float64(14.128)},
#  {'source': '情感', 'target': '3.56%', 'value': np.float64(12.568200000000001)},
#  {'source': '情感', 'target': '3.7', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '3.9%', 'value': np.float64(5.4)},
#  {'source': '情感', 'target': '3/4', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '30', 'value': np.float64(15.3294)},
#  {'source': '情感', 'target': '30%', 'value': np.float64(15.185599999999999)},
#  {'source': '情感', 'target': '30.02', 'value': np.float64(3.4101999999999997)},
#  {'source': '情感', 'target': '300', 'value': np.float64(42.808800000000005)},
#  {'source': '情感', 'target': '3000', 'value': np.float64(8.2934)},
#  {'source': '情感', 'target': '3000萬', 'value': np.float64(9.2292)},
#  {'source': '情感', 'target': '300萬', 'value': np.float64(3.8031999999999995)},
#  {'source': '情感', 'target': '3040', 'value': np.float64(2.4)},
#  {'source': '情感',
#   'target': '308491102',
#   'value': np.float64(4.5600000000000005)},
#  {'source': '情感', 'target': '30億', 'value': np.float64(4.5672)},
#  {'source': '情感', 'target': '30分', 'value': np.float64(22.545199999999998)},
#  {'source': '情感', 'target': '30年', 'value': np.float64(8.0486)},
#  {'source': '情感', 'target': '30萬', 'value': np.float64(3.2)},
#  {'source': '情感', 'target': '31', 'value': np.float64(4.857)},
#  {'source': '情感', 'target': '31%', 'value': np.float64(4.1894)},
#  {'source': '情感', 'target': '31.1', 'value': np.float64(28.8)},
#  {'source': '情感', 'target': '311', 'value': np.float64(4.7196)},
#  {'source': '情感', 'target': '317', 'value': np.float64(27.550399999999996)},
#  {'source': '情感', 'target': '32', 'value': np.float64(12.282)},
#  {'source': '情感', 'target': '32.3', 'value': np.float64(4.1912)},
#  {'source': '情感', 'target': '32.9%', 'value': np.float64(4.7604)},
#  {'source': '情感', 'target': '32A', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '33', 'value': np.float64(10.7972)},
#  {'source': '情感', 'target': '33%', 'value': np.float64(4.88)},
#  {'source': '情感', 'target': '33.2', 'value': np.float64(5.42)},
#  {'source': '情感', 'target': '33.5%', 'value': np.float64(15.6)},
#  {'source': '情感', 'target': '33.9', 'value': np.float64(12.4)},
#  {'source': '情感', 'target': '33姊', 'value': np.float64(5.6034)},
#  {'source': '情感', 'target': '34', 'value': np.float64(12.620000000000001)},
#  {'source': '情感', 'target': '34%', 'value': np.float64(9.3248)},
#  {'source': '情感', 'target': '35', 'value': np.float64(30.1044)},
#  {'source': '情感', 'target': '35%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '35.3%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '35.4%', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '35.5%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '35.6%', 'value': np.float64(15.577)},
#  {'source': '情感', 'target': '355', 'value': np.float64(5.7126)},
#  {'source': '情感', 'target': '36', 'value': np.float64(9.714)},
#  {'source': '情感', 'target': '36%', 'value': np.float64(10.555800000000001)},
#  {'source': '情感', 'target': '36.224.79.10', 'value': np.float64(6.8)},
#  {'source': '情感',
#   'target': '36.224.79.1011/0820:59',
#   'value': np.float64(6.813599999999999)},
#  {'source': '情感', 'target': '36.233.222.9', 'value': np.float64(4.4)},
#  {'source': '情感', 'target': '36.9', 'value': np.float64(4.7604)},
#  {'source': '情感', 'target': '36.9%', 'value': np.float64(21.4812)},
#  {'source': '情感', 'target': '360', 'value': np.float64(14.483)},
#  {'source': '情感', 'target': '365', 'value': np.float64(4.6541999999999994)},
#  {'source': '情感', 'target': '37', 'value': np.float64(5.5)},
#  {'source': '情感', 'target': '37.4%', 'value': np.float64(9.422799999999999)},
#  {'source': '情感', 'target': '37.7%', 'value': np.float64(14.14)},
#  {'source': '情感', 'target': '375', 'value': np.float64(4.119999999999999)},
#  {'source': '情感', 'target': '38%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '38.6%', 'value': np.float64(6.8)},
#  {'source': '情感', 'target': '3800萬', 'value': np.float64(11.9388)},
#  {'source': '情感', 'target': '39', 'value': np.float64(4.857)},
#  {'source': '情感', 'target': '39%', 'value': np.float64(50.8954)},
#  {'source': '情感', 'target': '39.39%', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': '39.7', 'value': np.float64(22.2)},
#  {'source': '情感', 'target': '390', 'value': np.float64(3.7266000000000004)},
#  {'source': '情感', 'target': '390萬', 'value': np.float64(4.0176)},
#  {'source': '情感', 'target': '391', 'value': np.float64(5.5514)},
#  {'source': '情感', 'target': '399', 'value': np.float64(5.0286)},
#  {'source': '情感', 'target': '3C', 'value': np.float64(8.4946)},
#  {'source': '情感', 'target': '3D', 'value': np.float64(5.319999999999999)},
#  {'source': '情感', 'target': '3G', 'value': np.float64(9.225)},
#  {'source': '情感', 'target': '3K', 'value': np.float64(9.313400000000001)},
#  {'source': '情感', 'target': '3P', 'value': np.float64(13.5404)},
#  {'source': '情感', 'target': '3xk', 'value': np.float64(4.864800000000001)},
#  {'source': '情感', 'target': '3兆', 'value': np.float64(4.492)},
#  {'source': '情感', 'target': '3分之1', 'value': np.float64(11.880399999999998)},
#  {'source': '情感', 'target': '3分之2', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '3千', 'value': np.float64(5.2)},
#  {'source': '情感', 'target': '3成', 'value': np.float64(44.933600000000006)},
#  {'source': '情感', 'target': '3成1', 'value': np.float64(14.4)},
#  {'source': '情感', 'target': '3成5', 'value': np.float64(4.529999999999999)},
#  {'source': '情感', 'target': '3成6', 'value': np.float64(14.4)},
#  {'source': '情感', 'target': '3成9', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': '3月', 'value': np.float64(3.6292)},
#  {'source': '情感', 'target': '3煞', 'value': np.float64(6.3)},
#  {'source': '情感', 'target': '3萬', 'value': np.float64(11.0378)},
#  {'source': '情感', 'target': '4', 'value': np.float64(44.88740000000001)},
#  {'source': '情感', 'target': '4%', 'value': np.float64(28.7744)},
#  {'source': '情感', 'target': '4.48', 'value': np.float64(4.640000000000001)},
#  {'source': '情感', 'target': '4.5', 'value': np.float64(3.2)},
#  {'source': '情感', 'target': '4.7', 'value': np.float64(3.8165999999999998)},
#  {'source': '情感', 'target': '4.8', 'value': np.float64(6.76)},
#  {'source': '情感', 'target': '4.8%', 'value': np.float64(12.8)},
#  {'source': '情感', 'target': '4.9%', 'value': np.float64(4.364)},
#  {'source': '情感', 'target': '4.TSM', 'value': np.float64(6.0)},
#  {'source': '情感', 'target': '40%', 'value': np.float64(150.24959999999993)},
#  {'source': '情感', 'target': '40.6%', 'value': np.float64(12.8)},
#  {'source': '情感', 'target': '40.7', 'value': np.float64(5.029999999999999)},
#  {'source': '情感', 'target': '40.9', 'value': np.float64(4.6624)},
#  {'source': '情感', 'target': '400', 'value': np.float64(9.6978)},
#  {'source': '情感', 'target': '4000萬', 'value': np.float64(6.779999999999999)},
#  {'source': '情感', 'target': '400多億', 'value': np.float64(5.8)},
#  {'source': '情感', 'target': '404', 'value': np.float64(8.4)},
#  {'source': '情感', 'target': '40億', 'value': np.float64(6.5)},
#  {'source': '情感', 'target': '40年', 'value': np.float64(14.401800000000001)},
#  {'source': '情感', 'target': '40萬', 'value': np.float64(13.319999999999999)},
#  {'source': '情感', 'target': '40趴', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '41%', 'value': np.float64(14.4)},
#  {'source': '情感', 'target': '41.8%', 'value': np.float64(3.4)},
#  {'source': '情感', 'target': '42', 'value': np.float64(17.1032)},
#  {'source': '情感', 'target': '42.4%', 'value': np.float64(4.7604)},
#  {'source': '情感',
#   'target': '42.72.113.140',
#   'value': np.float64(3.3125999999999998)},
#  {'source': '情感', 'target': '42.79.26.100', 'value': np.float64(4.26)},
#  {'source': '情感', 'target': '42.8%', 'value': np.float64(8.7076)},
#  {'source': '情感', 'target': '4248.02億', 'value': np.float64(5.0)},
#  {'source': '情感', 'target': '43', 'value': np.float64(4.253400000000001)},
#  {'source': '情感', 'target': '43.8', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '44.5%', 'value': np.float64(4.340000000000001)},
#  {'source': '情感', 'target': '45', 'value': np.float64(13.9124)},
#  {'source': '情感', 'target': '45%', 'value': np.float64(7.0)},
#  {'source': '情感', 'target': '45.3%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '45.67%', 'value': np.float64(4.6544)},
#  {'source': '情感', 'target': '4500', 'value': np.float64(5.6474)},
#  {'source': '情感', 'target': '450萬', 'value': np.float64(3.7266)},
#  {'source': '情感', 'target': '456', 'value': np.float64(3.8468000000000004)},
#  {'source': '情感', 'target': '46', 'value': np.float64(10.974800000000002)},
#  {'source': '情感', 'target': '46.6', 'value': np.float64(12.4)},
#  {'source': '情感', 'target': '46.847', 'value': np.float64(3.28)},
#  {'source': '情感', 'target': '47', 'value': np.float64(11.32)},
#  {'source': '情感', 'target': '47%', 'value': np.float64(11.675799999999999)},
#  {'source': '情感', 'target': '47.6', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '47491605', 'value': np.float64(4.94)},
#  {'source': '情感', 'target': '48%', 'value': np.float64(5.3176000000000005)},
#  {'source': '情感', 'target': '48.6%', 'value': np.float64(7.0)},
#  {'source': '情感', 'target': '484', 'value': np.float64(126.19820000000001)},
#  {'source': '情感', 'target': '4841.161.145.6711/10', 'value': np.float64(6.6)},
#  {'source': '情感', 'target': '486', 'value': np.float64(4.1342)},
#  {'source': '情感', 'target': '49', 'value': np.float64(4.857)},
#  {'source': '情感', 'target': '49%', 'value': np.float64(9.3248)},
#  {'source': '情感',
#   'target': '496212881',
#   'value': np.float64(6.5200000000000005)},
#  {'source': '情感', 'target': '49tAXH', 'value': np.float64(5.6034)},
#  {'source': '情感', 'target': '4G', 'value': np.float64(21.190800000000003)},
#  {'source': '情感', 'target': '4K', 'value': np.float64(9.648399999999999)},
#  {'source': '情感', 'target': '4PIN', 'value': np.float64(8.4712)},
#  {'source': '情感', 'target': '4PINPWM', 'value': np.float64(4.7576)},
#  {'source': '情感', 'target': '4ZfGE', 'value': np.float64(5.2244)},
#  {'source': '情感', 'target': '4a', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '4x', 'value': np.float64(1.2)},
#  {'source': '情感', 'target': '4叉貓', 'value': np.float64(5.380000000000001)},
#  {'source': '情感', 'target': '4成', 'value': np.float64(4.985)},
#  {'source': '情感', 'target': '4成5', 'value': np.float64(18.7538)},
#  {'source': '情感', 'target': '4時', 'value': np.float64(3.5799999999999996)},
#  {'source': '情感', 'target': '4月', 'value': np.float64(4.030799999999999)},
#  {'source': '情感', 'target': '4段', 'value': np.float64(5.6424)},
#  {'source': '情感', 'target': '4萬', 'value': np.float64(17.518200000000004)},
#  {'source': '情感', 'target': '4萬多', 'value': np.float64(9.89)},
#  {'source': '情感', 'target': '4點', 'value': np.float64(9.3596)},
#  {'source': '情感', 'target': '4點半', 'value': np.float64(5.38)},
#  {'source': '情感', 'target': '5', 'value': np.float64(29.135000000000005)},
#  {'source': '情感', 'target': '5%', 'value': np.float64(87.72600000000001)},
#  {'source': '情感', 'target': '5.', 'value': np.float64(6.6)},
#  {'source': '情感', 'target': '5.2', 'value': np.float64(5.4)},
#  {'source': '情感', 'target': '5.2%', 'value': np.float64(16.200000000000003)},
#  {'source': '情感', 'target': '5.20%', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': '5.3', 'value': np.float64(6.189)},
#  {'source': '情感', 'target': '5.7%', 'value': np.float64(21.0)},
#  {'source': '情感', 'target': '5.8', 'value': np.float64(20.28)},
#  {'source': '情感', 'target': '5.96.24711/0819:22', 'value': np.float64(4.6)},
#  {'source': '情感', 'target': '5/31', 'value': np.float64(9.6312)},
#  {'source': '情感', 'target': '50', 'value': np.float64(90.068)},
#  {'source': '情感', 'target': '50%', 'value': np.float64(18.3202)},
#  {'source': '情感', 'target': '50.3%', 'value': np.float64(4.364)},
#  {'source': '情感', 'target': '50.8%', 'value': np.float64(14.4)},
#  {'source': '情感', 'target': '500', 'value': np.float64(6.0)},
#  {'source': '情感', 'target': '5000', 'value': np.float64(4.6548)},
#  {'source': '情感', 'target': '5000萬', 'value': np.float64(4.040000000000001)},
#  {'source': '情感', 'target': '5001000', 'value': np.float64(3.0)},
#  {'source': '情感', 'target': '500萬', 'value': np.float64(8.8344)},
#  {'source': '情感', 'target': '50萬', 'value': np.float64(8.784199999999998)},
#  {'source': '情感', 'target': '51', 'value': np.float64(5.495)},
#  {'source': '情感', 'target': '51%', 'value': np.float64(5.495)},
#  {'source': '情感', 'target': '51.67%', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': '51~', 'value': np.float64(12.26)},
#  {'source': '情感', 'target': '52', 'value': np.float64(12.129999999999999)},
#  {'source': '情感', 'target': '520', 'value': np.float64(17.373600000000003)},
#  {'source': '情感', 'target': '524:', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '53', 'value': np.float64(4.857)},
#  {'source': '情感', 'target': '53%', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '538', 'value': np.float64(4.1226)},
#  {'source': '情感', 'target': '54.6', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '5400', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': '55', 'value': np.float64(7.827999999999999)},
#  {'source': '情感', 'target': '55%', 'value': np.float64(6.8)},
#  {'source': '情感', 'target': '5500E', 'value': np.float64(5.6474)},
#  {'source': '情感',
#   'target': '5548=100',
#   'value': np.float64(5.3176000000000005)},
#  {'source': '情感', 'target': '5566', 'value': np.float64(3.7)},
#  {'source': '情感', 'target': '56', 'value': np.float64(10.715)},
#  {'source': '情感', 'target': '56%', 'value': np.float64(6.4)},
#  {'source': '情感', 'target': '56/3', 'value': np.float64(3.8432000000000004)},
#  {'source': '情感', 'target': '560%', 'value': np.float64(2.4)},
#  {'source': '情感', 'target': '56272618', 'value': np.float64(4.94)},
#  {'source': '情感', 'target': '57', 'value': np.float64(14.0)},
#  {'source': '情感', 'target': '57.8%', 'value': np.float64(9.3248)},
#  {'source': '情感', 'target': '58', 'value': np.float64(8.577)},
#  {'source': '情感', 'target': '58%', 'value': np.float64(3.4)},
#  {'source': '情感', 'target': '581', 'value': np.float64(10.983)},
#  {'source': '情感', 'target': '585', 'value': np.float64(4.3076)},
#  {'source': '情感', 'target': '59', 'value': np.float64(15.352)},
#  {'source': '情感', 'target': '59%', 'value': np.float64(11.862400000000001)},
#  {'source': '情感', 'target': '5900X', 'value': np.float64(4.640000000000001)},
# ...
#  {'source': '情感', 'target': '75年', 'value': np.float64(6.22)},
#  {'source': '情感', 'target': '77', 'value': np.float64(7.8278)},
#  {'source': '情感',
#   'target': '7800X3D',
#   'value': np.float64(3.4101999999999997)},
#  {'source': '情感', 'target': '78千', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': '78成', 'value': np.float64(6.5504)},
#  {'source': '情感', 'target': '79.14%', 'value': np.float64(12.568200000000001)},
#  {'source': '情感',
#   'target': '7ELEVEN',
#   'value': np.float64(13.700000000000001)},
#  {'source': '情感', 'target': '7pupu', 'value': np.float64(6.1592)},
#  {'source': '情感', 'target': '7億多', 'value': np.float64(3.2)},
#  {'source': '情感', 'target': '7千多萬', 'value': np.float64(10.331599999999998)},
#  {'source': '情感', 'target': '7年級', 'value': np.float64(4.1486)},
#  {'source': '情感', 'target': '7成', 'value': np.float64(9.9768)},
#  {'source': '情感', 'target': '7成6', 'value': np.float64(4.364)},
#  {'source': '情感', 'target': '7月', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': '7萬', 'value': np.float64(5.6578)},
#  {'source': '情感', 'target': '7點', 'value': np.float64(4.455)},
#  {'source': '情感', 'target': '8', 'value': np.float64(29.9412)},
#  {'source': '情感', 'target': '8+9', 'value': np.float64(7.2432)},
#  {'source': '情感', 'target': '8.4', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '8.4%', 'value': np.float64(21.6)},
#  {'source': '情感', 'target': '8.585', 'value': np.float64(4.8355999999999995)},
#  {'source': '情感', 'target': '8.6%', 'value': np.float64(5.4)},
#  {'source': '情感', 'target': '8/20', 'value': np.float64(3.2)},
#  {'source': '情感', 'target': '8/23', 'value': np.float64(4.492)},
#  {'source': '情感', 'target': '80', 'value': np.float64(19.6614)},
#  {'source': '情感', 'target': '80%', 'value': np.float64(20.2284)},
#  {'source': '情感', 'target': '80/90年代', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': '800', 'value': np.float64(4.2)},
#  {'source': '情感', 'target': '800億', 'value': np.float64(5.8)},
#  {'source': '情感', 'target': '80億', 'value': np.float64(4.030799999999999)},
#  {'source': '情感', 'target': '80萬', 'value': np.float64(4.904599999999999)},
#  {'source': '情感', 'target': '812', 'value': np.float64(5.5)},
#  {'source': '情感', 'target': '816', 'value': np.float64(7.07)},
#  {'source': '情感', 'target': '82.7%', 'value': np.float64(3.4)},
#  {'source': '情感', 'target': '820:07', 'value': np.float64(4.6778)},
#  {'source': '情感', 'target': '823', 'value': np.float64(34.491200000000006)},
#  {'source': '情感', 'target': '83%', 'value': np.float64(6.8176000000000005)},
#  {'source': '情感', 'target': '85210', 'value': np.float64(5.0622)},
#  {'source': '情感', 'target': '87', 'value': np.float64(6.820399999999999)},
#  {'source': '情感', 'target': '87%', 'value': np.float64(19.252200000000002)},
#  {'source': '情感', 'target': '87成', 'value': np.float64(3.9582000000000006)},
#  {'source': '情感', 'target': '88', 'value': np.float64(11.011)},
#  {'source': '情感', 'target': '881', 'value': np.float64(4.42)},
#  {'source': '情感', 'target': '89', 'value': np.float64(222.56680000000003)},
#  {'source': '情感', 'target': '89成', 'value': np.float64(4.945)},
#  {'source': '情感', 'target': '8PIN', 'value': np.float64(3.3223999999999996)},
#  {'source': '情感', 'target': '8REMAKE', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': '8卦', 'value': np.float64(4.608)},
#  {'source': '情感', 'target': '8卦板', 'value': np.float64(8.364)},
#  {'source': '情感', 'target': '8年級', 'value': np.float64(4.3738)},
#  {'source': '情感', 'target': '8成', 'value': np.float64(18.68)},
#  {'source': '情感', 'target': '8日', 'value': np.float64(10.8096)},
#  {'source': '情感', 'target': '8時', 'value': np.float64(19.6792)},
#  {'source': '情感', 'target': '8月', 'value': np.float64(7.7958)},
#  {'source': '情感', 'target': '8點', 'value': np.float64(3.8892)},
#  {'source': '情感', 'target': '8點檔', 'value': np.float64(4.7616)},
#  {'source': '情感', 'target': '9', 'value': np.float64(20.2162)},
#  {'source': '情感', 'target': '9%', 'value': np.float64(21.4)},
#  {'source': '情感', 'target': '9.1%', 'value': np.float64(13.8)},
#  {'source': '情感', 'target': '9.2%', 'value': np.float64(4.2)},
#  {'source': '情感', 'target': '9.42', 'value': np.float64(2.8898)},
#  {'source': '情感', 'target': '9.7', 'value': np.float64(9.5208)},
#  {'source': '情感', 'target': '9.7%', 'value': np.float64(4.364)},
#  {'source': '情感', 'target': '9.97%', 'value': np.float64(5.1502)},
#  {'source': '情感', 'target': '9.jpeg', 'value': np.float64(4.5)},
#  {'source': '情感', 'target': '9/21', 'value': np.float64(17.968)},
#  {'source': '情感', 'target': '9/23', 'value': np.float64(4.3862)},
#  {'source': '情感', 'target': '90%', 'value': np.float64(14.9648)},
#  {'source': '情感', 'target': '900', 'value': np.float64(13.7114)},
#  {'source': '情感', 'target': '9008', 'value': np.float64(3.8199999999999994)},
#  {'source': '情感', 'target': '90W', 'value': np.float64(12.075199999999999)},
#  {'source': '情感', 'target': '90年代', 'value': np.float64(3.4)},
#  {'source': '情感', 'target': '90萬', 'value': np.float64(7.82)},
#  {'source': '情感', 'target': '91', 'value': np.float64(5.680400000000001)},
#  {'source': '情感', 'target': '91%', 'value': np.float64(5.1502)},
#  {'source': '情感', 'target': '91.06%', 'value': np.float64(4.1894)},
#  {'source': '情感', 'target': '911', 'value': np.float64(4.4)},
#  {'source': '情感', 'target': '921', 'value': np.float64(4.2578000000000005)},
#  {'source': '情感', 'target': '93', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '93%', 'value': np.float64(4.7018)},
#  {'source': '情感', 'target': '935', 'value': np.float64(8.811399999999999)},
#  {'source': '情感', 'target': '94', 'value': np.float64(3.599999999999999)},
#  {'source': '情感', 'target': '94.8', 'value': np.float64(13.52)},
#  {'source': '情感', 'target': '940', 'value': np.float64(4.6512)},
#  {'source': '情感', 'target': '95%', 'value': np.float64(13.389000000000001)},
#  {'source': '情感', 'target': '96', 'value': np.float64(3.31)},
#  {'source': '情感', 'target': '96A', 'value': np.float64(10.9332)},
#  {'source': '情感', 'target': '98', 'value': np.float64(6.545)},
#  {'source': '情感', 'target': '985萬', 'value': np.float64(4.6308)},
#  {'source': '情感', 'target': '99', 'value': np.float64(20.273)},
#  {'source': '情感', 'target': '99A', 'value': np.float64(5.515599999999999)},
#  {'source': '情感', 'target': '99A式', 'value': np.float64(5.2)},
#  {'source': '情感', 'target': '99旅', 'value': np.float64(5.8)},
#  {'source': '情感', 'target': '9MAN', 'value': np.float64(3.8)},
#  {'source': '情感', 'target': '9成', 'value': np.float64(8.9626)},
#  {'source': '情感', 'target': '9成1', 'value': np.float64(7.2)},
#  {'source': '情感', 'target': '9成9', 'value': np.float64(10.079999999999998)},
#  {'source': '情感', 'target': '9時', 'value': np.float64(5.994400000000001)},
#  {'source': '情感', 'target': '9月', 'value': np.float64(31.522399999999998)},
#  {'source': '情感', 'target': '9月份', 'value': np.float64(10.0048)},
#  {'source': '情感', 'target': '9點', 'value': np.float64(3.8599999999999994)},
#  {'source': '情感', 'target': ':', 'value': np.float64(4.3464)},
#  {'source': '情感', 'target': '==', 'value': np.float64(5.004)},
#  {'source': '情感', 'target': '=========', 'value': np.float64(7.6)},
#  {'source': '情感',
#   'target': '============',
#   'value': np.float64(5.273999999999999)},
#  {'source': '情感', 'target': '=============', 'value': np.float64(3.867)},
#  {'source': '情感',
#   'target': '=================================',
#   'value': np.float64(10.4584)},
#  {'source': '情感',
#   'target': '====================================================================',
#   'value': np.float64(5.6)},
#  {'source': '情感', 'target': '==a', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': '>', 'value': np.float64(6.0)},
#  {'source': '情感', 'target': '>>', 'value': np.float64(5.4)},
#  {'source': '情感', 'target': '@@', 'value': np.float64(4.6)},
#  {'source': '情感', 'target': '@@@', 'value': np.float64(8.3788)},
#  {'source': '情感', 'target': 'A', 'value': np.float64(100.06760000000001)},
#  {'source': '情感', 'target': 'A27I12M1', 'value': np.float64(2.8)},
#  {'source': '情感', 'target': 'A4', 'value': np.float64(6.44)},
#  {'source': '情感', 'target': 'A50200', 'value': np.float64(3.9099999999999993)},
#  {'source': '情感', 'target': 'AA', 'value': np.float64(3.725)},
#  {'source': '情感', 'target': 'AAA', 'value': np.float64(4.2)},
#  {'source': '情感',
#   'target': 'AB\nzh.wikipedia.org',
#   'value': np.float64(5.1412)},
#  {'source': '情感', 'target': 'ABC', 'value': np.float64(8.72)},
#  {'source': '情感', 'target': 'ACCT', 'value': np.float64(4.66)},
#  {'source': '情感', 'target': 'ACE', 'value': np.float64(5.16)},
#  {'source': '情感', 'target': 'ACER', 'value': np.float64(4.1476)},
#  {'source': '情感', 'target': 'ACLS', 'value': np.float64(4.0116)},
#  {'source': '情感', 'target': 'AD', 'value': np.float64(4.4)},
#  {'source': '情感', 'target': 'ADF', 'value': np.float64(4.6334)},
#  {'source': '情感', 'target': 'ADR', 'value': np.float64(60.7194)},
#  {'source': '情感', 'target': 'ADR28日', 'value': np.float64(6.653200000000001)},
#  {'source': '情感', 'target': 'AFTEE', 'value': np.float64(5.529400000000001)},
#  {'source': '情感', 'target': 'AG', 'value': np.float64(4.769)},
#  {'source': '情感',
#   'target': 'AGAMINGWIFI',
#   'value': np.float64(13.180800000000001)},
#  {'source': '情感', 'target': 'AGA派', 'value': np.float64(4.965000000000001)},
#  {'source': '情感', 'target': 'AGOA', 'value': np.float64(2.82)},
#  {'source': '情感', 'target': 'AHJ', 'value': np.float64(3.4599999999999995)},
#  {'source': '情感', 'target': 'AI', 'value': np.float64(313.95220000000006)},
#  {'source': '情感', 'target': 'AI/DC', 'value': np.float64(5.4475999999999996)},
#  {'source': '情感', 'target': 'AIBUG', 'value': np.float64(3.3200000000000003)},
#  {'source': '情感', 'target': 'AICOOLINGII', 'value': np.float64(4.26)},
#  {'source': '情感', 'target': 'AILLM', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': 'AIO', 'value': np.float64(9.8672)},
#  {'source': '情感', 'target': 'AIT', 'value': np.float64(72.6376)},
#  {'source': '情感', 'target': 'AI瘋', 'value': np.float64(5.5364)},
#  {'source': '情感', 'target': 'AK', 'value': np.float64(7.839999999999999)},
#  {'source': '情感', 'target': 'AKB', 'value': np.float64(4.728199999999999)},
#  {'source': '情感', 'target': 'AKB48', 'value': np.float64(5.8)},
#  {'source': '情感', 'target': 'ALC4080', 'value': np.float64(5.1076)},
#  {'source': '情感', 'target': 'ALC4082', 'value': np.float64(8.093399999999999)},
#  {'source': '情感', 'target': 'AM5', 'value': np.float64(4.935)},
#  {'source': '情感', 'target': 'AMD', 'value': np.float64(58.947)},
#  {'source': '情感',
#   'target': 'AMDX870',
#   'value': np.float64(22.330600000000004)},
#  {'source': '情感', 'target': 'AMDX870E', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': 'AML', 'value': np.float64(11.399999999999999)},
#  {'source': '情感', 'target': 'AMP\nAI', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': 'ANGEL', 'value': np.float64(3.9427999999999996)},
#  {'source': '情感', 'target': 'ANYWAY', 'value': np.float64(5.2)},
#  {'source': '情感',
#   'target': 'AORUSMASTER',
#   'value': np.float64(10.740199999999998)},
#  {'source': '情感', 'target': 'AORUSXTREME', 'value': np.float64(5.2704)},
#  {'source': '情感', 'target': 'AP1000', 'value': np.float64(8.607800000000001)},
#  {'source': '情感', 'target': 'APEX', 'value': np.float64(15.341400000000002)},
#  {'source': '情感', 'target': 'APP', 'value': np.float64(62.61119999999999)},
#  {'source': '情感', 'target': 'APP,', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': 'APPNati', 'value': np.float64(5.6034)},
#  {'source': '情感', 'target': 'APT', 'value': np.float64(16.0902)},
#  {'source': '情感', 'target': 'APT41', 'value': np.float64(15.340399999999999)},
#  {'source': '情感', 'target': 'APU', 'value': np.float64(10.8076)},
#  {'source': '情感', 'target': 'AQ', 'value': np.float64(4.54)},
#  {'source': '情感', 'target': 'AR', 'value': np.float64(10.0304)},
#  {'source': '情感', 'target': 'ASM2074', 'value': np.float64(5.6034)},
#  {'source': '情感',
#   'target': 'ASM358M',
#   'value': np.float64(3.8266000000000004)},
#  {'source': '情感', 'target': 'ASM4242', 'value': np.float64(19.3552)},
#  {'source': '情感', 'target': 'ASML', 'value': np.float64(35.2864)},
#  {'source': '情感', 'target': 'ASP2206', 'value': np.float64(4.2)},
#  {'source': '情感', 'target': 'ASPS', 'value': np.float64(3.2019999999999995)},
#  {'source': '情感', 'target': 'ASUSDRIVERHUB', 'value': np.float64(5.6)},
#  {'source': '情感', 'target': 'ATM', 'value': np.float64(4.3538)},
#  {'source': '情感', 'target': 'ATX24PIN', 'value': np.float64(4.3142)},
#  {'source': '情感', 'target': 'ATXPCB', 'value': np.float64(9.0794)},
#  {'source': '情感', 'target': 'AV', 'value': np.float64(8.76)},
#  {'source': '情感', 'target': 'AVGFPS', 'value': np.float64(12.4)},
#  {'source': '情感', 'target': 'AWG', 'value': np.float64(3.9114000000000004)},
#  {'source': '情感', 'target': 'AWS', 'value': np.float64(14.131599999999999)},
#  {'source': '情感', 'target': 'AZ', 'value': np.float64(18.974)},
#  {'source': '情感', 'target': 'AZ廠', 'value': np.float64(45.3612)},
#  {'source': '情感',
#   'target': 'Abinader',
#   'value': np.float64(6.507599999999999)},
#  {'source': '情感', 'target': 'Acer', 'value': np.float64(4.114800000000001)},
#  {'source': '情感', 'target': 'Ackman', 'value': np.float64(5.4)},
#  {'source': '情感', 'target': 'Acnes', 'value': np.float64(7.5)},
#  {'source': '情感', 'target': 'Act', 'value': np.float64(5.189)},
#  {'source': '情感',
#   'target': 'AdamLee',
#   'value': np.float64(5.9399999999999995)},
#  {'source': '情感', 'target': 'Ado', 'value': np.float64(22.682)},
#  {'source': '情感', 'target': 'Adr', 'value': np.float64(3.7600000000000002)},
#  {'source': '情感', 'target': 'Again', 'value': np.float64(3.5111999999999997)},
#  {'source': '情感', 'target': 'AgeUK', 'value': np.float64(5.1412)},
#  {'source': '情感', 'target': 'Agoda', 'value': np.float64(23.9236)},
#  {'source': '情感', 'target': 'Ai5', 'value': np.float64(5.175)},
#  {'source': '情感', 'target': 'AiLoS', 'value': np.float64(6.8)},
#  {'source': '情感', 'target': 'Alice', 'value': np.float64(5.5502)},
#  {'source': '情感', 'target': 'Alphabet', 'value': np.float64(19.042)},
#  {'source': '情感', 'target': 'Altman', 'value': np.float64(6.1628)},
#  {'source': '情感', 'target': 'Amour', 'value': np.float64(9.0534)},
#  {'source': '情感', 'target': 'Anchor', 'value': np.float64(4.34)},
#  {'source': '情感', 'target': 'Andah', 'value': np.float64(21.831599999999998)},
#  {'source': '情感', 'target': 'Andosinjo', 'value': np.float64(5.2)},
#  {'source': '情感', 'target': 'Angel', 'value': np.float64(11.998)},
#  {'source': '情感',
#   'target': 'Aniplex',
#   'value': np.float64(5.6450000000000005)},
#  {'source': '情感', 'target': 'AnnaGordon', 'value': np.float64(3.6)},
#  {'source': '情感', 'target': 'Annie', 'value': np.float64(5.0)},
#  {'source': '情感', 'target': 'Ansys', 'value': np.float64(12.2)},
#  {'source': '情感', 'target': 'Anvisa', 'value': np.float64(5.4586)},
#  {'source': '情感', 'target': 'AoWsL:', 'value': np.float64(6.3)},
#  {'source': '情感', 'target': 'Apk', 'value': np.float64(5.7112)},
#  {'source': '情感', 'target': 'App', 'value': np.float64(46.3212)},
#  {'source': '情感', 'target': 'Apple', 'value': np.float64(25.2356)},
#  {'source': '情感', 'target': 'Arizona', 'value': np.float64(4.364)},
#  {'source': '情感', 'target': 'Arm', 'value': np.float64(11.355599999999999)},
#  {'source': '情感', 'target': 'Arte', 'value': np.float64(4.904599999999999)},
#  {'source': '情感', 'target': 'Ascend', 'value': np.float64(4.8778)},
#  {'source': '情感', 'target': 'AssassinKing', 'value': np.float64(4.4)},
#  {'source': '情感', 'target': 'Astor', 'value': np.float64(16.8102)},
#  {'source': '情感', 'target': 'Atima:', 'value': np.float64(6.0144)},
#  {'source': '情感', 'target': 'Austin', 'value': np.float64(6.493399999999999)},
#  {'source': '情感', 'target': 'Autobuy', 'value': np.float64(5.08)},
#  {'source': '情感', 'target': 'Axios', 'value': np.float64(4.857)},
#  {'source': '情感', 'target': 'Ay', 'value': np.float64(3.6399999999999997)},
#  {'source': '情感', 'target': 'Ayase', 'value': np.float64(19.0888)},
#  {'source': '情感', 'target': 'Az', 'value': np.float64(4.425)},
#  {'source': '情感', 'target': 'Azimech', 'value': np.float64(4.873400000000001)},
#  {'source': '情感', 'target': 'A區', 'value': np.float64(6.2)},
#  {'source': '情感', 'target': 'A婆', 'value': np.float64(5.2)},
#  ...]

# %%
aop_df.groupby(["t", "o"]).size().sort_values(ascending=False).head(10)
# Out:
# t    o
# NAT  有     9170
#      說     9121
#      表示    4855
#      報導    2670
#      看     2667
#      知道    2564
#      想     2530
#      覺得    2429
# POS  好     2406
# NAT  指出    2389
# dtype: int64

# %%
select_o_aop_list = []
for tag, df in aop_df.groupby(["t"]):
    select_o = df["o"].value_counts().head(10).index.tolist()
    # print(select_o)
    select_o_aop_list.append(df.loc[df["o"].isin(select_o)])
    # print(df.loc[df.value_counts().head(10).index.tolist()])

# %%
pd.concat(select_o_aop_list)
# Out:
#                           id                    date   a   o       p    t
# 28      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678  習俗  知道  5.4000  NAT
# 29      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678   我  知道  5.4000  NAT
# 31      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678   人   說  5.6034  NAT
# 34      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678   我  知道  5.4000  NAT
# 41      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678  口福  知道  5.4000  NAT
# ...                      ...                     ...  ..  ..     ...  ...
# 334607  7g2dDpMBx63wKxznMfRx 2024-10-27 11:49:53.383  大家  希望  7.0000  POS
# 334608  7g2dDpMBx63wKxznMfRx 2024-10-27 11:49:53.383  台灣   好  6.8000  POS
# 334671  8Q2dDpMBx63wKxznMfRx 2024-10-18 15:03:07.631  投票  喜歡  7.0000  POS
# 334708  4w2dDpMBx63wKxznMfRx 2024-10-18 05:37:14.907  心態   好  6.8000  POS
# 334857  3w2dDpMBx63wKxznMfRx 2024-10-22 12:06:06.752  立院  通過  6.4000  POS
#
# [56395 rows x 6 columns]

# %%
select_o_aop_list
# Out:
# [                          id                    date    a   o       p    t
#  28      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678   習俗  知道  5.4000  NAT
#  29      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678    我  知道  5.4000  NAT
#  31      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678    人   說  5.6034  NAT
#  34      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678    我  知道  5.4000  NAT
#  41      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678   口福  知道  5.4000  NAT
#  ...                      ...                     ...  ...  ..     ...  ...
#  334856  3w2dDpMBx63wKxznMfRx 2024-10-22 12:06:06.752  張啟楷   說  5.6034  NAT
#  334862  3w2dDpMBx63wKxznMfRx 2024-10-22 12:06:06.752    他   說  5.6034  NAT
#  334933  3Q2dDpMBx63wKxznMfRx 2024-10-19 22:59:38.912  蔡英文   說  5.6034  NAT
#  334945  3Q2dDpMBx63wKxznMfRx 2024-10-19 22:59:38.912  蔡英文  表示  4.1894  NAT
#  334958  2w2dDpMBx63wKxznMfRx 2024-10-29 03:00:21.710   獻金   有  4.3538  NAT
#
#  [40726 rows x 6 columns],
#                            id                    date    a   o       p    t
#  223     9A1bDJMBx63wKxznkPM6 2024-10-31 01:31:16.781    事   差  3.4000  NEG
#  325     Bg3mBpMBx63wKxznz9G6 2024-10-18 05:51:16.506   說法  出現  2.8616  NEG
#  559     vQ3mBpMBx63wKxzntNBt 2024-11-03 17:31:21.112    人  變成  3.8102  NEG
#  659     vQ3mBpMBx63wKxzntNBt 2024-11-03 17:31:21.112   拳拳   打  3.2000  NEG
#  662     vQ3mBpMBx63wKxzntNBt 2024-11-03 17:31:21.112    你   打  3.2000  NEG
#  ...                      ...                     ...  ...  ..     ...  ...
#  334752  4w2dDpMBx63wKxznMfRx 2024-10-18 05:37:14.907   債務   達  3.6292  NEG
#  334861  3w2dDpMBx63wKxznMfRx 2024-10-22 12:06:06.752   皇帝   叫  3.5150  NEG
#  334867  3w2dDpMBx63wKxznMfRx 2024-10-22 12:06:06.752   國家  出現  2.8616  NEG
#  334873  3w2dDpMBx63wKxznMfRx 2024-10-22 12:06:06.752   素養   差  3.4000  NEG
#  334884  4Q2dDpMBx63wKxznMfRx 2024-10-22 11:14:28.235  王婉諭  強調  3.7802  NEG
#
#  [7661 rows x 6 columns],
#                            id                    date    a   o    p    t
#  10      xg1bDJMBx63wKxznjfFO 2024-11-03 20:48:04.752   司機   好  6.8  POS
#  15      xg1bDJMBx63wKxznjfFO 2024-11-03 20:48:04.752   國家   好  6.8  POS
#  27      0g1bDJMBx63wKxznjfFO 2024-11-07 12:29:07.678   補湯   好  6.8  POS
#  58      1A1bDJMBx63wKxznjfFO 2024-10-30 07:00:01.872  穩定性  重要  6.0  POS
#  60      1A1bDJMBx63wKxznjfFO 2024-10-30 07:00:01.872   網速  重要  6.0  POS
#  ...                      ...                     ...  ...  ..  ...  ...
#  334607  7g2dDpMBx63wKxznMfRx 2024-10-27 11:49:53.383   大家  希望  7.0  POS
#  334608  7g2dDpMBx63wKxznMfRx 2024-10-27 11:49:53.383   台灣   好  6.8  POS
#  334671  8Q2dDpMBx63wKxznMfRx 2024-10-18 15:03:07.631   投票  喜歡  7.0  POS
#  334708  4w2dDpMBx63wKxznMfRx 2024-10-18 05:37:14.907   心態   好  6.8  POS
#  334857  3w2dDpMBx63wKxznMfRx 2024-10-22 12:06:06.752   立院  通過  6.4  POS
#
#  [8008 rows x 6 columns]]

# %%
l_df, r_df = list(combinations(select_o_aop_list, 2))[0]

# %%
merge_df = pd.merge(l_df, r_df, on=["id"], suffixes=("_l", "_r"))

# %%
merge_df["t_l"].unique().tolist()
# Out:
# ['NAT']

# %%
for i in merge_df.groupby(["o_l", "o_r"]).size().items():
    print(i)
# Out:
# (('報導', '出現'), 402)
# (('報導', '叫'), 153)
# (('報導', '差'), 58)
# (('報導', '強調'), 616)
# (('報導', '打'), 121)
# (('報導', '找'), 159)
# (('報導', '署名'), 1320)
# (('報導', '變成'), 129)
# (('報導', '質疑'), 323)
# (('報導', '達'), 387)
# (('想', '出現'), 245)
# (('想', '叫'), 414)
# (('想', '差'), 258)
# (('想', '強調'), 266)
# (('想', '打'), 621)
# (('想', '找'), 344)
# (('想', '署名'), 260)
# (('想', '變成'), 301)
# (('想', '質疑'), 155)
# (('想', '達'), 139)
# (('指出', '出現'), 362)
# (('指出', '叫'), 129)
# (('指出', '差'), 92)
# (('指出', '強調'), 808)
# (('指出', '打'), 175)
# (('指出', '找'), 183)
# (('指出', '署名'), 1373)
# (('指出', '變成'), 155)
# (('指出', '質疑'), 530)
# (('指出', '達'), 434)
# (('有', '出現'), 1606)
# (('有', '叫'), 1405)
# (('有', '差'), 835)
# (('有', '強調'), 1576)
# (('有', '打'), 1611)
# (('有', '找'), 1107)
# (('有', '署名'), 1745)
# (('有', '變成'), 895)
# (('有', '質疑'), 1023)
# (('有', '達'), 1153)
# (('看', '出現'), 257)
# (('看', '叫'), 327)
# (('看', '差'), 291)
# (('看', '強調'), 181)
# (('看', '打'), 504)
# (('看', '找'), 281)
# (('看', '署名'), 226)
# (('看', '變成'), 259)
# (('看', '質疑'), 173)
# (('看', '達'), 142)
# (('知道', '出現'), 331)
# (('知道', '叫'), 524)
# (('知道', '差'), 227)
# (('知道', '強調'), 250)
# (('知道', '打'), 663)
# (('知道', '找'), 370)
# (('知道', '署名'), 158)
# (('知道', '變成'), 230)
# (('知道', '質疑'), 234)
# (('知道', '達'), 57)
# (('表示', '出現'), 712)
# (('表示', '叫'), 354)
# (('表示', '差'), 110)
# (('表示', '強調'), 1666)
# (('表示', '打'), 282)
# (('表示', '找'), 269)
# (('表示', '署名'), 2670)
# (('表示', '變成'), 262)
# (('表示', '質疑'), 790)
# (('表示', '達'), 718)
# (('覺得', '出現'), 273)
# (('覺得', '叫'), 416)
# (('覺得', '差'), 318)
# (('覺得', '強調'), 213)
# (('覺得', '打'), 535)
# (('覺得', '找'), 357)
# (('覺得', '署名'), 155)
# (('覺得', '變成'), 310)
# (('覺得', '質疑'), 177)
# (('覺得', '達'), 81)
# (('認為', '出現'), 371)
# (('認為', '叫'), 387)
# (('認為', '差'), 221)
# (('認為', '強調'), 662)
# (('認為', '打'), 418)
# (('認為', '找'), 202)
# (('認為', '署名'), 925)
# (('認為', '變成'), 265)
# (('認為', '質疑'), 411)
# (('認為', '達'), 302)
# (('說', '出現'), 1297)
# (('說', '叫'), 1755)
# (('說', '差'), 745)
# (('說', '強調'), 1791)
# (('說', '打'), 1990)
# (('說', '找'), 1065)
# (('說', '署名'), 2035)
# (('說', '變成'), 841)
# (('說', '質疑'), 1320)
# (('說', '達'), 588)

# %%
for l_df, r_df in combinations(select_o_aop_list, 2):
    l_df = l_df[['id', "o", "t"]]
    r_df = r_df[['id', "o", "t"]]
    print(pd.merge(l_df, r_df, on=["id"], suffixes=("_l", "_r")))
# Out:
#                          id o_l  t_l o_r  t_r
# 0      9A1bDJMBx63wKxznkPM6   想  NAT   差  NEG
# 1      9A1bDJMBx63wKxznkPM6   有  NAT   差  NEG
# 2      9A1bDJMBx63wKxznkPM6   有  NAT   差  NEG
# 3      9A1bDJMBx63wKxznkPM6   說  NAT   差  NEG
# 4      Bg3mBpMBx63wKxznz9G6  表示  NAT  出現  NEG
# ...                     ...  ..  ...  ..  ...
# 57807  3w2dDpMBx63wKxznMfRx   說  NAT  出現  NEG
# 57808  3w2dDpMBx63wKxznMfRx   說  NAT   差  NEG
# 57809  3w2dDpMBx63wKxznMfRx   說  NAT   叫  NEG
# 57810  3w2dDpMBx63wKxznMfRx   說  NAT  出現  NEG
# 57811  3w2dDpMBx63wKxznMfRx   說  NAT   差  NEG
#
# [57812 rows x 5 columns]
#                          id o_l  t_l o_r  t_r
# 0      0g1bDJMBx63wKxznjfFO  知道  NAT   好  POS
# 1      0g1bDJMBx63wKxznjfFO  知道  NAT   好  POS
# 2      0g1bDJMBx63wKxznjfFO   說  NAT   好  POS
# 3      0g1bDJMBx63wKxznjfFO  知道  NAT   好  POS
# 4      0g1bDJMBx63wKxznjfFO  知道  NAT   好  POS
# ...                     ...  ..  ...  ..  ...
# 57643  3w2dDpMBx63wKxznMfRx   說  NAT  通過  POS
# 57644  3w2dDpMBx63wKxznMfRx  指出  NAT  通過  POS
# 57645  3w2dDpMBx63wKxznMfRx  指出  NAT  通過  POS
# 57646  3w2dDpMBx63wKxznMfRx   說  NAT  通過  POS
# 57647  3w2dDpMBx63wKxznMfRx   說  NAT  通過  POS
#
# [57648 rows x 5 columns]
#                         id o_l  t_l o_r  t_r
# 0     Bg3mBpMBx63wKxznz9G6  出現  NEG  願意  POS
# 1     vQ3mBpMBx63wKxzntNBt  變成  NEG   好  POS
# 2     vQ3mBpMBx63wKxzntNBt  變成  NEG   好  POS
# 3     vQ3mBpMBx63wKxzntNBt  變成  NEG  重要  POS
# 4     vQ3mBpMBx63wKxzntNBt  變成  NEG  重要  POS
# ...                    ...  ..  ...  ..  ...
# 9897  4w2dDpMBx63wKxznMfRx  出現  NEG   好  POS
# 9898  4w2dDpMBx63wKxznMfRx   達  NEG   好  POS
# 9899  3w2dDpMBx63wKxznMfRx   叫  NEG  通過  POS
# 9900  3w2dDpMBx63wKxznMfRx  出現  NEG  通過  POS
# 9901  3w2dDpMBx63wKxznMfRx   差  NEG  通過  POS
#
# [9902 rows x 5 columns]

# %%
group_df = aop_df.groupby("t")["o"].value_counts().to_frame()

# %%
group_df
# Out:
#         count
# t   o
# NAT 有    9170
#     說    9121
#     表示   4855
#     報導   2670
#     看    2667
# ...       ...
# POS 麥       1
#     點亮      1
#     點唱      1
#     鼎盛      1
#     鼓舞      1
#
# [20659 rows x 1 columns]

# %%
tmp = list(group_df.groupby(level=0))[0][1]

# %%
tmp
# Out:
#          count
# t   o
# NAT 有     9170
#     說     9121
#     表示    4855
#     報導    2670
#     看     2667
# ...        ...
#     齊刷刷      1
#     齊發       1
#     齊開       1
#     龜縮成      1
#     😵        1
#
# [10756 rows x 1 columns]

# %%
tmp.loc["NAT"].iloc[10:]["count"].sum()
# Out:
# np.int64(171765)

# %%
tmp.loc["NAT"].iloc[0:10]
# Out:
#     count
# o
# 有    9170
# 說    9121
# 表示   4855
# 報導   2670
# 看    2667
# 知道   2564
# 想    2530
# 覺得   2429
# 指出   2389
# 認為   2331

# %%
o_df = tmp.loc["NAT"]

# %%
o_df[5:].sum()
# Out:
# count    184008
# dtype: int64

# %%
o_df
# Out:
#      count
# o
# 有     9170
# 說     9121
# 表示    4855
# 報導    2670
# 看     2667
# ..     ...
# 齊刷刷      1
# 齊發       1
# 齊開       1
# 龜縮成      1
# 😵        1
#
# [10756 rows x 1 columns]

# %%
pd.concat([o_df[:5], pd.DataFrame([o_df[5:].sum()], index=["others"], columns=["count"])])
# Out:
#          count
# 有         9170
# 說         9121
# 表示        4855
# 報導        2670
# 看         2667
# others  184008

# %%
o_df.query("count > 0")
# Out:
#          count
# 有         9170
# 說         9121
# 表示        4855
# 報導        2670
# 看         2667
# others  184008

# %%
list(o_df.itertuples())
# Out:
# [Pandas(Index='有', count=9170),
#  Pandas(Index='說', count=9121),
#  Pandas(Index='表示', count=4855),
#  Pandas(Index='報導', count=2670),
#  Pandas(Index='看', count=2667),
#  Pandas(Index='others', count=184008)]

# %%
int(list(o_df.iterrows())[0][1].iloc[0])
# Out:
# 9170

# %%
[p for p, o in group_df.groupby(level=0)]
# Out:
# ['NAT', 'NEG', 'POS']

# %%
group_df
# Out:
#         count
# t   o
# NAT 有    9170
#     說    9121
#     表示   4855
#     報導   2670
#     看    2667
# ...       ...
# POS 麥       1
#     點亮      1
#     點唱      1
#     鼎盛      1
#     鼓舞      1
#
# [20659 rows x 1 columns]

# %%
list(group_df)
# Out:
# [(('NAT', '有'),
#   count    9170
#   Name: (NAT, 有), dtype: int64),
#  (('NAT', '說'),
#   count    9121
#   Name: (NAT, 說), dtype: int64),
#  (('NAT', '表示'),
#   count    4855
#   Name: (NAT, 表示), dtype: int64),
#  (('NAT', '報導'),
#   count    2670
#   Name: (NAT, 報導), dtype: int64),
#  (('NAT', '看'),
#   count    2667
#   Name: (NAT, 看), dtype: int64),
#  (('NAT', '知道'),
#   count    2564
#   Name: (NAT, 知道), dtype: int64),
#  (('NAT', '想'),
#   count    2530
#   Name: (NAT, 想), dtype: int64),
#  (('NAT', '覺得'),
#   count    2429
#   Name: (NAT, 覺得), dtype: int64),
#  (('NAT', '指出'),
#   count    2389
#   Name: (NAT, 指出), dtype: int64),
#  (('NAT', '認為'),
#   count    2331
#   Name: (NAT, 認為), dtype: int64),
#  (('NAT', '沒有'),
#   count    1729
#   Name: (NAT, 沒有), dtype: int64),
#  (('NAT', '大'),
#   count    1719
#   Name: (NAT, 大), dtype: int64),
#  (('NAT', '做'),
#   count    1686
#   Name: (NAT, 做), dtype: int64),
#  (('NAT', '讓'),
#   count    1686
#   Name: (NAT, 讓), dtype: int64),
#  (('NAT', '高'),
#   count    1660
#   Name: (NAT, 高), dtype: int64),
#  (('NAT', '放'),
#   count    1613
#   Name: (NAT, 放), dtype: int64),
#  (('NAT', '來'),
#   count    1348
#   Name: (NAT, 來), dtype: int64),
#  (('NAT', '沒'),
#   count    1194
#   Name: (NAT, 沒), dtype: int64),
#  (('NAT', '當'),
#   count    1156
#   Name: (NAT, 當), dtype: int64),
#  (('NAT', '買'),
#   count    1137
#   Name: (NAT, 買), dtype: int64),
#  (('NAT', '講'),
#   count    1085
#   Name: (NAT, 講), dtype: int64),
#  (('NAT', '一樣'),
#   count    1059
#   Name: (NAT, 一樣), dtype: int64),
#  (('NAT', '多'),
#   count    1047
#   Name: (NAT, 多), dtype: int64),
#  (('NAT', '看到'),
#   count    1025
#   Name: (NAT, 看到), dtype: int64),
#  (('NAT', '問'),
#   count    932
#   Name: (NAT, 問), dtype: int64),
#  (('NAT', '為'),
#   count    868
#   Name: (NAT, 為), dtype: int64),
#  (('NAT', '去'),
#   count    852
#   Name: (NAT, 去), dtype: int64),
#  (('NAT', '發生'),
#   count    809
#   Name: (NAT, 發生), dtype: int64),
#  (('NAT', '當選'),
#   count    786
#   Name: (NAT, 當選), dtype: int64),
#  (('NAT', '發現'),
#   count    760
#   Name: (NAT, 發現), dtype: int64),
#  (('NAT', '開'),
#   count    724
#   Name: (NAT, 開), dtype: int64),
#  (('NAT', '給'),
#   count    704
#   Name: (NAT, 給), dtype: int64),
#  (('NAT', '提到'),
#   count    701
#   Name: (NAT, 提到), dtype: int64),
#  (('NAT', '低'),
#   count    696
#   Name: (NAT, 低), dtype: int64),
#  (('NAT', '用'),
#   count    696
#   Name: (NAT, 用), dtype: int64),
#  (('NAT', '搞'),
#   count    680
#   Name: (NAT, 搞), dtype: int64),
#  (('NAT', '到'),
#   count    676
#   Name: (NAT, 到), dtype: int64),
#  (('NAT', '元'),
#   count    666
#   Name: (NAT, 元), dtype: int64),
#  (('NAT', '進行'),
#   count    665
#   Name: (NAT, 進行), dtype: int64),
#  (('NAT', '提出'),
#   count    647
#   Name: (NAT, 提出), dtype: int64),
#  (('NAT', '要求'),
#   count    640
#   Name: (NAT, 要求), dtype: int64),
#  (('NAT', '提供'),
#   count    639
#   Name: (NAT, 提供), dtype: int64),
#  (('NAT', '顯示'),
#   count    594
#   Name: (NAT, 顯示), dtype: int64),
#  (('NAT', '拿'),
#   count    589
#   Name: (NAT, 拿), dtype: int64),
#  (('NAT', '超過'),
#   count    583
#   Name: (NAT, 超過), dtype: int64),
#  (('NAT', '成為'),
#   count    577
#   Name: (NAT, 成為), dtype: int64),
#  (('NAT', '稱'),
#   count    576
#   Name: (NAT, 稱), dtype: int64),
#  (('NAT', '增加'),
#   count    564
#   Name: (NAT, 增加), dtype: int64),
#  (('NAT', '回應'),
#   count    559
#   Name: (NAT, 回應), dtype: int64),
#  (('NAT', '算'),
#   count    547
#   Name: (NAT, 算), dtype: int64),
#  (('NAT', '吃'),
#   count    532
#   Name: (NAT, 吃), dtype: int64),
#  (('NAT', '接受'),
#   count    526
#   Name: (NAT, 接受), dtype: int64),
#  (('NAT', '需要'),
#   count    523
#   Name: (NAT, 需要), dtype: int64),
#  (('NAT', '出'),
#   count    501
#   Name: (NAT, 出), dtype: int64),
#  (('NAT', '宣布'),
#   count    501
#   Name: (NAT, 宣布), dtype: int64),
#  (('NAT', '提'),
#   count    495
#   Name: (NAT, 提), dtype: int64),
#  (('NAT', '要'),
#   count    492
#   Name: (NAT, 要), dtype: int64),
#  (('NAT', '以為'),
#   count    487
#   Name: (NAT, 以為), dtype: int64),
#  (('NAT', '想要'),
#   count    486
#   Name: (NAT, 想要), dtype: int64),
#  (('NAT', '執政'),
#   count    481
#   Name: (NAT, 執政), dtype: int64),
#  (('NAT', '轉載'),
#   count    466
#   Name: (NAT, 轉載), dtype: int64),
#  (('NAT', '說明'),
#   count    464
#   Name: (NAT, 說明), dtype: int64),
#  (('NAT', '指'),
#   count    452
#   Name: (NAT, 指), dtype: int64),
#  (('NAT', '上'),
#   count    451
#   Name: (NAT, 上), dtype: int64),
#  (('NAT', '少'),
#   count    444
#   Name: (NAT, 少), dtype: int64),
#  (('NAT', '增'),
#   count    435
#   Name: (NAT, 增), dtype: int64),
#  (('NAT', '討論'),
#   count    435
#   Name: (NAT, 討論), dtype: int64),
#  (('NAT', '變'),
#   count    426
#   Name: (NAT, 變), dtype: int64),
#  (('NAT', '使用'),
#   count    423
#   Name: (NAT, 使用), dtype: int64),
#  (('NAT', '主要'),
#   count    422
#   Name: (NAT, 主要), dtype: int64),
#  (('NAT', '寫'),
#   count    418
#   Name: (NAT, 寫), dtype: int64),
#  (('NAT', '發'),
#   count    418
#   Name: (NAT, 發), dtype: int64),
#  (('NAT', '代表'),
#   count    405
#   Name: (NAT, 代表), dtype: int64),
#  (('NAT', '結束'),
#   count    397
#   Name: (NAT, 結束), dtype: int64),
#  (('NAT', '承認'),
#   count    394
#   Name: (NAT, 承認), dtype: int64),
#  (('NAT', '公布'),
#   count    390
#   Name: (NAT, 公布), dtype: int64),
#  (('NAT', '帶'),
#   count    376
#   Name: (NAT, 帶), dtype: int64),
#  (('NAT', '選擇'),
#   count    373
#   Name: (NAT, 選擇), dtype: int64),
#  (('NAT', '喊'),
#   count    369
#   Name: (NAT, 喊), dtype: int64),
#  (('NAT', '無'),
#   count    358
#   Name: (NAT, 無), dtype: int64),
#  (('NAT', '透露'),
#   count    356
#   Name: (NAT, 透露), dtype: int64),
#  (('NAT', '走'),
#   count    355
#   Name: (NAT, 走), dtype: int64),
#  (('NAT', '小'),
#   count    353
#   Name: (NAT, 小), dtype: int64),
#  (('NAT', '選'),
#   count    352
#   Name: (NAT, 選), dtype: int64),
#  (('NAT', '規定'),
#   count    350
#   Name: (NAT, 規定), dtype: int64),
#  (('NAT', '分析'),
#   count    337
#   Name: (NAT, 分析), dtype: int64),
#  (('NAT', '一般'),
#   count    336
#   Name: (NAT, 一般), dtype: int64),
#  (('NAT', '佔'),
#   count    334
#   Name: (NAT, 佔), dtype: int64),
#  (('NAT', '分'),
#   count    332
#   Name: (NAT, 分), dtype: int64),
#  (('NAT', '夠'),
#   count    325
#   Name: (NAT, 夠), dtype: int64),
#  (('NAT', '告訴'),
#   count    323
#   Name: (NAT, 告訴), dtype: int64),
#  (('NAT', '包括'),
#   count    318
#   Name: (NAT, 包括), dtype: int64),
#  (('NAT', '公開'),
#   count    317
#   Name: (NAT, 公開), dtype: int64),
#  (('NAT', '回'),
#   count    314
#   Name: (NAT, 回), dtype: int64),
#  (('NAT', '玩'),
#   count    312
#   Name: (NAT, 玩), dtype: int64),
#  (('NAT', '舉行'),
#   count    310
#   Name: (NAT, 舉行), dtype: int64),
#  (('NAT', '減少'),
#   count    303
#   Name: (NAT, 減少), dtype: int64),
#  (('NAT', '不同'),
#   count    301
#   Name: (NAT, 不同), dtype: int64),
#  (('NAT', '花'),
#   count    301
#   Name: (NAT, 花), dtype: int64),
#  (('NAT', '月'),
#   count    294
#   Name: (NAT, 月), dtype: int64),
#  (('NAT', '辦'),
#   count    292
#   Name: (NAT, 辦), dtype: int64),
#  (('NAT', '面臨'),
#   count    291
#   Name: (NAT, 面臨), dtype: int64),
#  (('NAT', '參與'),
#   count    288
#   Name: (NAT, 參與), dtype: int64),
#  (('NAT', '這樣'),
#   count    282
#   Name: (NAT, 這樣), dtype: int64),
#  (('NAT', '公共'),
#   count    280
#   Name: (NAT, 公共), dtype: int64),
#  (('NAT', '成'),
#   count    280
#   Name: (NAT, 成), dtype: int64),
#  (('NAT', '減'),
#   count    276
#   Name: (NAT, 減), dtype: int64),
#  (('NAT', '成立'),
#   count    275
#   Name: (NAT, 成立), dtype: int64),
#  (('NAT', '暫停'),
#   count    275
#   Name: (NAT, 暫停), dtype: int64),
#  (('NAT', '面對'),
#   count    275
#   Name: (NAT, 面對), dtype: int64),
#  (('NAT', '收'),
#   count    273
#   Name: (NAT, 收), dtype: int64),
#  (('NAT', '聲請'),
#   count    270
#   Name: (NAT, 聲請), dtype: int64),
#  (('NAT', '處理'),
#   count    270
#   Name: (NAT, 處理), dtype: int64),
#  (('NAT', '來自'),
#   count    267
#   Name: (NAT, 來自), dtype: int64),
#  (('NAT', '解釋'),
#   count    267
#   Name: (NAT, 解釋), dtype: int64),
#  (('NAT', '占'),
#   count    266
#   Name: (NAT, 占), dtype: int64),
#  (('NAT', '擁有'),
#   count    265
#   Name: (NAT, 擁有), dtype: int64),
#  (('NAT', '達到'),
#   count    265
#   Name: (NAT, 達到), dtype: int64),
#  (('NAT', '記得'),
#   count    264
#   Name: (NAT, 記得), dtype: int64),
#  (('NAT', '出來'),
#   count    261
#   Name: (NAT, 出來), dtype: int64),
#  (('NAT', '發文'),
#   count    261
#   Name: (NAT, 發文), dtype: int64),
#  (('NAT', '不足'),
#   count    259
#   Name: (NAT, 不足), dtype: int64),
#  (('NAT', '參加'),
#   count    256
#   Name: (NAT, 參加), dtype: int64),
#  (('NAT', '清楚'),
#   count    254
#   Name: (NAT, 清楚), dtype: int64),
#  (('NAT', '屬於'),
#   count    250
#   Name: (NAT, 屬於), dtype: int64),
#  (('NAT', '召開'),
#   count    249
#   Name: (NAT, 召開), dtype: int64),
#  (('NAT', '跑'),
#   count    249
#   Name: (NAT, 跑), dtype: int64),
#  (('NAT', '挺'),
#   count    248
#   Name: (NAT, 挺), dtype: int64),
#  (('NAT', '曝光'),
#   count    248
#   Name: (NAT, 曝光), dtype: int64),
#  (('NAT', '查'),
#   count    247
#   Name: (NAT, 查), dtype: int64),
#  (('NAT', '在於'),
#   count    245
#   Name: (NAT, 在於), dtype: int64),
#  (('NAT', '賺'),
#   count    244
#   Name: (NAT, 賺), dtype: int64),
#  (('NAT', '下降'),
#   count    241
#   Name: (NAT, 下降), dtype: int64),
#  (('NAT', '直言'),
#   count    241
#   Name: (NAT, 直言), dtype: int64),
#  (('NAT', '準備'),
#   count    240
#   Name: (NAT, 準備), dtype: int64),
#  (('NAT', '判'),
#   count    238
#   Name: (NAT, 判), dtype: int64),
#  (('NAT', '沒辦法'),
#   count    235
#   Name: (NAT, 沒辦法), dtype: int64),
#  (('NAT', '偵辦'),
#   count    234
#   Name: (NAT, 偵辦), dtype: int64),
#  (('NAT', '長'),
#   count    233
#   Name: (NAT, 長), dtype: int64),
#  (('NAT', '快'),
#   count    231
#   Name: (NAT, 快), dtype: int64),
#  (('NAT', '包含'),
#   count    226
#   Name: (NAT, 包含), dtype: int64),
#  (('NAT', '擔任'),
#   count    222
#   Name: (NAT, 擔任), dtype: int64),
#  (('NAT', '帶來'),
#   count    221
#   Name: (NAT, 帶來), dtype: int64),
#  (('NAT', '特定'),
#   count    221
#   Name: (NAT, 特定), dtype: int64),
#  (('NAT', '維持'),
#   count    221
#   Name: (NAT, 維持), dtype: int64),
#  (('NAT', '利用'),
#   count    217
#   Name: (NAT, 利用), dtype: int64),
#  (('NAT', '改變'),
#   count    216
#   Name: (NAT, 改變), dtype: int64),
#  (('NAT', '證實'),
#   count    216
#   Name: (NAT, 證實), dtype: int64),
#  (('NAT', '遇到'),
#   count    216
#   Name: (NAT, 遇到), dtype: int64),
#  (('NAT', '知'),
#   count    215
#   Name: (NAT, 知), dtype: int64),
#  (('NAT', '重'),
#   count    212
#   Name: (NAT, 重), dtype: int64),
#  (('NAT', '換'),
#   count    210
#   Name: (NAT, 換), dtype: int64),
#  (('NAT', '發表'),
#   count    207
#   Name: (NAT, 發表), dtype: int64),
#  (('NAT', '轉'),
#   count    207
#   Name: (NAT, 轉), dtype: int64),
#  (('NAT', '進'),
#   count    207
#   Name: (NAT, 進), dtype: int64),
#  (('NAT', '適合'),
#   count    207
#   Name: (NAT, 適合), dtype: int64),
#  (('NAT', '取得'),
#   count    204
#   Name: (NAT, 取得), dtype: int64),
#  (('NAT', '批'),
#   count    204
#   Name: (NAT, 批), dtype: int64),
#  (('NAT', '投'),
#   count    201
#   Name: (NAT, 投), dtype: int64),
#  (('NAT', '貼'),
#   count    201
#   Name: (NAT, 貼), dtype: int64),
#  (('NAT', '抓'),
#   count    200
#   Name: (NAT, 抓), dtype: int64),
#  (('NAT', '提醒'),
#   count    200
#   Name: (NAT, 提醒), dtype: int64),
#  (('NAT', '認定'),
#   count    200
#   Name: (NAT, 認定), dtype: int64),
#  (('NAT', '笑死'),
#   count    199
#   Name: (NAT, 笑死), dtype: int64),
#  (('NAT', '高等'),
#   count    199
#   Name: (NAT, 高等), dtype: int64),
#  (('NAT', '算是'),
#   count    198
#   Name: (NAT, 算是), dtype: int64),
#  (('NAT', '站'),
#   count    197
#   Name: (NAT, 站), dtype: int64),
#  (('NAT', '上任'),
#   count    196
#   Name: (NAT, 上任), dtype: int64),
#  (('NAT', '蓋'),
#   count    196
#   Name: (NAT, 蓋), dtype: int64),
#  (('NAT', '推出'),
#   count    195
#   Name: (NAT, 推出), dtype: int64),
#  (('NAT', '主張'),
#   count    194
#   Name: (NAT, 主張), dtype: int64),
#  (('NAT', '差不多'),
#   count    194
#   Name: (NAT, 差不多), dtype: int64),
#  (('NAT', '住'),
#   count    193
#   Name: (NAT, 住), dtype: int64),
#  (('NAT', '開始'),
#   count    192
#   Name: (NAT, 開始), dtype: int64),
#  (('NAT', '剩'),
#   count    191
#   Name: (NAT, 剩), dtype: int64),
#  (('NAT', '當成'),
#   count    190
#   Name: (NAT, 當成), dtype: int64),
#  (('NAT', '獨立'),
#   count    189
#   Name: (NAT, 獨立), dtype: int64),
#  (('NAT', '出席'),
#   count    188
#   Name: (NAT, 出席), dtype: int64),
#  (('NAT', '改'),
#   count    188
#   Name: (NAT, 改), dtype: int64),
#  (('NAT', '裁定'),
#   count    188
#   Name: (NAT, 裁定), dtype: int64),
#  (('NAT', '提高'),
#   count    187
#   Name: (NAT, 提高), dtype: int64),
#  (('NAT', '理解'),
#   count    187
#   Name: (NAT, 理解), dtype: int64),
#  (('NAT', '詢問'),
#   count    187
#   Name: (NAT, 詢問), dtype: int64),
#  (('NAT', '原'),
#   count    183
#   Name: (NAT, 原), dtype: int64),
#  (('NAT', '得到'),
#   count    182
#   Name: (NAT, 得到), dtype: int64),
#  (('NAT', '上升'),
#   count    181
#   Name: (NAT, 上升), dtype: int64),
#  (('NAT', '做出'),
#   count    181
#   Name: (NAT, 做出), dtype: int64),
#  (('NAT', '控制'),
#   count    181
#   Name: (NAT, 控制), dtype: int64),
#  (('NAT', '拿到'),
#   count    180
#   Name: (NAT, 拿到), dtype: int64),
#  (('NAT', '看看'),
#   count    180
#   Name: (NAT, 看看), dtype: int64),
#  (('NAT', '認識'),
#   count    180
#   Name: (NAT, 認識), dtype: int64),
#  (('NAT', '預計'),
#   count    177
#   Name: (NAT, 預計), dtype: int64),
#  (('NAT', '投資'),
#   count    176
#   Name: (NAT, 投資), dtype: int64),
#  (('NAT', '提及'),
#   count    175
#   Name: (NAT, 提及), dtype: int64),
#  (('NAT', '見'),
#   count    175
#   Name: (NAT, 見), dtype: int64),
#  (('NAT', '考慮'),
#   count    174
#   Name: (NAT, 考慮), dtype: int64),
#  (('NAT', '申請'),
#   count    173
#   Name: (NAT, 申請), dtype: int64),
#  (('NAT', '聽到'),
#   count    172
#   Name: (NAT, 聽到), dtype: int64),
#  (('NAT', '收到'),
#   count    171
#   Name: (NAT, 收到), dtype: int64),
#  (('NAT', '好奇'),
#   count    170
#   Name: (NAT, 好奇), dtype: int64),
#  (('NAT', '攝'),
#   count    169
#   Name: (NAT, 攝), dtype: int64),
#  (('NAT', '赴'),
#   count    168
#   Name: (NAT, 赴), dtype: int64),
#  (('NAT', '關'),
#   count    168
#   Name: (NAT, 關), dtype: int64),
#  (('NAT', '統一'),
#   count    166
#   Name: (NAT, 統一), dtype: int64),
#  (('NAT', '掌握'),
#   count    165
#   Name: (NAT, 掌握), dtype: int64),
#  (('NAT', '談'),
#   count    165
#   Name: (NAT, 談), dtype: int64),
#  (('NAT', '投票'),
#   count    164
#   Name: (NAT, 投票), dtype: int64),
#  (('NAT', '了解'),
#   count    163
#   Name: (NAT, 了解), dtype: int64),
#  (('NAT', '加'),
#   count    163
#   Name: (NAT, 加), dtype: int64),
#  (('NAT', '明顯'),
#   count    163
#   Name: (NAT, 明顯), dtype: int64),
#  (('NAT', '等'),
#   count    162
#   Name: (NAT, 等), dtype: int64),
#  (('NAT', '創'),
#   count    160
#   Name: (NAT, 創), dtype: int64),
#  (('NAT', '國定'),
#   count    160
#   Name: (NAT, 國定), dtype: int64),
#  (('NAT', '學'),
#   count    160
#   Name: (NAT, 學), dtype: int64),
#  (('NAT', '爆發'),
#   count    159
#   Name: (NAT, 爆發), dtype: int64),
#  (('NAT', '連結'),
#   count    159
#   Name: (NAT, 連結), dtype: int64),
#  (('NAT', '回來'),
#   count    158
#   Name: (NAT, 回來), dtype: int64),
#  (('NAT', '採用'),
#   count    158
#   Name: (NAT, 採用), dtype: int64),
#  (('NAT', '遵守'),
#   count    157
#   Name: (NAT, 遵守), dtype: int64),
#  (('NAT', '回答'),
#   count    156
#   Name: (NAT, 回答), dtype: int64),
#  (('NAT', '停止'),
#   count    155
#   Name: (NAT, 停止), dtype: int64),
#  (('NAT', '涉及'),
#   count    155
#   Name: (NAT, 涉及), dtype: int64),
#  (('NAT', '準備好'),
#   count    155
#   Name: (NAT, 準備好), dtype: int64),
#  (('NAT', '降低'),
#   count    154
#   Name: (NAT, 降低), dtype: int64),
#  (('NAT', '屬'),
#   count    152
#   Name: (NAT, 屬), dtype: int64),
#  (('NAT', '繳'),
#   count    152
#   Name: (NAT, 繳), dtype: int64),
#  (('NAT', '高達'),
#   count    151
#   Name: (NAT, 高達), dtype: int64),
#  (('NAT', '紅'),
#   count    149
#   Name: (NAT, 紅), dtype: int64),
#  (('NAT', '找到'),
#   count    148
#   Name: (NAT, 找到), dtype: int64),
#  (('NAT', '作為'),
#   count    146
#   Name: (NAT, 作為), dtype: int64),
#  (('NAT', '歲'),
#   count    146
#   Name: (NAT, 歲), dtype: int64),
#  (('NAT', '重視'),
#   count    145
#   Name: (NAT, 重視), dtype: int64),
#  (('NAT', '感覺'),
#   count    144
#   Name: (NAT, 感覺), dtype: int64),
#  (('NAT', '發動'),
#   count    144
#   Name: (NAT, 發動), dtype: int64),
#  (('NAT', '出爐'),
#   count    143
#   Name: (NAT, 出爐), dtype: int64),
#  (('NAT', '張貼'),
#   count    143
#   Name: (NAT, 張貼), dtype: int64),
#  (('NAT', '久'),
#   count    142
#   Name: (NAT, 久), dtype: int64),
#  (('NAT', '提案'),
#   count    142
#   Name: (NAT, 提案), dtype: int64),
#  (('NAT', '雙重'),
#   count    142
#   Name: (NAT, 雙重), dtype: int64),
#  (('NAT', '認'),
#   count    141
#   Name: (NAT, 認), dtype: int64),
#  (('NAT', '工作'),
#   count    140
#   Name: (NAT, 工作), dtype: int64),
#  (('NAT', '拍'),
#   count    140
#   Name: (NAT, 拍), dtype: int64),
#  (('NAT', '當作'),
#   count    140
#   Name: (NAT, 當作), dtype: int64),
#  (('NAT', '上班'),
#   count    138
#   Name: (NAT, 上班), dtype: int64),
#  (('NAT', '執行'),
#   count    137
#   Name: (NAT, 執行), dtype: int64),
#  (('NAT', '視為'),
#   count    137
#   Name: (NAT, 視為), dtype: int64),
#  (('NAT', '進口'),
#   count    137
#   Name: (NAT, 進口), dtype: int64),
#  (('NAT', '傳'),
#   count    136
#   Name: (NAT, 傳), dtype: int64),
#  (('NAT', '在乎'),
#   count    136
#   Name: (NAT, 在乎), dtype: int64),
#  (('NAT', '天'),
#   count    136
#   Name: (NAT, 天), dtype: int64),
#  (('NAT', '納入'),
#   count    135
#   Name: (NAT, 納入), dtype: int64),
#  (('NAT', '使'),
#   count    134
#   Name: (NAT, 使), dtype: int64),
#  (('NAT', '列為'),
#   count    134
#   Name: (NAT, 列為), dtype: int64),
#  (('NAT', '持續'),
#   count    134
#   Name: (NAT, 持續), dtype: int64),
#  (('NAT', '派'),
#   count    134
#   Name: (NAT, 派), dtype: int64),
#  (('NAT', '修法'),
#   count    133
#   Name: (NAT, 修法), dtype: int64),
#  (('NAT', '重申'),
#   count    133
#   Name: (NAT, 重申), dtype: int64),
#  (('NAT', '來到'),
#   count    132
#   Name: (NAT, 來到), dtype: int64),
#  (('NAT', '想到'),
#   count    132
#   Name: (NAT, 想到), dtype: int64),
#  (('NAT', '現任'),
#   count    132
#   Name: (NAT, 現任), dtype: int64),
#  (('NAT', '引述'),
#   count    131
#   Name: (NAT, 引述), dtype: int64),
#  (('NAT', '注意'),
#   count    131
#   Name: (NAT, 注意), dtype: int64),
#  (('NAT', '外籍'),
#   count    130
#   Name: (NAT, 外籍), dtype: int64),
#  (('NAT', '洗'),
#   count    130
#   Name: (NAT, 洗), dtype: int64),
#  (('NAT', '留言'),
#   count    130
#   Name: (NAT, 留言), dtype: int64),
#  (('NAT', '配合'),
#   count    130
#   Name: (NAT, 配合), dtype: int64),
#  (('NAT', '統治'),
#   count    129
#   Name: (NAT, 統治), dtype: int64),
#  (('NAT', '猜'),
#   count    128
#   Name: (NAT, 猜), dtype: int64),
#  (('NAT', '設'),
#   count    128
#   Name: (NAT, 設), dtype: int64),
#  (('NAT', '安排'),
#   count    127
#   Name: (NAT, 安排), dtype: int64),
#  (('NAT', '解散'),
#   count    127
#   Name: (NAT, 解散), dtype: int64),
#  (('NAT', '讀'),
#   count    127
#   Name: (NAT, 讀), dtype: int64),
#  (('NAT', '教'),
#   count    126
#   Name: (NAT, 教), dtype: int64),
#  (('NAT', '登陸'),
#   count    126
#   Name: (NAT, 登陸), dtype: int64),
#  (('NAT', '預測'),
#   count    126
#   Name: (NAT, 預測), dtype: int64),
#  (('NAT', '領'),
#   count    126
#   Name: (NAT, 領), dtype: int64),
#  (('NAT', '接近'),
#   count    125
#   Name: (NAT, 接近), dtype: int64),
#  (('NAT', '國有'),
#   count    124
#   Name: (NAT, 國有), dtype: int64),
#  (('NAT', '定'),
#   count    124
#   Name: (NAT, 定), dtype: int64),
#  (('NAT', '忘'),
#   count    124
#   Name: (NAT, 忘), dtype: int64),
#  (('NAT', '搭'),
#   count    124
#   Name: (NAT, 搭), dtype: int64),
#  (('NAT', '坦言'),
#   count    122
#   Name: (NAT, 坦言), dtype: int64),
#  (('NAT', '酸'),
#   count    122
#   Name: (NAT, 酸), dtype: int64),
#  (('NAT', '加強'),
#   count    121
#   Name: (NAT, 加強), dtype: int64),
#  (('NAT', '有限'),
#   count    121
#   Name: (NAT, 有限), dtype: int64),
#  (('NAT', '現行'),
#   count    120
#   Name: (NAT, 現行), dtype: int64),
#  (('NAT', '判決'),
#   count    119
#   Name: (NAT, 判決), dtype: int64),
#  (('NAT', '拿來'),
#   count    119
#   Name: (NAT, 拿來), dtype: int64),
#  (('NAT', '試圖'),
#   count    119
#   Name: (NAT, 試圖), dtype: int64),
#  (('NAT', '看過'),
#   count    118
#   Name: (NAT, 看過), dtype: int64),
#  (('NAT', '通知'),
#   count    118
#   Name: (NAT, 通知), dtype: int64),
#  (('NAT', '離開'),
#   count    118
#   Name: (NAT, 離開), dtype: int64),
#  (('NAT', '畢業'),
#   count    117
#   Name: (NAT, 畢業), dtype: int64),
#  (('NAT', '剩下'),
#   count    116
#   Name: (NAT, 剩下), dtype: int64),
#  (('NAT', '合理'),
#   count    116
#   Name: (NAT, 合理), dtype: int64),
#  (('NAT', '喊話'),
#   count    116
#   Name: (NAT, 喊話), dtype: int64),
#  (('NAT', '比'),
#   count    116
#   Name: (NAT, 比), dtype: int64),
#  (('NAT', '破'),
#   count    115
#   Name: (NAT, 破), dtype: int64),
#  (('NAT', '穿'),
#   count    115
#   Name: (NAT, 穿), dtype: int64),
#  (('NAT', '打臉'),
#   count    114
#   Name: (NAT, 打臉), dtype: int64),
#  (('NAT', '接'),
#   count    114
#   Name: (NAT, 接), dtype: int64),
#  (('NAT', '更新'),
#   count    114
#   Name: (NAT, 更新), dtype: int64),
#  (('NAT', '結婚'),
#   count    114
#   Name: (NAT, 結婚), dtype: int64),
#  (('NAT', '降'),
#   count    114
#   Name: (NAT, 降), dtype: int64),
#  (('NAT', '低於'),
#   count    113
#   Name: (NAT, 低於), dtype: int64),
#  (('NAT', '公告'),
#   count    113
#   Name: (NAT, 公告), dtype: int64),
#  (('NAT', '拉'),
#   count    113
#   Name: (NAT, 拉), dtype: int64),
#  (('NAT', '拿去'),
#   count    113
#   Name: (NAT, 拿去), dtype: int64),
#  (('NAT', '採取'),
#   count    113
#   Name: (NAT, 採取), dtype: int64),
#  (('NAT', '改成'),
#   count    112
#   Name: (NAT, 改成), dtype: int64),
#  (('NAT', '適用'),
#   count    112
#   Name: (NAT, 適用), dtype: int64),
#  (('NAT', '介入'),
#   count    111
#   Name: (NAT, 介入), dtype: int64),
#  (('NAT', '付'),
#   count    111
#   Name: (NAT, 付), dtype: int64),
#  (('NAT', '一定'),
#   count    110
#   Name: (NAT, 一定), dtype: int64),
#  (('NAT', '退出'),
#   count    110
#   Name: (NAT, 退出), dtype: int64),
#  (('NAT', '放假'),
#   count    109
#   Name: (NAT, 放假), dtype: int64),
#  (('NAT', '救'),
#   count    109
#   Name: (NAT, 救), dtype: int64),
#  (('NAT', '正常'),
#   count    109
#   Name: (NAT, 正常), dtype: int64),
#  (('NAT', '判定'),
#   count    108
#   Name: (NAT, 判定), dtype: int64),
#  (('NAT', '支援'),
#   count    108
#   Name: (NAT, 支援), dtype: int64),
#  (('NAT', '突破'),
#   count    108
#   Name: (NAT, 突破), dtype: int64),
#  (('NAT', '調整'),
#   count    108
#   Name: (NAT, 調整), dtype: int64),
#  (('NAT', '修正'),
#   count    107
#   Name: (NAT, 修正), dtype: int64),
#  (('NAT', '哭'),
#   count    107
#   Name: (NAT, 哭), dtype: int64),
#  (('NAT', '如何'),
#   count    107
#   Name: (NAT, 如何), dtype: int64),
#  (('NAT', '停'),
#   count    106
#   Name: (NAT, 停), dtype: int64),
#  (('NAT', '排'),
#   count    106
#   Name: (NAT, 排), dtype: int64),
#  (('NAT', '擋'),
#   count    106
#   Name: (NAT, 擋), dtype: int64),
#  (('NAT', '舉'),
#   count    106
#   Name: (NAT, 舉), dtype: int64),
#  (('NAT', '論'),
#   count    106
#   Name: (NAT, 論), dtype: int64),
#  (('NAT', '補充'),
#   count    105
#   Name: (NAT, 補充), dtype: int64),
#  (('NAT', '實施'),
#   count    104
#   Name: (NAT, 實施), dtype: int64),
#  (('NAT', '介紹'),
#   count    102
#   Name: (NAT, 介紹), dtype: int64),
#  (('NAT', '在意'),
#   count    101
#   Name: (NAT, 在意), dtype: int64),
#  (('NAT', '慢'),
#   count    101
#   Name: (NAT, 慢), dtype: int64),
#  (('NAT', '身為'),
#   count    101
#   Name: (NAT, 身為), dtype: int64),
#  (('NAT', '前往'),
#   count    100
#   Name: (NAT, 前往), dtype: int64),
#  (('NAT', '展開'),
#   count    100
#   Name: (NAT, 展開), dtype: int64),
#  (('NAT', '審查'),
#   count    99
#   Name: (NAT, 審查), dtype: int64),
#  (('NAT', '有關'),
#   count    99
#   Name: (NAT, 有關), dtype: int64),
#  (('NAT', '啟動'),
#   count    98
#   Name: (NAT, 啟動), dtype: int64),
#  (('NAT', '回歸'),
#   count    98
#   Name: (NAT, 回歸), dtype: int64),
#  (('NAT', '報告'),
#   count    98
#   Name: (NAT, 報告), dtype: int64),
#  (('NAT', '高階'),
#   count    98
#   Name: (NAT, 高階), dtype: int64),
#  (('NAT', '採'),
#   count    97
#   Name: (NAT, 採), dtype: int64),
#  (('NAT', '數位'),
#   count    97
#   Name: (NAT, 數位), dtype: int64),
#  (('NAT', '留在'),
#   count    97
#   Name: (NAT, 留在), dtype: int64),
#  (('NAT', '發出'),
#   count    96
#   Name: (NAT, 發出), dtype: int64),
#  (('NAT', '做好'),
#   count    95
#   Name: (NAT, 做好), dtype: int64),
#  (('NAT', '跑去'),
#   count    95
#   Name: (NAT, 跑去), dtype: int64),
#  (('NAT', '高於'),
#   count    95
#   Name: (NAT, 高於), dtype: int64),
#  (('NAT', '經營'),
#   count    94
#   Name: (NAT, 經營), dtype: int64),
#  (('NAT', '設立'),
#   count    94
#   Name: (NAT, 設立), dtype: int64),
#  (('NAT', '發電'),
#   count    93
#   Name: (NAT, 發電), dtype: int64),
#  (('NAT', '電'),
#   count    93
#   Name: (NAT, 電), dtype: int64),
#  (('NAT', '下'),
#   count    92
#   Name: (NAT, 下), dtype: int64),
#  (('NAT', '現有'),
#   count    92
#   Name: (NAT, 現有), dtype: int64),
#  (('NAT', '補助'),
#   count    92
#   Name: (NAT, 補助), dtype: int64),
#  (('NAT', '辦理'),
#   count    92
#   Name: (NAT, 辦理), dtype: int64),
#  (('NAT', '做到'),
#   count    91
#   Name: (NAT, 做到), dtype: int64),
#  (('NAT', '優先'),
#   count    91
#   Name: (NAT, 優先), dtype: int64),
#  (('NAT', '具'),
#   count    91
#   Name: (NAT, 具), dtype: int64),
#  (('NAT', '怎樣'),
#   count    91
#   Name: (NAT, 怎樣), dtype: int64),
#  (('NAT', '承擔'),
#   count    91
#   Name: (NAT, 承擔), dtype: int64),
#  (('NAT', '經歷'),
#   count    91
#   Name: (NAT, 經歷), dtype: int64),
#  (('NAT', '經過'),
#   count    91
#   Name: (NAT, 經過), dtype: int64),
#  (('NAT', '美元'),
#   count    91
#   Name: (NAT, 美元), dtype: int64),
#  (('NAT', '運用'),
#   count    91
#   Name: (NAT, 運用), dtype: int64),
#  (('NAT', '合法'),
#   count    90
#   Name: (NAT, 合法), dtype: int64),
#  (('NAT', '大於'),
#   count    90
#   Name: (NAT, 大於), dtype: int64),
#  (('NAT', '年'),
#   count    90
#   Name: (NAT, 年), dtype: int64),
#  (('NAT', '集中'),
#   count    90
#   Name: (NAT, 集中), dtype: int64),
#  (('NAT', '思考'),
#   count    89
#   Name: (NAT, 思考), dtype: int64),
#  (('NAT', '想像'),
#   count    89
#   Name: (NAT, 想像), dtype: int64),
#  (('NAT', '推進'),
#   count    89
#   Name: (NAT, 推進), dtype: int64),
#  (('NAT', '監督'),
#   count    89
#   Name: (NAT, 監督), dtype: int64),
#  (('NAT', '賣給'),
#   count    89
#   Name: (NAT, 賣給), dtype: int64),
#  (('NAT', '漲價'),
#   count    88
#   Name: (NAT, 漲價), dtype: int64),
#  (('NAT', '發起'),
#   count    88
#   Name: (NAT, 發起), dtype: int64),
#  (('NAT', '入'),
#   count    87
#   Name: (NAT, 入), dtype: int64),
#  (('NAT', '現身'),
#   count    87
#   Name: (NAT, 現身), dtype: int64),
#  (('NAT', '生產'),
#   count    87
#   Name: (NAT, 生產), dtype: int64),
#  (('NAT', '綜合'),
#   count    87
#   Name: (NAT, 綜合), dtype: int64),
#  (('NAT', '坐'),
#   count    86
#   Name: (NAT, 坐), dtype: int64),
#  (('NAT', '報'),
#   count    86
#   Name: (NAT, 報), dtype: int64),
#  (('NAT', '後續'),
#   count    86
#   Name: (NAT, 後續), dtype: int64),
#  (('NAT', '藏'),
#   count    86
#   Name: (NAT, 藏), dtype: int64),
#  (('NAT', '出國'),
#   count    85
#   Name: (NAT, 出國), dtype: int64),
#  (('NAT', '呈現'),
#   count    85
#   Name: (NAT, 呈現), dtype: int64),
#  (('NAT', '行'),
#   count    85
#   Name: (NAT, 行), dtype: int64),
#  (('NAT', '衝'),
#   count    85
#   Name: (NAT, 衝), dtype: int64),
#  (('NAT', '設定'),
#   count    85
#   Name: (NAT, 設定), dtype: int64),
#  (('NAT', '上市'),
#   count    84
#   Name: (NAT, 上市), dtype: int64),
#  (('NAT', '無罪'),
#   count    84
#   Name: (NAT, 無罪), dtype: int64),
#  (('NAT', '規劃'),
#   count    84
#   Name: (NAT, 規劃), dtype: int64),
#  (('NAT', '釋憲'),
#   count    84
#   Name: (NAT, 釋憲), dtype: int64),
#  (('NAT', '限制'),
#   count    84
#   Name: (NAT, 限制), dtype: int64),
#  (('NAT', '打算'),
#   count    83
#   Name: (NAT, 打算), dtype: int64),
#  (('NAT', '檢討'),
#   count    83
#   Name: (NAT, 檢討), dtype: int64),
#  (('NAT', '翻攝'),
#   count    83
#   Name: (NAT, 翻攝), dtype: int64),
#  (('NAT', '起'),
#   count    83
#   Name: (NAT, 起), dtype: int64),
#  (('NAT', '小心'),
#   count    82
#   Name: (NAT, 小心), dtype: int64),
#  (('NAT', '拿出來'),
#   count    82
#   Name: (NAT, 拿出來), dtype: int64),
#  (('NAT', '掛'),
#   count    82
#   Name: (NAT, 掛), dtype: int64),
#  (('NAT', '炒'),
#   count    82
#   Name: (NAT, 炒), dtype: int64),
#  (('NAT', '研究'),
#   count    82
#   Name: (NAT, 研究), dtype: int64),
#  (('NAT', '重大'),
#   count    82
#   Name: (NAT, 重大), dtype: int64),
#  (('NAT', '回到'),
#   count    81
#   Name: (NAT, 回到), dtype: int64),
#  (('NAT', '度'),
#   count    81
#   Name: (NAT, 度), dtype: int64),
#  (('NAT', '恢復'),
#   count    81
#   Name: (NAT, 恢復), dtype: int64),
#  (('NAT', '最終'),
#   count    81
#   Name: (NAT, 最終), dtype: int64),
#  (('NAT', '美'),
#   count    81
#   Name: (NAT, 美), dtype: int64),
#  (('NAT', '飛'),
#   count    81
#   Name: (NAT, 飛), dtype: int64),
#  (('NAT', '下令'),
#   count    80
#   Name: (NAT, 下令), dtype: int64),
#  (('NAT', '打電話'),
#   count    80
#   Name: (NAT, 打電話), dtype: int64),
#  (('NAT', '過去'),
#   count    80
#   Name: (NAT, 過去), dtype: int64),
#  (('NAT', '完蛋'),
#   count    79
#   Name: (NAT, 完蛋), dtype: int64),
#  (('NAT', '貼出'),
#   count    79
#   Name: (NAT, 貼出), dtype: int64),
#  (('NAT', '回覆'),
#   count    78
#   Name: (NAT, 回覆), dtype: int64),
#  (('NAT', '學習'),
#   count    78
#   Name: (NAT, 學習), dtype: int64),
#  (('NAT', '接獲'),
#   count    78
#   Name: (NAT, 接獲), dtype: int64),
#  (('NAT', '穩'),
#   count    78
#   Name: (NAT, 穩), dtype: int64),
#  (('NAT', '追'),
#   count    78
#   Name: (NAT, 追), dtype: int64),
#  (('NAT', '單一'),
#   count    77
#   Name: (NAT, 單一), dtype: int64),
#  (('NAT', '審理'),
#   count    77
#   Name: (NAT, 審理), dtype: int64),
#  (('NAT', '留'),
#   count    77
#   Name: (NAT, 留), dtype: int64),
#  (('NAT', '賺錢'),
#   count    77
#   Name: (NAT, 賺錢), dtype: int64),
#  (('NAT', '追問'),
#   count    77
#   Name: (NAT, 追問), dtype: int64),
#  (('NAT', '運作'),
#   count    77
#   Name: (NAT, 運作), dtype: int64),
#  (('NAT', '公平'),
#   count    76
#   Name: (NAT, 公平), dtype: int64),
#  (('NAT', '戴'),
#   count    76
#   Name: (NAT, 戴), dtype: int64),
#  (('NAT', '排名'),
#   count    76
#   Name: (NAT, 排名), dtype: int64),
#  (('NAT', '提名'),
#   count    76
#   Name: (NAT, 提名), dtype: int64),
#  (('NAT', '歸'),
#   count    76
#   Name: (NAT, 歸), dtype: int64),
#  (('NAT', '聯繫'),
#   count    76
#   Name: (NAT, 聯繫), dtype: int64),
#  (('NAT', '訪問'),
#   count    76
#   Name: (NAT, 訪問), dtype: int64),
#  (('NAT', '逾'),
#   count    76
#   Name: (NAT, 逾), dtype: int64),
#  (('NAT', '選上'),
#   count    76
#   Name: (NAT, 選上), dtype: int64),
#  (('NAT', '奇怪'),
#   count    75
#   Name: (NAT, 奇怪), dtype: int64),
#  (('NAT', '拿出'),
#   count    75
#   Name: (NAT, 拿出), dtype: int64),
#  (('NAT', '處於'),
#   count    75
#   Name: (NAT, 處於), dtype: int64),
#  (('NAT', '幫'),
#   count    74
#   Name: (NAT, 幫), dtype: int64),
#  (('NAT', '延長'),
#   count    74
#   Name: (NAT, 延長), dtype: int64),
#  (('NAT', '形成'),
#   count    74
#   Name: (NAT, 形成), dtype: int64),
#  (('NAT', '排除'),
#   count    74
#   Name: (NAT, 排除), dtype: int64),
#  (('NAT', '溝通'),
#   count    74
#   Name: (NAT, 溝通), dtype: int64),
#  (('NAT', '編列'),
#   count    74
#   Name: (NAT, 編列), dtype: int64),
#  (('NAT', '設計'),
#   count    74
#   Name: (NAT, 設計), dtype: int64),
#  (('NAT', '保障'),
#   count    73
#   Name: (NAT, 保障), dtype: int64),
#  (('NAT', '公里'),
#   count    73
#   Name: (NAT, 公里), dtype: int64),
#  (('NAT', '喝'),
#   count    73
#   Name: (NAT, 喝), dtype: int64),
#  (('NAT', '安安'),
#   count    73
#   Name: (NAT, 安安), dtype: int64),
#  (('NAT', '複雜'),
#   count    73
#   Name: (NAT, 複雜), dtype: int64),
#  (('NAT', '訪'),
#   count    73
#   Name: (NAT, 訪), dtype: int64),
#  (('NAT', '出身'),
#   count    72
#   Name: (NAT, 出身), dtype: int64),
#  (('NAT', '壓'),
#   count    72
#   Name: (NAT, 壓), dtype: int64),
#  (('NAT', '弄'),
#   count    72
#   Name: (NAT, 弄), dtype: int64),
#  (('NAT', '理'),
#   count    72
#   Name: (NAT, 理), dtype: int64),
#  (('NAT', '確認'),
#   count    72
#   Name: (NAT, 確認), dtype: int64),
#  (('NAT', '主持'),
#   count    71
#   Name: (NAT, 主持), dtype: int64),
#  (('NAT', '怎麼樣'),
#   count    71
#   Name: (NAT, 怎麼樣), dtype: int64),
#  (('NAT', '斷交'),
#   count    71
#   Name: (NAT, 斷交), dtype: int64),
#  (('NAT', '流行'),
#   count    71
#   Name: (NAT, 流行), dtype: int64),
#  (('NAT', '考量'),
#   count    71
#   Name: (NAT, 考量), dtype: int64),
#  (('NAT', '誇張'),
#   count    71
#   Name: (NAT, 誇張), dtype: int64),
#  (('NAT', '過半'),
#   count    71
#   Name: (NAT, 過半), dtype: int64),
#  (('NAT', '降至'),
#   count    71
#   Name: (NAT, 降至), dtype: int64),
#  (('NAT', '上訴'),
#   count    70
#   Name: (NAT, 上訴), dtype: int64),
#  (('NAT', '打成'),
#   count    70
#   Name: (NAT, 打成), dtype: int64),
#  (('NAT', '給予'),
#   count    70
#   Name: (NAT, 給予), dtype: int64),
#  (('NAT', '習慣'),
#   count    70
#   Name: (NAT, 習慣), dtype: int64),
#  (('NAT', '一致'),
#   count    69
#   Name: (NAT, 一致), dtype: int64),
#  (('NAT', '告知'),
#   count    69
#   Name: (NAT, 告知), dtype: int64),
#  (('NAT', '實現'),
#   count    69
#   Name: (NAT, 實現), dtype: int64),
#  (('NAT', '成佛'),
#   count    69
#   Name: (NAT, 成佛), dtype: int64),
#  (('NAT', '持'),
#   count    69
#   Name: (NAT, 持), dtype: int64),
#  (('NAT', '處'),
#   count    69
#   Name: (NAT, 處), dtype: int64),
#  (('NAT', '計算'),
#   count    69
#   Name: (NAT, 計算), dtype: int64),
#  (('NAT', '調漲'),
#   count    69
#   Name: (NAT, 調漲), dtype: int64),
#  (('NAT', '起跳'),
#   count    69
#   Name: (NAT, 起跳), dtype: int64),
#  (('NAT', '辛苦'),
#   count    69
#   Name: (NAT, 辛苦), dtype: int64),
#  (('NAT', '隸屬'),
#   count    69
#   Name: (NAT, 隸屬), dtype: int64),
#  (('NAT', '需'),
#   count    69
#   Name: (NAT, 需), dtype: int64),
#  (('NAT', '領導'),
#   count    69
#   Name: (NAT, 領導), dtype: int64),
#  (('NAT', '含'),
#   count    68
#   Name: (NAT, 含), dtype: int64),
#  (('NAT', '牽'),
#   count    68
#   Name: (NAT, 牽), dtype: int64),
#  (('NAT', '稱為'),
#   count    68
#   Name: (NAT, 稱為), dtype: int64),
#  (('NAT', '談到'),
#   count    68
#   Name: (NAT, 談到), dtype: int64),
#  (('NAT', '交給'),
#   count    67
#   Name: (NAT, 交給), dtype: int64),
#  (('NAT', '付出'),
#   count    67
#   Name: (NAT, 付出), dtype: int64),
#  (('NAT', '列'),
#   count    67
#   Name: (NAT, 列), dtype: int64),
#  (('NAT', '列入'),
#   count    67
#   Name: (NAT, 列入), dtype: int64),
#  (('NAT', '動員'),
#   count    67
#   Name: (NAT, 動員), dtype: int64),
#  (('NAT', '操作'),
#   count    67
#   Name: (NAT, 操作), dtype: int64),
#  (('NAT', '法定'),
#   count    67
#   Name: (NAT, 法定), dtype: int64),
#  (('NAT', '短'),
#   count    67
#   Name: (NAT, 短), dtype: int64),
#  (('NAT', '近'),
#   count    67
#   Name: (NAT, 近), dtype: int64),
#  (('NAT', '重返'),
#   count    67
#   Name: (NAT, 重返), dtype: int64),
#  (('NAT', '集結'),
#   count    67
#   Name: (NAT, 集結), dtype: int64),
#  (('NAT', '動'),
#   count    66
#   Name: (NAT, 動), dtype: int64),
#  (('NAT', '完整'),
#   count    66
#   Name: (NAT, 完整), dtype: int64),
#  (('NAT', '打過來'),
#   count    66
#   Name: (NAT, 打過來), dtype: int64),
#  (('NAT', '接到'),
#   count    66
#   Name: (NAT, 接到), dtype: int64),
#  (('NAT', '撐'),
#   count    66
#   Name: (NAT, 撐), dtype: int64),
#  (('NAT', '支付'),
#   count    66
#   Name: (NAT, 支付), dtype: int64),
#  (('NAT', '聽說'),
#   count    66
#   Name: (NAT, 聽說), dtype: int64),
#  (('NAT', '負'),
#   count    66
#   Name: (NAT, 負), dtype: int64),
#  (('NAT', '購買'),
#   count    66
#   Name: (NAT, 購買), dtype: int64),
#  (('NAT', '通'),
#   count    66
#   Name: (NAT, 通), dtype: int64),
#  (('NAT', '雙邊'),
#   count    66
#   Name: (NAT, 雙邊), dtype: int64),
#  (('NAT', '可以'),
#   count    65
#   Name: (NAT, 可以), dtype: int64),
#  (('NAT', '形容'),
#   count    65
#   Name: (NAT, 形容), dtype: int64),
#  (('NAT', '意味'),
#   count    65
#   Name: (NAT, 意味), dtype: int64),
#  (('NAT', '拆'),
#   count    65
#   Name: (NAT, 拆), dtype: int64),
#  (('NAT', '無關'),
#   count    65
#   Name: (NAT, 無關), dtype: int64),
#  (('NAT', '熟'),
#   count    65
#   Name: (NAT, 熟), dtype: int64),
#  (('NAT', '跟'),
#   count    65
#   Name: (NAT, 跟), dtype: int64),
#  (('NAT', '開發'),
#   count    65
#   Name: (NAT, 開發), dtype: int64),
#  (('NAT', '延續'),
#   count    64
#   Name: (NAT, 延續), dtype: int64),
#  (('NAT', '打到'),
#   count    64
#   Name: (NAT, 打到), dtype: int64),
#  (('NAT', '簽'),
#   count    64
#   Name: (NAT, 簽), dtype: int64),
#  (('NAT', '設置'),
#   count    64
#   Name: (NAT, 設置), dtype: int64),
#  (('NAT', '跳出來'),
#   count    64
#   Name: (NAT, 跳出來), dtype: int64),
#  (('NAT', '轉向'),
#   count    64
#   Name: (NAT, 轉向), dtype: int64),
#  (('NAT', '交'),
#   count    63
#   Name: (NAT, 交), dtype: int64),
#  (('NAT', '保留'),
#   count    63
#   Name: (NAT, 保留), dtype: int64),
#  (('NAT', '所屬'),
#   count    63
#   Name: (NAT, 所屬), dtype: int64),
#  (('NAT', '選舉'),
#   count    63
#   Name: (NAT, 選舉), dtype: int64),
#  (('NAT', '採訪'),
#   count    62
#   Name: (NAT, 採訪), dtype: int64),
#  (('NAT', '籲'),
#   count    62
#   Name: (NAT, 籲), dtype: int64),
#  (('NAT', '考'),
#   count    62
#   Name: (NAT, 考), dtype: int64),
#  (('NAT', '評估'),
#   count    62
#   Name: (NAT, 評估), dtype: int64),
#  (('NAT', '吸收'),
#   count    61
#   Name: (NAT, 吸收), dtype: int64),
#  (('NAT', '幻想'),
#   count    61
#   Name: (NAT, 幻想), dtype: int64),
#  (('NAT', '拿掉'),
#   count    61
#   Name: (NAT, 拿掉), dtype: int64),
#  (('NAT', '挑'),
#   count    61
#   Name: (NAT, 挑), dtype: int64),
#  (('NAT', '澄清'),
#   count    61
#   Name: (NAT, 澄清), dtype: int64),
#  (('NAT', '走向'),
#   count    61
#   Name: (NAT, 走向), dtype: int64),
#  (('NAT', '轉型'),
#   count    61
#   Name: (NAT, 轉型), dtype: int64),
#  (('NAT', '主導'),
#   count    60
#   Name: (NAT, 主導), dtype: int64),
#  (('NAT', '保'),
#   count    60
#   Name: (NAT, 保), dtype: int64),
#  (('NAT', '告'),
#   count    60
#   Name: (NAT, 告), dtype: int64),
#  (('NAT', '宣傳'),
#   count    60
#   Name: (NAT, 宣傳), dtype: int64),
#  (('NAT', '容易'),
#   count    60
#   Name: (NAT, 容易), dtype: int64),
#  (('NAT', '廢除'),
#   count    60
#   Name: (NAT, 廢除), dtype: int64),
#  (('NAT', '得'),
#   count    60
#   Name: (NAT, 得), dtype: int64),
#  (('NAT', '怎麼辦'),
#   count    60
#   Name: (NAT, 怎麼辦), dtype: int64),
#  (('NAT', '號稱'),
#   count    60
#   Name: (NAT, 號稱), dtype: int64),
#  (('NAT', '訂'),
#   count    60
#   Name: (NAT, 訂), dtype: int64),
#  (('NAT', '追蹤'),
#   count    60
#   Name: (NAT, 追蹤), dtype: int64),
#  (('NAT', '退'),
#   count    60
#   Name: (NAT, 退), dtype: int64),
#  (('NAT', '避免'),
#   count    60
#   Name: (NAT, 避免), dtype: int64),
#  (('NAT', '阻止'),
#   count    60
#   Name: (NAT, 阻止), dtype: int64),
#  (('NAT', '不斷'),
#   count    59
#   Name: (NAT, 不斷), dtype: int64),
#  (('NAT', '依賴'),
#   count    59
#   Name: (NAT, 依賴), dtype: int64),
#  (('NAT', '出門'),
#   count    59
#   Name: (NAT, 出門), dtype: int64),
#  (('NAT', '協商'),
#   count    59
#   Name: (NAT, 協商), dtype: int64),
#  (('NAT', '增強'),
#   count    59
#   Name: (NAT, 增強), dtype: int64),
#  (('NAT', '審'),
#   count    59
#   Name: (NAT, 審), dtype: int64),
#  (('NAT', '相關'),
#   count    59
#   Name: (NAT, 相關), dtype: int64),
#  (('NAT', '配'),
#   count    59
#   Name: (NAT, 配), dtype: int64),
#  (('NAT', '付錢'),
#   count    58
#   Name: (NAT, 付錢), dtype: int64),
#  (('NAT', '想想'),
#   count    58
#   Name: (NAT, 想想), dtype: int64),
#  (('NAT', '抵達'),
#   count    58
#   Name: (NAT, 抵達), dtype: int64),
#  (('NAT', '解除'),
#   count    58
#   Name: (NAT, 解除), dtype: int64),
#  (('NAT', '驚人'),
#   count    58
#   Name: (NAT, 驚人), dtype: int64),
#  (('NAT', '問到'),
#   count    57
#   Name: (NAT, 問到), dtype: int64),
#  (('NAT', '增長'),
#   count    57
#   Name: (NAT, 增長), dtype: int64),
#  (('NAT', '待'),
#   count    57
#   Name: (NAT, 待), dtype: int64),
#  (('NAT', '採購'),
#   count    57
#   Name: (NAT, 採購), dtype: int64),
#  (('NAT', '檢舉'),
#   count    57
#   Name: (NAT, 檢舉), dtype: int64),
#  (('NAT', '發揮'),
#   count    57
#   Name: (NAT, 發揮), dtype: int64),
#  (('NAT', '相同'),
#   count    57
#   Name: (NAT, 相同), dtype: int64),
#  (('NAT', '製作'),
#   count    57
#   Name: (NAT, 製作), dtype: int64),
#  (('NAT', '開出'),
#   count    57
#   Name: (NAT, 開出), dtype: int64),
#  (('NAT', '開票'),
#   count    57
#   Name: (NAT, 開票), dtype: int64),
#  (('NAT', '估計'),
#   count    56
#   Name: (NAT, 估計), dtype: int64),
#  (('NAT', '分成'),
#   count    56
#   Name: (NAT, 分成), dtype: int64),
#  (('NAT', '改為'),
#   count    56
#   Name: (NAT, 改為), dtype: int64),
#  (('NAT', '明白'),
#   count    56
#   Name: (NAT, 明白), dtype: int64),
#  (('NAT', '用來'),
#   count    56
#   Name: (NAT, 用來), dtype: int64),
#  (('NAT', '用於'),
#   count    56
#   Name: (NAT, 用於), dtype: int64),
#  (('NAT', '真正'),
#   count    56
#   Name: (NAT, 真正), dtype: int64),
#  (('NAT', '轟'),
#   count    56
#   Name: (NAT, 轟), dtype: int64),
#  (('NAT', '開打'),
#   count    56
#   Name: (NAT, 開打), dtype: int64),
#  (('NAT', '中'),
#   count    55
#   Name: (NAT, 中), dtype: int64),
#  (('NAT', '合'),
#   count    55
#   Name: (NAT, 合), dtype: int64),
#  (('NAT', '完'),
#   count    55
#   Name: (NAT, 完), dtype: int64),
#  (('NAT', '指定'),
#   count    55
#   Name: (NAT, 指定), dtype: int64),
#  (('NAT', '指揮'),
#   count    55
#   Name: (NAT, 指揮), dtype: int64),
#  (('NAT', '相反'),
#   count    55
#   Name: (NAT, 相反), dtype: int64),
#  (('NAT', '落幕'),
#   count    55
#   Name: (NAT, 落幕), dtype: int64),
#  (('NAT', '設廠'),
#   count    55
#   Name: (NAT, 設廠), dtype: int64),
#  (('NAT', '跑到'),
#   count    55
#   Name: (NAT, 跑到), dtype: int64),
#  (('NAT', '連鎖'),
#   count    55
#   Name: (NAT, 連鎖), dtype: int64),
#  (('NAT', '遇'),
#   count    55
#   Name: (NAT, 遇), dtype: int64),
#  (('NAT', '類似'),
#   count    55
#   Name: (NAT, 類似), dtype: int64),
#  (('NAT', '反應'),
#   count    54
#   Name: (NAT, 反應), dtype: int64),
#  (('NAT', '排審'),
#   count    54
#   Name: (NAT, 排審), dtype: int64),
#  (('NAT', '機動'),
#   count    54
#   Name: (NAT, 機動), dtype: int64),
#  (('NAT', '來臨'),
#   count    53
#   Name: (NAT, 來臨), dtype: int64),
#  (('NAT', '優於'),
#   count    53
#   Name: (NAT, 優於), dtype: int64),
#  (('NAT', '打開'),
#   count    53
#   Name: (NAT, 打開), dtype: int64),
#  (('NAT', '欠'),
#   count    53
#   Name: (NAT, 欠), dtype: int64),
#  (('NAT', '比較'),
#   count    53
#   Name: (NAT, 比較), dtype: int64),
#  (('NAT', '盼'),
#   count    53
#   Name: (NAT, 盼), dtype: int64),
#  (('NAT', '編'),
#   count    53
#   Name: (NAT, 編), dtype: int64),
#  (('NAT', '賦予'),
#   count    53
#   Name: (NAT, 賦予), dtype: int64),
#  (('NAT', '龐大'),
#   count    53
#   Name: (NAT, 龐大), dtype: int64),
#  (('NAT', '上演'),
#   count    52
#   Name: (NAT, 上演), dtype: int64),
#  (('NAT', '公佈'),
#   count    52
#   Name: (NAT, 公佈), dtype: int64),
#  (('NAT', '分配'),
#   count    52
#   Name: (NAT, 分配), dtype: int64),
#  (('NAT', '判斷'),
#   count    52
#   Name: (NAT, 判斷), dtype: int64),
#  (('NAT', '勸'),
#   count    52
#   Name: (NAT, 勸), dtype: int64),
#  (('NAT', '包'),
#   count    52
#   Name: (NAT, 包), dtype: int64),
#  (('NAT', '回饋'),
#   count    52
#   Name: (NAT, 回饋), dtype: int64),
#  (('NAT', '填'),
#   count    52
#   Name: (NAT, 填), dtype: int64),
#  (('NAT', '念'),
#   count    52
#   Name: (NAT, 念), dtype: int64),
#  (('NAT', '拚'),
#   count    52
#   Name: (NAT, 拚), dtype: int64),
#  (('NAT', '換成'),
#   count    52
#   Name: (NAT, 換成), dtype: int64),
#  (('NAT', '整理'),
#   count    52
#   Name: (NAT, 整理), dtype: int64),
#  (('NAT', '滲透'),
#   count    52
#   Name: (NAT, 滲透), dtype: int64),
#  (('NAT', '說說'),
#   count    52
#   Name: (NAT, 說說), dtype: int64),
#  (('NAT', '買單'),
#   count    52
#   Name: (NAT, 買單), dtype: int64),
#  (('NAT', '陪'),
#   count    52
#   Name: (NAT, 陪), dtype: int64),
#  (('NAT', '額外'),
#   count    52
#   Name: (NAT, 額外), dtype: int64),
#  (('NAT', '一模一樣'),
#   count    51
#   Name: (NAT, 一模一樣), dtype: int64),
#  (('NAT', '供'),
#   count    51
#   Name: (NAT, 供), dtype: int64),
#  (('NAT', '出口'),
#   count    51
#   Name: (NAT, 出口), dtype: int64),
#  (('NAT', '分立'),
#   count    51
#   Name: (NAT, 分立), dtype: int64),
#  (('NAT', '力挺'),
#   count    51
#   Name: (NAT, 力挺), dtype: int64),
#  (('NAT', '宣佈'),
#   count    51
#   Name: (NAT, 宣佈), dtype: int64),
#  (('NAT', '指示'),
#   count    51
#   Name: (NAT, 指示), dtype: int64),
#  (('NAT', '授權'),
#   count    51
#   Name: (NAT, 授權), dtype: int64),
#  (('NAT', '熟悉'),
#   count    51
#   Name: (NAT, 熟悉), dtype: int64),
#  (('NAT', '爆出'),
#   count    51
#   Name: (NAT, 爆出), dtype: int64),
#  (('NAT', '看待'),
#   count    51
#   Name: (NAT, 看待), dtype: int64),
#  (('NAT', '規範'),
#   count    51
#   Name: (NAT, 規範), dtype: int64),
#  (('NAT', '轉移到'),
#   count    51
#   Name: (NAT, 轉移到), dtype: int64),
#  (('NAT', '呼'),
#   count    50
#   Name: (NAT, 呼), dtype: int64),
#  (('NAT', '崛起'),
#   count    50
#   Name: (NAT, 崛起), dtype: int64),
#  (('NAT', '擬'),
#   count    50
#   Name: (NAT, 擬), dtype: int64),
#  (('NAT', '施壓'),
#   count    50
#   Name: (NAT, 施壓), dtype: int64),
#  (('NAT', '激烈'),
#   count    50
#   Name: (NAT, 激烈), dtype: int64),
#  (('NAT', '個'),
#   count    49
#   Name: (NAT, 個), dtype: int64),
#  (('NAT', '停留'),
#   count    49
#   Name: (NAT, 停留), dtype: int64),
#  (('NAT', '嘴'),
#   count    49
#   Name: (NAT, 嘴), dtype: int64),
#  (('NAT', '回家'),
#   count    49
#   Name: (NAT, 回家), dtype: int64),
#  (('NAT', '廢掉'),
#   count    49
#   Name: (NAT, 廢掉), dtype: int64),
#  (('NAT', '持有'),
#   count    49
#   Name: (NAT, 持有), dtype: int64),
#  (('NAT', '獨家'),
#   count    49
#   Name: (NAT, 獨家), dtype: int64),
#  (('NAT', '生氣'),
#   count    49
#   Name: (NAT, 生氣), dtype: int64),
#  (('NAT', '裁准'),
#   count    49
#   Name: (NAT, 裁准), dtype: int64),
#  (('NAT', '計'),
#   count    49
#   Name: (NAT, 計), dtype: int64),
#  (('NAT', '跨'),
#   count    49
#   Name: (NAT, 跨), dtype: int64),
#  (('NAT', '轉發'),
#   count    49
#   Name: (NAT, 轉發), dtype: int64),
#  (('NAT', '降到'),
#   count    49
#   Name: (NAT, 降到), dtype: int64),
#  (('NAT', '交付'),
#   count    48
#   Name: (NAT, 交付), dtype: int64),
#  (('NAT', '享有'),
#   count    48
#   Name: (NAT, 享有), dtype: int64),
#  (('NAT', '借'),
#   count    48
#   Name: (NAT, 借), dtype: int64),
#  (('NAT', '帶動'),
#   count    48
#   Name: (NAT, 帶動), dtype: int64),
#  (('NAT', '投控'),
#   count    48
#   Name: (NAT, 投控), dtype: int64),
#  (('NAT', '自稱'),
#   count    48
#   Name: (NAT, 自稱), dtype: int64),
#  (('NAT', '講話'),
#   count    48
#   Name: (NAT, 講話), dtype: int64),
#  (('NAT', '跨國'),
#   count    48
#   Name: (NAT, 跨國), dtype: int64),
#  (('NAT', '開啟'),
#   count    48
#   Name: (NAT, 開啟), dtype: int64),
#  (('NAT', '點'),
#   count    48
#   Name: (NAT, 點), dtype: int64),
#  (('NAT', '任'),
#   count    47
#   Name: (NAT, 任), dtype: int64),
#  (('NAT', '具備'),
#   count    47
#   Name: (NAT, 具備), dtype: int64),
#  (('NAT', '取'),
#   count    47
#   Name: (NAT, 取), dtype: int64),
#  (('NAT', '大漲'),
#   count    47
#   Name: (NAT, 大漲), dtype: int64),
#  (('NAT', '為由'),
#   count    47
#   Name: (NAT, 為由), dtype: int64),
#  (('NAT', '熱'),
#   count    47
#   Name: (NAT, 熱), dtype: int64),
#  (('NAT', '短缺'),
#   count    47
#   Name: (NAT, 短缺), dtype: int64),
#  (('NAT', '硬'),
#   count    47
#   Name: (NAT, 硬), dtype: int64),
#  (('NAT', '示範'),
#   count    47
#   Name: (NAT, 示範), dtype: int64),
#  (('NAT', '花錢'),
#   count    47
#   Name: (NAT, 花錢), dtype: int64),
#  (('NAT', '試'),
#   count    47
#   Name: (NAT, 試), dtype: int64),
#  (('NAT', '認知'),
#   count    47
#   Name: (NAT, 認知), dtype: int64),
#  (('NAT', '轉移'),
#   count    47
#   Name: (NAT, 轉移), dtype: int64),
#  (('NAT', '香'),
#   count    47
#   Name: (NAT, 香), dtype: int64),
#  (('NAT', '估'),
#   count    46
#   Name: (NAT, 估), dtype: int64),
#  (('NAT', '公立'),
#   count    46
#   Name: (NAT, 公立), dtype: int64),
#  (('NAT', '出動'),
#   count    46
#   Name: (NAT, 出動), dtype: int64),
#  (('NAT', '出走'),
#   count    46
#   Name: (NAT, 出走), dtype: int64),
#  (('NAT', '到期'),
#   count    46
#   Name: (NAT, 到期), dtype: int64),
#  (('NAT', '宣示'),
#   count    46
#   Name: (NAT, 宣示), dtype: int64),
#  (('NAT', '晚安'),
#   count    46
#   Name: (NAT, 晚安), dtype: int64),
#  (('NAT', '相比'),
#   count    46
#   Name: (NAT, 相比), dtype: int64),
#  (('NAT', '知情'),
#   count    46
#   Name: (NAT, 知情), dtype: int64),
#  (('NAT', '祭出'),
#   count    46
#   Name: (NAT, 祭出), dtype: int64),
#  (('NAT', '說出'),
#   count    46
#   Name: (NAT, 說出), dtype: int64),
#  (('NAT', '跟上'),
#   count    46
#   Name: (NAT, 跟上), dtype: int64),
#  (('NAT', '辦案'),
#   count    46
#   Name: (NAT, 辦案), dtype: int64),
#  (('NAT', '上路'),
#   count    45
#   Name: (NAT, 上路), dtype: int64),
#  (('NAT', '下修'),
#   count    45
#   Name: (NAT, 下修), dtype: int64),
#  (('NAT', '作出'),
#   count    45
#   Name: (NAT, 作出), dtype: int64),
#  (('NAT', '列出'),
#   count    45
#   Name: (NAT, 列出), dtype: int64),
#  (('NAT', '加大'),
#   count    45
#   Name: (NAT, 加大), dtype: int64),
#  (('NAT', '待在'),
#   count    45
#   Name: (NAT, 待在), dtype: int64),
#  (('NAT', '披露'),
#   count    45
#   Name: (NAT, 披露), dtype: int64),
#  (('NAT', '捧'),
#   count    45
#   Name: (NAT, 捧), dtype: int64),
#  (('NAT', '接觸'),
#   count    45
#   Name: (NAT, 接觸), dtype: int64),
#  (('NAT', '放過'),
#   count    45
#   Name: (NAT, 放過), dtype: int64),
#  (('NAT', '敏感'),
#   count    45
#   Name: (NAT, 敏感), dtype: int64),
#  (('NAT', '相當於'),
#   count    45
#   Name: (NAT, 相當於), dtype: int64),
#  (('NAT', '移'),
#   count    45
#   Name: (NAT, 移), dtype: int64),
#  (('NAT', '聊'),
#   count    45
#   Name: (NAT, 聊), dtype: int64),
#  (('NAT', '自主'),
#   count    45
#   Name: (NAT, 自主), dtype: int64),
#  (('NAT', '跳'),
#   count    45
#   Name: (NAT, 跳), dtype: int64),
#  (('NAT', '不管'),
#   count    44
#   Name: (NAT, 不管), dtype: int64),
#  (('NAT', '嘗試'),
#   count    44
#   Name: (NAT, 嘗試), dtype: int64),
#  (('NAT', '固定'),
#   count    44
#   Name: (NAT, 固定), dtype: int64),
#  (('NAT', '尋求'),
#   count    44
#   Name: (NAT, 尋求), dtype: int64),
#  (('NAT', '成熟'),
#   count    44
#   Name: (NAT, 成熟), dtype: int64),
#  (('NAT', '打來'),
#   count    44
#   Name: (NAT, 打來), dtype: int64),
#  (('NAT', '投給'),
#   count    44
#   Name: (NAT, 投給), dtype: int64),
#  (('NAT', '拜託'),
#   count    44
#   Name: (NAT, 拜託), dtype: int64),
#  (('NAT', '推行'),
#   count    44
#   Name: (NAT, 推行), dtype: int64),
#  (('NAT', '擠'),
#   count    44
#   Name: (NAT, 擠), dtype: int64),
#  (('NAT', '移民'),
#   count    44
#   Name: (NAT, 移民), dtype: int64),
#  (('NAT', '競選'),
#   count    44
#   Name: (NAT, 競選), dtype: int64),
#  (('NAT', '缺工'),
#   count    44
#   Name: (NAT, 缺工), dtype: int64),
#  (('NAT', '轉為'),
#   count    44
#   Name: (NAT, 轉為), dtype: int64),
#  (('NAT', '進去'),
#   count    44
#   Name: (NAT, 進去), dtype: int64),
#  (('NAT', '不如'),
#   count    43
#   Name: (NAT, 不如), dtype: int64),
#  (('NAT', '件'),
#   count    43
#   Name: (NAT, 件), dtype: int64),
#  (('NAT', '休'),
#   count    43
#   Name: (NAT, 休), dtype: int64),
#  (('NAT', '地下'),
#   count    43
#   Name: (NAT, 地下), dtype: int64),
#  (('NAT', '建交'),
#   count    43
#   Name: (NAT, 建交), dtype: int64),
#  (('NAT', '拋出'),
#   count    43
#   Name: (NAT, 拋出), dtype: int64),
#  (('NAT', '暴增'),
#   count    43
#   Name: (NAT, 暴增), dtype: int64),
#  (('NAT', '睽違'),
#   count    43
#   Name: (NAT, 睽違), dtype: int64),
#  (('NAT', '約談'),
#   count    43
#   Name: (NAT, 約談), dtype: int64),
#  (('NAT', '綠'),
#   count    43
#   Name: (NAT, 綠), dtype: int64),
#  (('NAT', '聯手'),
#   count    43
#   Name: (NAT, 聯手), dtype: int64),
#  (('NAT', '落實'),
#   count    43
#   Name: (NAT, 落實), dtype: int64),
#  (('NAT', '護航'),
#   count    43
#   Name: (NAT, 護航), dtype: int64),
#  (('NAT', '進來'),
#   count    43
#   Name: (NAT, 進來), dtype: int64),
# ...
#  (('NAT', '聚集'),
#   count    42
#   Name: (NAT, 聚集), dtype: int64),
#  (('NAT', '聯絡'),
#   count    42
#   Name: (NAT, 聯絡), dtype: int64),
#  (('NAT', '脫離'),
#   count    42
#   Name: (NAT, 脫離), dtype: int64),
#  (('NAT', '變化'),
#   count    42
#   Name: (NAT, 變化), dtype: int64),
#  (('NAT', '附上'),
#   count    42
#   Name: (NAT, 附上), dtype: int64),
#  (('NAT', '刷'),
#   count    41
#   Name: (NAT, 刷), dtype: int64),
#  (('NAT', '創立'),
#   count    41
#   Name: (NAT, 創立), dtype: int64),
#  (('NAT', '升'),
#   count    41
#   Name: (NAT, 升), dtype: int64),
#  (('NAT', '宣判'),
#   count    41
#   Name: (NAT, 宣判), dtype: int64),
#  (('NAT', '抗告'),
#   count    41
#   Name: (NAT, 抗告), dtype: int64),
#  (('NAT', '拍攝'),
#   count    41
#   Name: (NAT, 拍攝), dtype: int64),
#  (('NAT', '求'),
#   count    41
#   Name: (NAT, 求), dtype: int64),
#  (('NAT', '畫'),
#   count    41
#   Name: (NAT, 畫), dtype: int64),
#  (('NAT', '登記'),
#   count    41
#   Name: (NAT, 登記), dtype: int64),
#  (('NAT', '移到'),
#   count    41
#   Name: (NAT, 移到), dtype: int64),
#  (('NAT', '管理'),
#   count    41
#   Name: (NAT, 管理), dtype: int64),
#  (('NAT', '透明'),
#   count    41
#   Name: (NAT, 透明), dtype: int64),
#  (('NAT', '點出'),
#   count    41
#   Name: (NAT, 點出), dtype: int64),
#  (('NAT', '協調'),
#   count    40
#   Name: (NAT, 協調), dtype: int64),
#  (('NAT', '呈'),
#   count    40
#   Name: (NAT, 呈), dtype: int64),
#  (('NAT', '天然'),
#   count    40
#   Name: (NAT, 天然), dtype: int64),
#  (('NAT', '屆滿'),
#   count    40
#   Name: (NAT, 屆滿), dtype: int64),
#  (('NAT', '打擊'),
#   count    40
#   Name: (NAT, 打擊), dtype: int64),
#  (('NAT', '承受'),
#   count    40
#   Name: (NAT, 承受), dtype: int64),
#  (('NAT', '抱'),
#   count    40
#   Name: (NAT, 抱), dtype: int64),
#  (('NAT', '抵'),
#   count    40
#   Name: (NAT, 抵), dtype: int64),
#  (('NAT', '捍衛'),
#   count    40
#   Name: (NAT, 捍衛), dtype: int64),
#  (('NAT', '攻'),
#   count    40
#   Name: (NAT, 攻), dtype: int64),
#  (('NAT', '標題'),
#   count    40
#   Name: (NAT, 標題), dtype: int64),
#  (('NAT', '猛'),
#   count    40
#   Name: (NAT, 猛), dtype: int64),
#  (('NAT', '繞'),
#   count    40
#   Name: (NAT, 繞), dtype: int64),
#  (('NAT', '繳稅'),
#   count    40
#   Name: (NAT, 繳稅), dtype: int64),
#  (('NAT', '脫鉤'),
#   count    40
#   Name: (NAT, 脫鉤), dtype: int64),
#  (('NAT', '設有'),
#   count    40
#   Name: (NAT, 設有), dtype: int64),
#  (('NAT', '通報'),
#   count    40
#   Name: (NAT, 通報), dtype: int64),
#  (('NAT', '來勢洶洶'),
#   count    39
#   Name: (NAT, 來勢洶洶), dtype: int64),
#  (('NAT', '卡關'),
#   count    39
#   Name: (NAT, 卡關), dtype: int64),
#  (('NAT', '圍'),
#   count    39
#   Name: (NAT, 圍), dtype: int64),
#  (('NAT', '如'),
#   count    39
#   Name: (NAT, 如), dtype: int64),
#  (('NAT', '怎麼'),
#   count    39
#   Name: (NAT, 怎麼), dtype: int64),
#  (('NAT', '爆滿'),
#   count    39
#   Name: (NAT, 爆滿), dtype: int64),
#  (('NAT', '答應'),
#   count    39
#   Name: (NAT, 答應), dtype: int64),
#  (('NAT', '花費'),
#   count    39
#   Name: (NAT, 花費), dtype: int64),
#  (('NAT', '調'),
#   count    39
#   Name: (NAT, 調), dtype: int64),
#  (('NAT', '附'),
#   count    39
#   Name: (NAT, 附), dtype: int64),
#  (('NAT', '上課'),
#   count    38
#   Name: (NAT, 上課), dtype: int64),
#  (('NAT', '保衛'),
#   count    38
#   Name: (NAT, 保衛), dtype: int64),
#  (('NAT', '充足'),
#   count    38
#   Name: (NAT, 充足), dtype: int64),
#  (('NAT', '合憲'),
#   count    38
#   Name: (NAT, 合憲), dtype: int64),
#  (('NAT', '問問'),
#   count    38
#   Name: (NAT, 問問), dtype: int64),
#  (('NAT', '因應'),
#   count    38
#   Name: (NAT, 因應), dtype: int64),
#  (('NAT', '扛'),
#   count    38
#   Name: (NAT, 扛), dtype: int64),
#  (('NAT', '支'),
#   count    38
#   Name: (NAT, 支), dtype: int64),
#  (('NAT', '有利'),
#   count    38
#   Name: (NAT, 有利), dtype: int64),
#  (('NAT', '蒐集'),
#   count    38
#   Name: (NAT, 蒐集), dtype: int64),
#  (('NAT', '覺醒'),
#   count    38
#   Name: (NAT, 覺醒), dtype: int64),
#  (('NAT', '過不了'),
#   count    38
#   Name: (NAT, 過不了), dtype: int64),
#  (('NAT', '達標'),
#   count    38
#   Name: (NAT, 達標), dtype: int64),
#  (('NAT', '那樣'),
#   count    38
#   Name: (NAT, 那樣), dtype: int64),
#  (('NAT', '開示'),
#   count    38
#   Name: (NAT, 開示), dtype: int64),
#  (('NAT', '除役'),
#   count    38
#   Name: (NAT, 除役), dtype: int64),
#  (('NAT', '出手'),
#   count    37
#   Name: (NAT, 出手), dtype: int64),
#  (('NAT', '加碼'),
#   count    37
#   Name: (NAT, 加碼), dtype: int64),
#  (('NAT', '暗示'),
#   count    37
#   Name: (NAT, 暗示), dtype: int64),
#  (('NAT', '碰到'),
#   count    37
#   Name: (NAT, 碰到), dtype: int64),
#  (('NAT', '立法'),
#   count    37
#   Name: (NAT, 立法), dtype: int64),
#  (('NAT', '見到'),
#   count    37
#   Name: (NAT, 見到), dtype: int64),
#  (('NAT', '註銷'),
#   count    37
#   Name: (NAT, 註銷), dtype: int64),
#  (('NAT', '退休'),
#   count    37
#   Name: (NAT, 退休), dtype: int64),
#  (('NAT', '過剩'),
#   count    37
#   Name: (NAT, 過剩), dtype: int64),
#  (('NAT', '釐清'),
#   count    37
#   Name: (NAT, 釐清), dtype: int64),
#  (('NAT', '限縮'),
#   count    37
#   Name: (NAT, 限縮), dtype: int64),
#  (('NAT', '飆'),
#   count    37
#   Name: (NAT, 飆), dtype: int64),
#  (('NAT', '上架'),
#   count    36
#   Name: (NAT, 上架), dtype: int64),
#  (('NAT', '化'),
#   count    36
#   Name: (NAT, 化), dtype: int64),
#  (('NAT', '守護'),
#   count    36
#   Name: (NAT, 守護), dtype: int64),
#  (('NAT', '就讀'),
#   count    36
#   Name: (NAT, 就讀), dtype: int64),
#  (('NAT', '意圖'),
#   count    36
#   Name: (NAT, 意圖), dtype: int64),
#  (('NAT', '應對'),
#   count    36
#   Name: (NAT, 應對), dtype: int64),
#  (('NAT', '截圖'),
#   count    36
#   Name: (NAT, 截圖), dtype: int64),
#  (('NAT', '按'),
#   count    36
#   Name: (NAT, 按), dtype: int64),
#  (('NAT', '提要'),
#   count    36
#   Name: (NAT, 提要), dtype: int64),
#  (('NAT', '擺'),
#   count    36
#   Name: (NAT, 擺), dtype: int64),
#  (('NAT', '放到'),
#   count    36
#   Name: (NAT, 放到), dtype: int64),
#  (('NAT', '湧入'),
#   count    36
#   Name: (NAT, 湧入), dtype: int64),
#  (('NAT', '漲到'),
#   count    36
#   Name: (NAT, 漲到), dtype: int64),
#  (('NAT', '爭'),
#   count    36
#   Name: (NAT, 爭), dtype: int64),
#  (('NAT', '生成'),
#   count    36
#   Name: (NAT, 生成), dtype: int64),
#  (('NAT', '當兵'),
#   count    36
#   Name: (NAT, 當兵), dtype: int64),
#  (('NAT', '説'),
#   count    36
#   Name: (NAT, 説), dtype: int64),
#  (('NAT', '購'),
#   count    36
#   Name: (NAT, 購), dtype: int64),
#  (('NAT', '離'),
#   count    36
#   Name: (NAT, 離), dtype: int64),
#  (('NAT', '顧'),
#   count    36
#   Name: (NAT, 顧), dtype: int64),
#  (('NAT', '飾演'),
#   count    36
#   Name: (NAT, 飾演), dtype: int64),
#  (('NAT', '中斷'),
#   count    35
#   Name: (NAT, 中斷), dtype: int64),
#  (('NAT', '介於'),
#   count    35
#   Name: (NAT, 介於), dtype: int64),
#  (('NAT', '修憲'),
#   count    35
#   Name: (NAT, 修憲), dtype: int64),
#  (('NAT', '出發'),
#   count    35
#   Name: (NAT, 出發), dtype: int64),
#  (('NAT', '定義'),
#   count    35
#   Name: (NAT, 定義), dtype: int64),
#  (('NAT', '居多'),
#   count    35
#   Name: (NAT, 居多), dtype: int64),
#  (('NAT', '忍不住'),
#   count    35
#   Name: (NAT, 忍不住), dtype: int64),
#  (('NAT', '掌控'),
#   count    35
#   Name: (NAT, 掌控), dtype: int64),
#  (('NAT', '擴張'),
#   count    35
#   Name: (NAT, 擴張), dtype: int64),
#  (('NAT', '攝影'),
#   count    35
#   Name: (NAT, 攝影), dtype: int64),
#  (('NAT', '斷'),
#   count    35
#   Name: (NAT, 斷), dtype: int64),
#  (('NAT', '欲'),
#   count    35
#   Name: (NAT, 欲), dtype: int64),
#  (('NAT', '深刻'),
#   count    35
#   Name: (NAT, 深刻), dtype: int64),
#  (('NAT', '生效'),
#   count    35
#   Name: (NAT, 生效), dtype: int64),
#  (('NAT', '致電'),
#   count    35
#   Name: (NAT, 致電), dtype: int64),
#  (('NAT', '躺'),
#   count    35
#   Name: (NAT, 躺), dtype: int64),
#  (('NAT', '開會'),
#   count    35
#   Name: (NAT, 開會), dtype: int64),
#  (('NAT', '驗證'),
#   count    35
#   Name: (NAT, 驗證), dtype: int64),
#  (('NAT', '鬧'),
#   count    35
#   Name: (NAT, 鬧), dtype: int64),
#  (('NAT', '做主'),
#   count    34
#   Name: (NAT, 做主), dtype: int64),
#  (('NAT', '制定'),
#   count    34
#   Name: (NAT, 制定), dtype: int64),
#  (('NAT', '制衡'),
#   count    34
#   Name: (NAT, 制衡), dtype: int64),
#  (('NAT', '反問'),
#   count    34
#   Name: (NAT, 反問), dtype: int64),
#  (('NAT', '合併'),
#   count    34
#   Name: (NAT, 合併), dtype: int64),
#  (('NAT', '唸'),
#   count    34
#   Name: (NAT, 唸), dtype: int64),
#  (('NAT', '安'),
#   count    34
#   Name: (NAT, 安), dtype: int64),
#  (('NAT', '帶到'),
#   count    34
#   Name: (NAT, 帶到), dtype: int64),
#  (('NAT', '廣'),
#   count    34
#   Name: (NAT, 廣), dtype: int64),
#  (('NAT', '援助'),
#   count    34
#   Name: (NAT, 援助), dtype: int64),
#  (('NAT', '搜索'),
#   count    34
#   Name: (NAT, 搜索), dtype: int64),
#  (('NAT', '白'),
#   count    34
#   Name: (NAT, 白), dtype: int64),
#  (('NAT', '租'),
#   count    34
#   Name: (NAT, 租), dtype: int64),
#  (('NAT', '聲明'),
#   count    34
#   Name: (NAT, 聲明), dtype: int64),
#  (('NAT', '補'),
#   count    34
#   Name: (NAT, 補), dtype: int64),
#  (('NAT', '驚'),
#   count    34
#   Name: (NAT, 驚), dtype: int64),
#  (('NAT', '二手'),
#   count    33
#   Name: (NAT, 二手), dtype: int64),
#  (('NAT', '偏向'),
#   count    33
#   Name: (NAT, 偏向), dtype: int64),
#  (('NAT', '外來'),
#   count    33
#   Name: (NAT, 外來), dtype: int64),
#  (('NAT', '平等'),
#   count    33
#   Name: (NAT, 平等), dtype: int64),
#  (('NAT', '平衡'),
#   count    33
#   Name: (NAT, 平衡), dtype: int64),
#  (('NAT', '引'),
#   count    33
#   Name: (NAT, 引), dtype: int64),
#  (('NAT', '強勁'),
#   count    33
#   Name: (NAT, 強勁), dtype: int64),
#  (('NAT', '得知'),
#   count    33
#   Name: (NAT, 得知), dtype: int64),
#  (('NAT', '打回'),
#   count    33
#   Name: (NAT, 打回), dtype: int64),
#  (('NAT', '會'),
#   count    33
#   Name: (NAT, 會), dtype: int64),
#  (('NAT', '確鑿'),
#   count    33
#   Name: (NAT, 確鑿), dtype: int64),
#  (('NAT', '聚焦'),
#   count    33
#   Name: (NAT, 聚焦), dtype: int64),
#  (('NAT', '走到'),
#   count    33
#   Name: (NAT, 走到), dtype: int64),
#  (('NAT', '進場'),
#   count    33
#   Name: (NAT, 進場), dtype: int64),
#  (('NAT', '上來'),
#   count    32
#   Name: (NAT, 上來), dtype: int64),
#  (('NAT', '上線'),
#   count    32
#   Name: (NAT, 上線), dtype: int64),
#  (('NAT', '係'),
#   count    32
#   Name: (NAT, 係), dtype: int64),
#  (('NAT', '公分'),
#   count    32
#   Name: (NAT, 公分), dtype: int64),
#  (('NAT', '出版'),
#   count    32
#   Name: (NAT, 出版), dtype: int64),
#  (('NAT', '分為'),
#   count    32
#   Name: (NAT, 分為), dtype: int64),
#  (('NAT', '問及'),
#   count    32
#   Name: (NAT, 問及), dtype: int64),
#  (('NAT', '專業'),
#   count    32
#   Name: (NAT, 專業), dtype: int64),
#  (('NAT', '尋'),
#   count    32
#   Name: (NAT, 尋), dtype: int64),
#  (('NAT', '居住'),
#   count    32
#   Name: (NAT, 居住), dtype: int64),
#  (('NAT', '巨大'),
#   count    32
#   Name: (NAT, 巨大), dtype: int64),
#  (('NAT', '查到'),
#   count    32
#   Name: (NAT, 查到), dtype: int64),
#  (('NAT', '派出'),
#   count    32
#   Name: (NAT, 派出), dtype: int64),
#  (('NAT', '盡'),
#   count    32
#   Name: (NAT, 盡), dtype: int64),
#  (('NAT', '科幻'),
#   count    32
#   Name: (NAT, 科幻), dtype: int64),
#  (('NAT', '賣超'),
#   count    32
#   Name: (NAT, 賣超), dtype: int64),
#  (('NAT', '雙標'),
#   count    32
#   Name: (NAT, 雙標), dtype: int64),
#  (('NAT', '預言'),
#   count    32
#   Name: (NAT, 預言), dtype: int64),
#  (('NAT', '任職'),
#   count    31
#   Name: (NAT, 任職), dtype: int64),
#  (('NAT', '個別'),
#   count    31
#   Name: (NAT, 個別), dtype: int64),
#  (('NAT', '假裝'),
#   count    31
#   Name: (NAT, 假裝), dtype: int64),
#  (('NAT', '做成'),
#   count    31
#   Name: (NAT, 做成), dtype: int64),
#  (('NAT', '公'),
#   count    31
#   Name: (NAT, 公), dtype: int64),
#  (('NAT', '分區'),
#   count    31
#   Name: (NAT, 分區), dtype: int64),
#  (('NAT', '回升'),
#   count    31
#   Name: (NAT, 回升), dtype: int64),
#  (('NAT', '對待'),
#   count    31
#   Name: (NAT, 對待), dtype: int64),
#  (('NAT', '干擾'),
#   count    31
#   Name: (NAT, 干擾), dtype: int64),
#  (('NAT', '建'),
#   count    31
#   Name: (NAT, 建), dtype: int64),
#  (('NAT', '批准'),
#   count    31
#   Name: (NAT, 批准), dtype: int64),
#  (('NAT', '排隊'),
#   count    31
#   Name: (NAT, 排隊), dtype: int64),
#  (('NAT', '核准'),
#   count    31
#   Name: (NAT, 核准), dtype: int64),
#  (('NAT', '發放'),
#   count    31
#   Name: (NAT, 發放), dtype: int64),
#  (('NAT', '監控'),
#   count    31
#   Name: (NAT, 監控), dtype: int64),
#  (('NAT', '自認'),
#   count    31
#   Name: (NAT, 自認), dtype: int64),
#  (('NAT', '計畫'),
#   count    31
#   Name: (NAT, 計畫), dtype: int64),
#  (('NAT', '記載'),
#   count    31
#   Name: (NAT, 記載), dtype: int64),
#  (('NAT', '認可'),
#   count    31
#   Name: (NAT, 認可), dtype: int64),
#  (('NAT', '說出來'),
#   count    31
#   Name: (NAT, 說出來), dtype: int64),
#  (('NAT', '請辭'),
#   count    31
#   Name: (NAT, 請辭), dtype: int64),
#  (('NAT', '超貼'),
#   count    31
#   Name: (NAT, 超貼), dtype: int64),
#  (('NAT', '退選'),
#   count    31
#   Name: (NAT, 退選), dtype: int64),
#  (('NAT', '鎖定'),
#   count    31
#   Name: (NAT, 鎖定), dtype: int64),
#  (('NAT', '限定'),
#   count    31
#   Name: (NAT, 限定), dtype: int64),
#  (('NAT', '下列'),
#   count    30
#   Name: (NAT, 下列), dtype: int64),
#  (('NAT', '享'),
#   count    30
#   Name: (NAT, 享), dtype: int64),
#  (('NAT', '修改'),
#   count    30
#   Name: (NAT, 修改), dtype: int64),
#  (('NAT', '偷吃'),
#   count    30
#   Name: (NAT, 偷吃), dtype: int64),
#  (('NAT', '入主'),
#   count    30
#   Name: (NAT, 入主), dtype: int64),
#  (('NAT', '包圍'),
#   count    30
#   Name: (NAT, 包圍), dtype: int64),
#  (('NAT', '升格'),
#   count    30
#   Name: (NAT, 升格), dtype: int64),
#  (('NAT', '反擊'),
#   count    30
#   Name: (NAT, 反擊), dtype: int64),
#  (('NAT', '妥協'),
#   count    30
#   Name: (NAT, 妥協), dtype: int64),
#  (('NAT', '建國'),
#   count    30
#   Name: (NAT, 建國), dtype: int64),
#  (('NAT', '拉到'),
#   count    30
#   Name: (NAT, 拉到), dtype: int64),
#  (('NAT', '推測'),
#   count    30
#   Name: (NAT, 推測), dtype: int64),
#  (('NAT', '推翻'),
#   count    30
#   Name: (NAT, 推翻), dtype: int64),
#  (('NAT', '放下'),
#   count    30
#   Name: (NAT, 放下), dtype: int64),
#  (('NAT', '普通'),
#   count    30
#   Name: (NAT, 普通), dtype: int64),
#  (('NAT', '流傳'),
#   count    30
#   Name: (NAT, 流傳), dtype: int64),
#  (('NAT', '清'),
#   count    30
#   Name: (NAT, 清), dtype: int64),
#  (('NAT', '源'),
#   count    30
#   Name: (NAT, 源), dtype: int64),
#  (('NAT', '發佈'),
#   count    30
#   Name: (NAT, 發佈), dtype: int64),
#  (('NAT', '示'),
#   count    30
#   Name: (NAT, 示), dtype: int64),
#  (('NAT', '穿越'),
#   count    30
#   Name: (NAT, 穿越), dtype: int64),
#  (('NAT', '翻倍'),
#   count    30
#   Name: (NAT, 翻倍), dtype: int64),
#  (('NAT', '膨脹'),
#   count    30
#   Name: (NAT, 膨脹), dtype: int64),
#  (('NAT', '補貼'),
#   count    30
#   Name: (NAT, 補貼), dtype: int64),
#  (('NAT', '試試'),
#   count    30
#   Name: (NAT, 試試), dtype: int64),
#  (('NAT', '課'),
#   count    30
#   Name: (NAT, 課), dtype: int64),
#  (('NAT', '談論'),
#   count    30
#   Name: (NAT, 談論), dtype: int64),
#  (('NAT', '轉往'),
#   count    30
#   Name: (NAT, 轉往), dtype: int64),
#  (('NAT', '出訪'),
#   count    29
#   Name: (NAT, 出訪), dtype: int64),
#  (('NAT', '台幣'),
#   count    29
#   Name: (NAT, 台幣), dtype: int64),
#  (('NAT', '回去'),
#   count    29
#   Name: (NAT, 回去), dtype: int64),
#  (('NAT', '安裝'),
#   count    29
#   Name: (NAT, 安裝), dtype: int64),
#  (('NAT', '對話'),
#   count    29
#   Name: (NAT, 對話), dtype: int64),
#  (('NAT', '收取'),
#   count    29
#   Name: (NAT, 收取), dtype: int64),
#  (('NAT', '日常'),
#   count    29
#   Name: (NAT, 日常), dtype: int64),
#  (('NAT', '曉得'),
#   count    29
#   Name: (NAT, 曉得), dtype: int64),
#  (('NAT', '有意'),
#   count    29
#   Name: (NAT, 有意), dtype: int64),
#  (('NAT', '毫無'),
#   count    29
#   Name: (NAT, 毫無), dtype: int64),
#  (('NAT', '民主'),
#   count    29
#   Name: (NAT, 民主), dtype: int64),
#  (('NAT', '派遣'),
#   count    29
#   Name: (NAT, 派遣), dtype: int64),
#  (('NAT', '用完'),
#   count    29
#   Name: (NAT, 用完), dtype: int64),
#  (('NAT', '當上'),
#   count    29
#   Name: (NAT, 當上), dtype: int64),
#  (('NAT', '種'),
#   count    29
#   Name: (NAT, 種), dtype: int64),
#  (('NAT', '繼續'),
#   count    29
#   Name: (NAT, 繼續), dtype: int64),
#  (('NAT', '聊天'),
#   count    29
#   Name: (NAT, 聊天), dtype: int64),
#  (('NAT', '處理掉'),
#   count    29
#   Name: (NAT, 處理掉), dtype: int64),
#  (('NAT', '觀看'),
#   count    29
#   Name: (NAT, 觀看), dtype: int64),
#  (('NAT', '購入'),
#   count    29
#   Name: (NAT, 購入), dtype: int64),
#  (('NAT', '降價'),
#   count    29
#   Name: (NAT, 降價), dtype: int64),
#  (('NAT', '電動'),
#   count    29
#   Name: (NAT, 電動), dtype: int64),
#  (('NAT', '上網'),
#   count    28
#   Name: (NAT, 上網), dtype: int64),
#  (('NAT', '交由'),
#   count    28
#   Name: (NAT, 交由), dtype: int64),
#  (('NAT', '住在'),
#   count    28
#   Name: (NAT, 住在), dtype: int64),
#  (('NAT', '免'),
#   count    28
#   Name: (NAT, 免), dtype: int64),
#  (('NAT', '剖測'),
#   count    28
#   Name: (NAT, 剖測), dtype: int64),
#  (('NAT', '呼應'),
#   count    28
#   Name: (NAT, 呼應), dtype: int64),
#  (('NAT', '回擊'),
#   count    28
#   Name: (NAT, 回擊), dtype: int64),
#  (('NAT', '居'),
#   count    28
#   Name: (NAT, 居), dtype: int64),
#  (('NAT', '徵收'),
#   count    28
#   Name: (NAT, 徵收), dtype: int64),
#  (('NAT', '招'),
#   count    28
#   Name: (NAT, 招), dtype: int64),
#  (('NAT', '拼'),
#   count    28
#   Name: (NAT, 拼), dtype: int64),
#  ...]

# %%
aop_df.groupby("t").get_group("POS")["o"].value_counts()
# Out:
# o
# 好     2406
# 支持     961
# 喜歡     792
# 希望     712
# 愛      616
#       ...
# 豐收       1
# 擔綱       1
# 激化       1
# 歌訟       1
# 嘗到       1
# Name: count, Length: 2579, dtype: int64

# %%
aop_df[(aop_df["date"] < "2024-11-02") & (aop_df["date"] >= "2024-11-01")]
# Out:
#                           id                    date    a    o       p  t
# 4542    eg4AD5MBx63wKxznQgDy 2024-11-01 05:38:27.706    人    住  4.2380  0
# 4543    eg4AD5MBx63wKxznQgDy 2024-11-01 05:38:27.706    我    用  4.6334  0
# 4544    eg4AD5MBx63wKxznQgDy 2024-11-01 05:38:27.706    網    差  3.4000 -1
# 4545    eg4AD5MBx63wKxznQgDy 2024-11-01 05:38:27.706    信    差  3.4000 -1
# 4546    eg4AD5MBx63wKxznQgDy 2024-11-01 05:38:27.706   本人    懂  3.9428 -1
# ...                      ...                     ...  ...  ...     ... ..
# 334549  -Q2dDpMBx63wKxznMfRx 2024-11-01 08:27:26.006   影片    有  4.3538  0
# 334550  -Q2dDpMBx63wKxznMfRx 2024-11-01 08:27:26.006  中選會    想  5.2000  0
# 334551  -Q2dDpMBx63wKxznMfRx 2024-11-01 08:27:26.006   事情  壓下來  3.2600 -1
# 334552  -Q2dDpMBx63wKxznMfRx 2024-11-01 08:27:26.006    票   開完  5.3000  0
# 334553  -Q2dDpMBx63wKxznMfRx 2024-11-01 08:27:26.006    人    放  4.4920  0
#
# [12668 rows x 6 columns]

# %%
id_df = aop_df.groupby(pd.Grouper(key="date", freq="D"))["id"].agg(['unique'])

# %%
type(id_df)

# %%
list(enumerate(pd.concat([id_df, id_df], axis=1).loc["2024-10-26"]))

# %%
list(pd.concat([id_df, id_df], axis=1).loc["2024-10-26"].items())

# %%
str(datetime.date.fromtimestamp(1730310459813.0842/1000))

# %%
aop_df_date_p.loc[datetime.date.fromtimestamp(1730310459813.0842/1000)]

# %%
[i.isoformat()+"Z" for i in aop_df_date_p.index.to_list()]

# %%
id_df.loc["2024-10-26":"2024-10-27"].T

# %%
tmp = list(id_df.loc["2024-10-26":"2024-10-27"].T.iterrows())

# %%
import numpy as np

# %%
tmp[0][1].to_list()

# %%
np.concatenate(tmp[0][1].to_list()).tolist()

# %%
tmp = [(i, j) for i, j in enumerate(id_df.loc["2024-10-26":"2024-10-27"].iterrows())]

# %%
id_df

# %%
tmp[0][1][1].tolist()

# %%
id_df.loc["2024-10-26"].apply(lambda x: x[:5].tolist())

# %%
aop_df_date_p = aop_df.groupby(pd.Grouper(key="date", freq="D"))["p"].mean()

# %%
aop_df_date_t = aop_df.groupby(pd.Grouper(key="date", freq="D"))["t"].mean()

# %%
pd.DataFrame([aop_df_date_p, aop_df_date_p]).T.columns
